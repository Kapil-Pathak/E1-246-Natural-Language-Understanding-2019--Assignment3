# %%
import nltk
from nltk import Tree
from nltk.corpus import treebank
from nltk import Nonterminal, Production
from nltk import induce_pcfg

# %%
print("Induce PCFG grammar from treebank data:")

productions = []
Leaves=set()
for item in treebank.fileids():
    for tree in treebank.parsed_sents(item):
        tree.collapse_unary(collapsePOS = False)# Remove branches A-B-C into A-B+C
        tree.chomsky_normal_form(horzMarkov = 2)# Remove A->(B,C,D) into A->B,C+D->D
        productions += tree.productions()
        for i in range(len(tree.leaves())):
            Leaves.add(tree.leaves()[i])
# Out:
# Induce PCFG grammar from treebank data:

# %%
Leaves=list(Leaves)

# %%
from nltk  import Nonterminal
S = Nonterminal('S')
grammar = induce_pcfg(S, productions)

# %%
from nltk.parse import ViterbiParser
from functools import reduce
sentence="I saw it"
tokens = sentence.split(' ')
parser = ViterbiParser(grammar)
parses = parser.parse_all(tokens)

if parses: 
    lp = len(parses)
    p = reduce(lambda a,b:a+b.prob(), parses, 0.0)
else:
    p = 0
for parse in parses:
    print(parse)
# Out:
# (S (NP-SBJ (PRP I)) (VP (VBD saw) (NP (PRP it)))) (p=5.31475e-10)

# %%
count = {}
rule_count = {}
rule_probs = {}
for rule in grammar:
    if rule[0] not in count:
        count[rule[0]] = 1
    else:
        count[rule[0]] += 1
for rule in grammar:
    if rule not in rule_count:
        rule_count[rule] = 1
    else:
        rule_count[rule] += 1
for entry in rule_count:
    rule_probs[entry] = float(rule_count[entry])/count[entry[0]]

# %%
grammar_rules=[]
for line in productions:
    grammar_rules.append(tuple(str(line).rstrip('\n').split(' -> ')))

# %%
count = {}
rule_count = {}
rule_probs = {}
for rule in grammar_rules:
    if rule[0] not in count:
        count[rule[0]] = 1
    else:
        count[rule[0]] += 1
for rule in grammar_rules:
    if rule not in rule_count:
        rule_count[rule] = 1
    else:
        rule_count[rule] += 1
for entry in rule_count:
    rule_probs[entry] = float(rule_count[entry])/count[entry[0]]

# %%
non_terms = set()
for rules in set(grammar_rules):
    non_terms.add(rules[0])
non_terms=list(non_terms)
sent="I saw John with my eyes"
sent=sent.split(" ")
print(sent)
# Out:
# ['I', 'saw', 'John', 'with', 'my', 'eyes']

# %%
score=[[[0.0 for i in range(len(non_terms))] for j in range(len(sent)+1)] for k in range(len(sent)+1)]
back =[[[-1 for i in range(len(non_terms))] for j in range(len(sent)+1)] for k in range(len(sent)+1)]

# %%
rule_index = {}
from tqdm import tqdm_notebook as tqdm
for i,word in tqdm(enumerate(sent)):
    rules_used = []
    rules_not_used = []
    for j,A in tqdm(enumerate(non_terms)):
        r = A, '\'' + word + '\''
        if r in grammar_rules:
            score[i][i+1][j] = rule_probs[r]
            rules_used.append(j)
            rule_index[A] = j
        else:
            rules_not_used.append(j)
            rule_index[A] = j
    rules_used_temp = rules_used[:]
    rules_not_used_temp = rules_not_used[:]
    added = True
    while added:
        print(added)
        added = False
        for a in rules_not_used:
            for b in rules_used:
                r = non_terms[a], non_terms[b]
                if r in grammar_rules:
                    prob = rule_probs[r] * score[i][i+1][b]
                    if prob > score[i][i+1][a]:
                        score[i][i+1][a] = prob
                        back[i][i+1][a] = b
                        rules_used_temp.append(a)
                        try:
                            rules_not_used_temp.remove(a)
                            rules_used_temp.remove(b)
                        except ValueError:
                            pass
                        added = True

        rules_used = rules_used_temp[:]
        rules_not_used =rules_not_used_temp[:]
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# True
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# True
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# True
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# True
# True
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# True
# True
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# True
# True

# %%
bin_set = set()
for rules in grammar_rules:
    if len(rules[1].split(' ')) == 2:
        b, c = rules[1].split(' ')
        bin_set.add((rules[0],b,c))
        bin_set.add((rules[0], c, b))

# %%
binary_rules =list(bin_set)
for span in tqdm(range(2,len(sent)+1)):
    print("span:"+str(span))
    for begin in tqdm(range(len(sent)+1-span)):
        rules_used = []
        end = begin + span
        print("span: "+str(span)+" begin: "+str(begin)+" end: "+str(end))
        for split in tqdm(range(begin+1, end)):
            print("span: "+str(span)+" begin: "+str(begin)+" end: "+str(end)+" split: "+str(split))
            for rule in tqdm(binary_rules):
                a, b, c = rule_index[rule[0]], rule_index[rule[1]], rule_index[rule[2]]
                concat_rule = rule[0], ' '.join((rule[1], rule[2]))
                if concat_rule in grammar_rules:
                    prob = score[begin][split][b] * score[split][end][c] * rule_probs[concat_rule]
                else:
                    continue
                if prob > score[begin][end][a]:
                    score[begin][end][a] = prob
                    back[begin][end][a] = split, b, c
                    rules_used.append(a)

            ### Handle Unaries
        added = True
        while added:
            added = False
            for a in range(len(non_terms)):
                for b in rules_used:
                    r = non_terms[a], non_terms[b]
                    if r in grammar_rules:
                        prob = rule_probs[r] * score[begin][end][b]
                        if prob > score[begin][end][a]:
                            score[begin][end][a] = prob
                            back[begin][end][a] = b
                            added = True
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# span:2
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# span: 2 begin: 0 end: 2
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 0 end: 2 split: 1
# HBox(children=(IntProgress(value=0, max=20802), HTML(value='')))
# span: 2 begin: 1 end: 3
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 1 end: 3 split: 2
# HBox(children=(IntProgress(value=0, max=20802), HTML(value='')))
# span: 2 begin: 2 end: 4
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 2 end: 4 split: 3
# HBox(children=(IntProgress(value=0, max=20802), HTML(value='')))

# %%
from collections import defaultdict
print(grammar.productions()[0].lhs())
source=defaultdict()
prob=defaultdict()
rhs_1=set()
lhs_1=set()
total=set()
for i in range(len(grammar.productions())):
    q=len(grammar.productions()[i].rhs())
    print(grammar.productions()[i].lhs())
    A=str(grammar.productions()[i]).split(' -> ')[0]
    print(A)
    BC=str(grammar.productions()[i]).split(' -> ')[1].split()[:-1]
    source[A]=BC
    lhs_1.add(A)
    total.add(A)
    p1=float(str(grammar.productions()[i]).split(' -> ')[1].split()[-1][1:-1])
    if len(BC)==1:
        prob[str(grammar.productions()[i]).split(' -> ')[0]+" -> "+str(BC[0])]=p1
        rhs_1.add(BC[0])
        total.add(BC[0])
    elif len(BC)==2:
        prob[str(grammar.productions()[i]).split(' -> ')[0]+" -> "+str(BC[0])+" "+str(BC[1])]=p1
        rhs_1.add(BC[0])
        rhs_1.add(BC[1])
        total.add(BC[0])
        total.add(BC[1])
rhs_dict=defaultdict()
lhs_dict=defaultdict()
rhs_dict_r=defaultdict()
lhs_dict_l=defaultdict()
for i, item in enumerate(lhs_1):
    lhs_dict[item]=i
    lhs_dict_l[i]=item
total_dict=defaultdict()
reverse_dict=defaultdict()
for i, item in enumerate(total):
    total_dict[item]=i
    reverse_dict[i]=item
# Out:
# S
# S
# S
# NP-SBJ
# NP-SBJ
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NP-SBJ|<,-ADJP>
# NP-SBJ|<,-ADJP>
# ,
# ,
# NP-SBJ|<ADJP-,>
# NP-SBJ|<ADJP-,>
# ADJP
# ADJP
# NP
# NP
# CD
# CD
# NNS
# NNS
# JJ
# JJ
# S|<VP-.>
# S|<VP-.>
# VP
# VP
# MD
# MD
# VP
# VP
# VB
# VB
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# NP
# NP
# DT
# DT
# NN
# NN
# VP|<PP-CLR-NP-TMP>
# VP|<PP-CLR-NP-TMP>
# PP-CLR
# PP-CLR
# IN
# IN
# NP
# NP
# DT
# DT
# NP|<JJ-NN>
# NP|<JJ-NN>
# JJ
# JJ
# NN
# NN
# NP-TMP
# NP-TMP
# NNP
# NNP
# CD
# CD
# .
# .
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# VP
# VP
# VBZ
# VBZ
# NP-PRD
# NP-PRD
# NP
# NP
# NN
# NN
# PP
# PP
# IN
# IN
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NP|<,-NP>
# NP|<,-NP>
# NP
# NP
# NP|<NNP-VBG>
# NP|<NNP-VBG>
# NNP
# NNP
# NP|<VBG-NN>
# NP|<VBG-NN>
# VBG
# VBG
# NN
# NN
# S
# S
# NP-SBJ-1
# NP-SBJ-1
# NNP
# NNP
# NNP
# NNP
# NP-SBJ-1|<,-UCP>
# NP-SBJ-1|<,-UCP>
# NP-SBJ-1|<UCP-,>
# NP-SBJ-1|<UCP-,>
# UCP
# UCP
# CD
# CD
# UCP|<CC-NP>
# UCP|<CC-NP>
# CC
# CC
# NP
# NP
# NP
# NP
# JJ
# JJ
# NP
# NP
# NNP
# NNP
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# NNP
# NNP
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP
# VP
# VBN
# VBN
# S
# S
# NP-SBJ
# NP-SBJ
# -NONE-
# -NONE-
# NP
# NP
# DT
# DT
# NP|<JJ-JJ>
# NP|<JJ-JJ>
# JJ
# JJ
# JJ
# JJ
# NN
# NN
# S
# S
# S-TPC-1
# S-TPC-1
# NP-SBJ
# NP-SBJ
# DT
# DT
# NN
# NN
# NN
# NN
# RRC
# RRC
# ADVP-TMP
# ADVP-TMP
# RB
# RB
# VP
# VP
# VBN
# VBN
# VP|<NP-S-CLR>
# VP|<NP-S-CLR>
# NP
# NP
# -NONE-
# -NONE-
# S-CLR
# S-CLR
# VP
# VP
# TO
# TO
# VP
# VP
# VB
# VB
# NP
# NP
# NNP
# NNP
# NP|<NN-NNS>
# NP|<NN-NNS>
# NN
# NN
# NNS
# NNS
# VP
# VP
# VBZ
# VBZ
# VP
# VP
# VBN
# VBN
# NP
# NP
# JJ
# JJ
# NN
# NN
# NP|<PP-PP-LOC>
# NP|<PP-PP-LOC>
# NP
# NP
# NN
# NN
# NNS
# NNS
# PP-LOC
# PP-LOC
# IN
# IN
# NP
# NP
# NP
# NP
# NNS
# NNS
# RRC+VP
# RRC+VP
# VBN
# VBN
# RRC+VP|<NP-PP-CLR>
# RRC+VP|<NP-PP-CLR>
# RRC+VP|<PP-CLR-ADVP-TMP>
# RRC+VP|<PP-CLR-ADVP-TMP>
# PP-CLR
# PP-CLR
# NP
# NP
# PRP
# PRP
# ADVP-TMP
# ADVP-TMP
# NP
# NP
# QP
# QP
# RBR
# RBR
# QP|<IN-CD>
# QP|<IN-CD>
# IN
# IN
# CD
# CD
# IN
# IN
# S|<,-NP-SBJ>
# S|<,-NP-SBJ>
# S|<NP-SBJ-VP>
# S|<NP-SBJ-VP>
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# SBAR
# SBAR
# -NONE-
# -NONE-
# S
# S
# -NONE-
# -NONE-
# S
# S
# S-TPC-2
# S-TPC-2
# NP-SBJ
# NP-SBJ
# NP
# NP
# DT
# DT
# NP|<NN-NN>
# NP|<NN-NN>
# NN
# NN
# NP-SBJ|<,-NP>
# NP-SBJ|<,-NP>
# NP-SBJ|<NP-,>
# NP-SBJ|<NP-,>
# NN
# NN
# VP
# VP
# VP|<ADJP-PRD-SBAR-TMP>
# VP|<ADJP-PRD-SBAR-TMP>
# ADJP-PRD
# ADJP-PRD
# RB
# RB
# JJ
# JJ
# VP|<SBAR-TMP-,>
# VP|<SBAR-TMP-,>
# SBAR-TMP
# SBAR-TMP
# IN
# IN
# S
# S
# NP-SBJ
# NP-SBJ
# VP
# VP
# VBZ
# VBZ
# NP
# NP
# NNS
# NNS
# VP|<,-PP>
# VP|<,-PP>
# PP
# PP
# IN
# IN
# S-NOM
# S-NOM
# NP-SBJ
# NP-SBJ
# NP
# NP
# RB
# RB
# NP|<JJ-NNS>
# NP|<JJ-NNS>
# JJ
# JJ
# NNS
# NNS
# PP
# PP
# VP
# VP
# VBG
# VBG
# NP
# NP
# NNS
# NNS
# SBAR
# SBAR
# WHNP-1
# WHNP-1
# WDT
# WDT
# VP
# VP
# VBP
# VBP
# VP|<PRT-ADVP-TMP>
# VP|<PRT-ADVP-TMP>
# PRT
# PRT
# RP
# RP
# ADVP-TMP
# ADVP-TMP
# NNS
# NNS
# JJ
# JJ
# VBD
# VBD
# -NONE-
# -NONE-
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NN
# NN
# NP|<PP-SBAR>
# NP|<PP-SBAR>
# NP
# NP
# ADJP
# ADJP
# JJ
# JJ
# JJ
# JJ
# NNP
# NNP
# NNP
# NNP
# SBAR
# SBAR
# WHNP-2
# WHNP-2
# VBZ
# VBZ
# NP
# NP
# NNS
# NNS
# VBD
# VBD
# VP
# VP
# VBG
# VBG
# VP|<NP-PP-LOC-CLR>
# VP|<NP-PP-LOC-CLR>
# VP|<PP-LOC-CLR-PP-TMP>
# VP|<PP-LOC-CLR-PP-TMP>
# PP-LOC-CLR
# PP-LOC-CLR
# IN
# IN
# NP
# NP
# PRP$
# PRP$
# NP|<NN-NN>
# NP|<NN-NN>
# NN
# NN
# PP-TMP
# PP-TMP
# NP
# NP
# CD
# CD
# S
# S
# SBAR-ADV
# SBAR-ADV
# IN
# IN
# S
# S
# NP-SBJ-2
# NP-SBJ-2
# JJ
# JJ
# NNS
# NNS
# VBD
# VBD
# VP
# VP
# VBN
# VBN
# VP|<NP-ADVP-TMP>
# VP|<NP-ADVP-TMP>
# -NONE-
# -NONE-
# NP
# NP
# QP
# QP
# QP|<IN-DT>
# QP|<IN-DT>
# NN
# NN
# NP-SBJ
# NP-SBJ
# NP-SBJ|<JJS-NNS>
# NP-SBJ|<JJS-NNS>
# JJS
# JJS
# NNS
# NNS
# VP
# VP
# VBP
# VBP
# NP
# NP
# NP
# NP
# NN
# NN
# POS
# POS
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NNP
# NNP
# NP
# NP
# NN
# NN
# ADJP
# ADJP
# JJ
# JJ
# VP
# VP
# VB
# VB
# VP|<NP-PP-DIR>
# VP|<NP-PP-DIR>
# JJ
# JJ
# NN
# NN
# PP-DIR
# PP-DIR
# NN
# NN
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NNP-NN>
# NP-SBJ|<NNP-NN>
# NN
# NN
# VP
# VP
# VP|<,-``>
# VP|<,-``>
# VP|<``-S>
# VP|<``-S>
# ``
# ``
# NP-SBJ
# NP-SBJ
# DT
# DT
# NP-PRD
# NP-PRD
# DT
# DT
# NP-PRD|<JJ-NN>
# NP-PRD|<JJ-NN>
# NN
# NN
# PRP
# PRP
# VP
# VP
# VBP
# VBP
# VP
# VP
# VBG
# VBG
# PP-CLR
# PP-CLR
# IN
# IN
# ADVP-TMP
# ADVP-TMP
# ADVP
# ADVP
# SBAR
# SBAR
# IN
# IN
# NP-SBJ
# NP-SBJ
# NN
# NN
# VP
# VP
# VBD
# VBD
# PP-CLR
# PP-CLR
# VBG
# VBG
# NP
# NP
# DT
# DT
# JJ
# JJ
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# EX
# EX
# S|<VP-.>
# S|<VP-.>
# VP
# VP
# VP|<NP-PRD-PP-LOC>
# VP|<NP-PRD-PP-LOC>
# NP-PRD
# NP-PRD
# DT
# DT
# VP|<PP-LOC-ADVP-TMP>
# VP|<PP-LOC-ADVP-TMP>
# NP
# NP
# PRP$
# PRP$
# NNS
# NNS
# RB
# RB
# S|<.-''>
# S|<.-''>
# ''
# ''
# NP-SBJ
# NP-SBJ
# DT
# DT
# NP-SBJ|<NP-CC>
# NP-SBJ|<NP-CC>
# NP-SBJ|<CC-NP>
# NP-SBJ|<CC-NP>
# CC
# CC
# SBAR
# SBAR
# WHNP-3
# WHNP-3
# WP
# WP
# -NONE-
# -NONE-
# VP
# VP
# VBD
# VBD
# VP
# VP
# ADJP-PRD
# ADJP-PRD
# JJ
# JJ
# NN
# NN
# IN
# IN
# NNS
# NNS
# NP
# NP
# NP|<NNP-NNS>
# NP|<NNP-NNS>
# SINV
# SINV
# SINV|<S-TPC-1-,>
# SINV|<S-TPC-1-,>
# VP
# VP
# VBP
# VBP
# JJ
# JJ
# NN
# NN
# PP
# PP
# IN
# IN
# NNS
# NNS
# VP
# VP
# VBP
# VBP
# PP-PRD
# PP-PRD
# IN
# IN
# NN
# NN
# SINV|<,-''>
# SINV|<,-''>
# SINV|<''-VP>
# SINV|<''-VP>
# SINV|<VP-NP-SBJ>
# SINV|<VP-NP-SBJ>
# VP
# VP
# SINV|<NP-SBJ-.>
# SINV|<NP-SBJ-.>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VBD
# VBD
# NN
# NN
# NP
# NP
# PP-DIR
# PP-DIR
# IN
# IN
# NP
# NP
# NP
# NP
# NNP
# NNP
# NP|<CC-NP>
# NP|<CC-NP>
# JJ
# JJ
# NNS
# NNS
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# S
# S
# NP-SBJ-1
# NP-SBJ-1
# VP
# VP
# VP
# VP
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# VP|<PP-CLR-PP-LOC>
# VP|<PP-CLR-PP-LOC>
# PP-CLR
# PP-CLR
# PP-CLR|<``-NP>
# PP-CLR|<``-NP>
# PP-CLR|<NP-''>
# PP-CLR|<NP-''>
# NP
# NP
# ADJP
# ADJP
# RB
# RB
# JJ
# JJ
# NNS
# NNS
# VP|<PP-LOC-PP-TMP>
# VP|<PP-LOC-PP-TMP>
# PP-LOC
# PP-LOC
# VBG
# VBG
# NN
# NN
# IN
# IN
# NP
# NP
# NP|<JJ-CD>
# NP|<JJ-CD>
# JJ
# JJ
# CD
# CD
# VP|<CC-VP>
# VP|<CC-VP>
# VP
# VP
# VBN
# VBN
# VP|<NP-PP>
# VP|<NP-PP>
# VP|<PP-PP-TMP>
# VP|<PP-PP-TMP>
# JJ
# JJ
# NN
# NN
# NN
# NN
# S-TPC-1
# S-TPC-1
# PP-TMP
# PP-TMP
# IN
# IN
# CD
# CD
# CD
# CD
# S-TPC-1|<,-NP-SBJ-3>
# S-TPC-1|<,-NP-SBJ-3>
# S-TPC-1|<NP-SBJ-3-VP>
# S-TPC-1|<NP-SBJ-3-VP>
# NP-SBJ-3
# NP-SBJ-3
# NP
# NP
# QP
# QP
# CD
# CD
# CD
# CD
# VBN
# VBN
# -NONE-
# -NONE-
# NP-SBJ
# NP-SBJ
# NN
# NN
# S
# S
# IN
# IN
# CD
# CD
# NNS
# NNS
# SBAR
# SBAR
# WHNP-4
# WHNP-4
# -NONE-
# -NONE-
# VP
# VP
# VBD
# VBD
# VP|<ADVP-MNR-PP-CLR>
# VP|<ADVP-MNR-PP-CLR>
# ADVP-MNR
# ADVP-MNR
# RB
# RB
# NN
# NN
# NP-SBJ
# NP-SBJ
# CD
# CD
# -NONE-
# -NONE-
# VP
# VP
# VBN
# VBN
# VP|<:-NP-1>
# VP|<:-NP-1>
# :
# :
# NP-1
# NP-1
# QP
# QP
# JJ
# JJ
# QP|<IN-CD>
# QP|<IN-CD>
# QP|<CD-NNS>
# QP|<CD-NNS>
# CD
# CD
# NNS
# NNS
# NP-1|<DT-VBN>
# NP-1|<DT-VBN>
# NP-1|<VBN-NN>
# NP-1|<VBN-NN>
# VBN
# VBN
# NN
# NN
# CD
# CD
# NP
# NP
# NP|<CD-VBG>
# NP|<CD-VBG>
# CD
# CD
# NP|<VBG-NNS>
# NP|<VBG-NNS>
# VBG
# VBG
# VP
# VP
# VP|<NP-,>
# VP|<NP-,>
# NP
# NP
# JJ
# JJ
# NNS
# NNS
# PP
# PP
# VBG
# VBG
# NP
# NP
# ADJP
# ADJP
# RB
# RB
# VBN
# VBN
# NN
# NN
# CD
# CD
# JJ
# JJ
# NN
# NN
# NP|<,-NP>
# NP|<,-NP>
# NP|<NP-CC>
# NP|<NP-CC>
# NP
# NP
# NN
# NN
# NN
# NN
# ADJP-PRD
# ADJP-PRD
# ADJP
# ADJP
# RB
# RB
# JJR
# JJR
# -NONE-
# -NONE-
# NP-SBJ
# NP-SBJ
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NN-NN>
# NP-SBJ|<NN-NN>
# NN
# NN
# NN
# NN
# VP|<NP-PRD-PP-LOC>
# VP|<NP-PRD-PP-LOC>
# JJ
# JJ
# NN
# NN
# NP
# NP
# DT
# DT
# PRP
# PRP
# SBAR
# SBAR
# WHNP-5
# WHNP-5
# -NONE-
# -NONE-
# VBP
# VBP
# S-TPC-2
# S-TPC-2
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<PP-PP-LOC>
# NP-SBJ-1|<PP-PP-LOC>
# NP
# NP
# NP
# NP
# NP
# NP
# NP|<NAC-LOC-NN>
# NP|<NAC-LOC-NN>
# NAC-LOC
# NAC-LOC
# NNP
# NNP
# NAC-LOC|<NNP-,>
# NAC-LOC|<NNP-,>
# NNP
# NNP
# NAC-LOC|<,-NNP>
# NAC-LOC|<,-NNP>
# NAC-LOC|<NNP-,>
# NAC-LOC|<NNP-,>
# NNP
# NNP
# NN
# NN
# VP
# VP
# VBZ
# VBZ
# VP
# VP
# VB
# VB
# NP
# NP
# JJS
# JJS
# NP
# NP
# RRC+VP
# RRC+VP
# VBN
# VBN
# RRC+VP|<NP-PP-LOC>
# RRC+VP|<NP-PP-LOC>
# NP
# NP
# JJ
# JJ
# NP|<VBN-NNS>
# NP|<VBN-NNS>
# VBN
# VBN
# NNS
# NNS
# PRP
# PRP
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP-SBJ|<,-SBAR>
# NP-SBJ|<,-SBAR>
# NP-SBJ|<SBAR-,>
# NP-SBJ|<SBAR-,>
# WDT
# WDT
# S
# S
# NP-SBJ-4
# NP-SBJ-4
# VBN
# VBN
# VP|<NP-PP>
# VP|<NP-PP>
# -NONE-
# -NONE-
# PP
# PP
# IN
# IN
# NP-LGS
# NP-LGS
# NNP
# NNP
# NP-LGS|<CC-NNP>
# NP-LGS|<CC-NNP>
# CC
# CC
# NP-LGS|<NNP-NNP>
# NP-LGS|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# PP-LOC-PRD
# PP-LOC-PRD
# IN
# IN
# NP
# NP
# NP
# NP
# NN
# NN
# -NONE-
# -NONE-
# NP|<PP-S-2>
# NP|<PP-S-2>
# NN
# NN
# S-2
# S-2
# S-TPC-1
# S-TPC-1
# S-TPC-1|<ADVP-VP>
# S-TPC-1|<ADVP-VP>
# ADVP
# ADVP
# RB
# RB
# VB
# VB
# SBAR
# SBAR
# WHNP-6
# WHNP-6
# -NONE-
# -NONE-
# VP
# VP
# VBP
# VBP
# IN
# IN
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# MD
# MD
# VP
# VP
# VB
# VB
# VP|<NP-ADVP-MNR>
# VP|<NP-ADVP-MNR>
# NP
# NP
# NN
# NN
# NP|<PP-PP>
# NP|<PP-PP>
# ADVP-MNR
# ADVP-MNR
# ADVP
# ADVP
# RB
# RB
# NP
# NP
# NP
# NP
# JJ
# JJ
# NN
# NN
# NP|<PP-,>
# NP|<PP-,>
# NP|<,-NP>
# NP|<,-NP>
# NP|<NP-,>
# NP|<NP-,>
# NN
# NN
# VP
# VP
# VBN
# VBN
# VP|<NP-PP-LOC-CLR>
# VP|<NP-PP-LOC-CLR>
# NP
# NP
# JJS
# JJS
# JJ
# JJ
# NNS
# NNS
# VP
# VP
# VP|<NP-PRD-,>
# VP|<NP-PRD-,>
# CD
# CD
# NP
# NP
# NP|<JJ-VBN>
# NP|<JJ-VBN>
# JJ
# JJ
# NNS
# NNS
# SBAR
# SBAR
# WHNP-7
# WHNP-7
# -NONE-
# -NONE-
# VP
# VP
# VBZ
# VBZ
# VP|<RB-VP>
# VP|<RB-VP>
# RB
# RB
# VB
# VB
# NP
# NP
# NP|<JJR-NN>
# NP|<JJR-NN>
# NN
# NN
# NN
# NN
# NP
# NP
# NP|<JJ-,>
# NP|<JJ-,>
# JJ
# JJ
# NP|<,-JJ>
# NP|<,-JJ>
# JJ
# JJ
# NNS
# NNS
# PP
# PP
# JJ
# JJ
# PP|<IN-NP>
# PP|<IN-NP>
# S
# S
# NP-SBJ-5
# NP-SBJ-5
# VBN
# VBN
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# -NONE-
# -NONE-
# NNS
# NNS
# PP
# PP
# VBG
# VBG
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NN
# NN
# NP
# NP
# NP|<NAC-NNP>
# NP|<NAC-NNP>
# NAC
# NAC
# NNP
# NNP
# NNP
# NNP
# NP-SBJ-1
# NP-SBJ-1
# RBR
# RBR
# NP-SBJ-1|<JJ-NN>
# NP-SBJ-1|<JJ-NN>
# NP-SBJ-1|<NN-NNS>
# NP-SBJ-1|<NN-NNS>
# VP
# VP
# ADJP-PRD
# ADJP-PRD
# JJ
# JJ
# VP
# VP
# ADVP-MNR
# ADVP-MNR
# RB
# RB
# VP|<VBN-NP>
# VP|<VBN-NP>
# VBN
# VBN
# NP-LGS
# NP-LGS
# NN
# NN
# VBD
# VBD
# S
# S
# IN
# IN
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NNP-NNP>
# NP-SBJ|<NNP-NNP>
# NNP
# NNP
# NP-SBJ|<NNP-NNP>
# NP-SBJ|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# JJ
# JJ
# NN
# NN
# ADJP
# ADJP
# RB
# RB
# DT
# DT
# NNS
# NNS
# S
# S
# IN
# IN
# CD
# CD
# S|<,-NP-SBJ-6>
# S|<,-NP-SBJ-6>
# S|<NP-SBJ-6-VP>
# S|<NP-SBJ-6-VP>
# NP-SBJ-6
# NP-SBJ-6
# NP
# NP
# RB
# RB
# VBG
# VBG
# JJ
# JJ
# VP
# VP
# VBN
# VBN
# -NONE-
# -NONE-
# S
# S
# NP-SBJ-7
# NP-SBJ-7
# QP
# QP
# IN
# IN
# CD
# CD
# SBAR
# SBAR
# WHNP-8
# WHNP-8
# -NONE-
# -NONE-
# VBD
# VBD
# VP
# VP
# VP|<NP-PP-DIR>
# VP|<NP-PP-DIR>
# -NONE-
# -NONE-
# VP|<PP-DIR-PP-TMP>
# VP|<PP-DIR-PP-TMP>
# NP
# NP
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# NP-SBJ|<PP-SBAR>
# NP-SBJ|<PP-SBAR>
# SBAR
# SBAR
# VP
# VP
# VP|<ADJP-PRD-SBAR-2>
# VP|<ADJP-PRD-SBAR-2>
# RB
# RB
# JJ
# JJ
# SBAR-2
# SBAR-2
# WHADVP-1
# WHADVP-1
# WRB
# WRB
# S
# S
# NP-SBJ-8
# NP-SBJ-8
# VP
# VP
# VP|<NP-ADVP-LOC>
# VP|<NP-ADVP-LOC>
# -NONE-
# -NONE-
# ADVP-LOC
# ADVP-LOC
# NNS
# NNS
# VP
# VP
# VP
# VP
# VBD
# VBD
# NP
# NP
# JJ
# JJ
# NN
# NN
# NNS
# NNS
# NP
# NP
# NP|<VBN-NN>
# NP|<VBN-NN>
# VBN
# VBN
# NN
# NN
# IN
# IN
# JJ
# JJ
# NN
# NN
# VP|<,-VP>
# VP|<,-VP>
# VP|<VP-CC>
# VP|<VP-CC>
# VP
# VP
# VBD
# VBD
# VP|<PRT-NP>
# VP|<PRT-NP>
# RP
# RP
# NP
# NP
# NN
# NN
# NP|<CC-NN>
# NP|<CC-NN>
# NN
# NN
# VP|<CC-VP+VP>
# VP|<CC-VP+VP>
# VP+VP
# VP+VP
# RB
# RB
# VP+VP|<VBD-NP>
# VP+VP|<VBD-NP>
# VBD
# VBD
# VP+VP|<NP-PP-LOC>
# VP+VP|<NP-PP-LOC>
# JJ
# JJ
# NN
# NN
# RRC+VP
# RRC+VP
# RRC+VP|<NP-S-CLR>
# RRC+VP|<NP-S-CLR>
# VBD
# VBD
# NP
# NP
# NP|<NP-PP>
# NP|<NP-PP>
# NNS
# NNS
# NP|<PP-''>
# NP|<PP-''>
# JJ
# JJ
# NN
# NN
# NP|<''-SBAR>
# NP|<''-SBAR>
# VP
# VP
# VBD
# VBD
# VP|<PP-LOC-,>
# VP|<PP-LOC-,>
# IN
# IN
# NNS
# NNS
# VP|<,-SBAR-ADV>
# VP|<,-SBAR-ADV>
# SBAR-ADV
# SBAR-ADV
# SBAR-ADV|<IN-S>
# SBAR-ADV|<IN-S>
# IN
# IN
# NP-SBJ
# NP-SBJ
# NN
# NN
# NNS
# NNS
# VBD
# VBD
# NN
# NN
# VBZ
# VBZ
# NP-PRD
# NP-PRD
# NN
# NN
# DT
# DT
# NP
# NP
# NP|<NNS-CC>
# NP|<NNS-CC>
# NP|<CC-NNS>
# NP|<CC-NNS>
# NNS
# NNS
# VBD
# VBD
# NNP
# NNP
# NNP
# NNP
# NP-SBJ|<,-NP>
# NP-SBJ|<,-NP>
# NN
# NN
# NN
# NN
# JJ
# JJ
# NNS
# NNS
# NP
# NP
# NP|<CC-NNP>
# NP|<CC-NNP>
# S
# S
# S|<CC-NP-SBJ-1>
# S|<CC-NP-SBJ-1>
# CC
# CC
# S|<NP-SBJ-1-VP>
# S|<NP-SBJ-1-VP>
# NP-SBJ-1
# NP-SBJ-1
# PRP
# PRP
# VP
# VP
# VP
# VP
# VB
# VB
# DT
# DT
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# NN
# NN
# CD
# CD
# PRP
# PRP
# NN
# NN
# NP
# NP
# NN
# NN
# NN
# NN
# NP-TMP
# NP-TMP
# NP-SBJ-1
# NP-SBJ-1
# NNS
# NNS
# NP
# NP
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<S-,>
# VP|<S-,>
# VP
# VP
# VB
# VB
# VP|<,-PP-LOC>
# VP|<,-PP-LOC>
# IN
# IN
# NP
# NP
# NNS
# NNS
# NN
# NN
# VBP
# VBP
# JJ
# JJ
# NNS
# NNS
# NN
# NN
# NNS
# NNS
# JJ
# JJ
# NP|<JJ-NN>
# NP|<JJ-NN>
# JJ
# JJ
# NN
# NN
# NN
# NN
# NP
# NP
# NP|<CD-JJ>
# NP|<CD-JJ>
# CD
# CD
# JJ
# JJ
# VBN
# VBN
# NP-LGS
# NP-LGS
# NNP
# NNP
# NP-LGS|<NNP-NNP>
# NP-LGS|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP|<NP-ADV-PP-DIR>
# VP|<NP-ADV-PP-DIR>
# NP-ADV
# NP-ADV
# NN
# NN
# NN
# NN
# VP|<PP-DIR-PP-DIR>
# VP|<PP-DIR-PP-DIR>
# NP
# NP
# CD
# CD
# NN
# NN
# CD
# CD
# NN
# NN
# VP
# VP
# VBD
# VBD
# NP-TMP
# NP-TMP
# NNP
# NNP
# NN
# NN
# NNS
# NNS
# VP
# VP
# VBP
# VBP
# UCP
# UCP
# NN
# NN
# NNS
# NNS
# UCP|<CC-SBAR>
# UCP|<CC-SBAR>
# NP-SBJ
# NP-SBJ
# NP-SBJ|<JJ-NN>
# NP-SBJ|<JJ-NN>
# JJ
# JJ
# VP
# VP
# VBZ
# VBZ
# JJ
# JJ
# NN
# NN
# NP
# NP
# NP
# NP
# NP|<NNS-POS>
# NP|<NNS-POS>
# POS
# POS
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<PP-EXT-PP-DIR>
# VP|<PP-EXT-PP-DIR>
# PP-EXT
# PP-EXT
# NN
# NN
# VP|<PP-DIR-PP>
# VP|<PP-DIR-PP>
# CD
# CD
# NNS
# NNS
# NP
# NP
# JJS
# JJS
# IN
# IN
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NP-SBJ-1
# NP-SBJ-1
# JJR
# JJR
# NNS
# NNS
# VBN
# VBN
# VP
# VP
# VB
# VB
# VP|<NP-SBAR-PRP>
# VP|<NP-SBAR-PRP>
# NP
# NP
# VBG
# VBG
# SBAR-PRP
# SBAR-PRP
# IN
# IN
# PRP
# PRP
# VBP
# VBP
# VP
# VP
# VB
# VB
# VP|<NP-PP-TMP>
# VP|<NP-PP-TMP>
# NP
# NP
# RB
# RB
# NP|<JJR-NNS>
# NP|<JJR-NNS>
# JJR
# JJR
# NN
# NN
# S
# S
# NP-SBJ-9
# NP-SBJ-9
# JJR
# JJR
# VP
# VP
# VBN
# VBN
# VP|<S-SBAR-PRP>
# VP|<S-SBAR-PRP>
# -NONE-
# -NONE-
# NN
# NN
# NP
# NP
# VBG
# VBG
# MD
# MD
# VP
# VP
# VB
# VB
# NP
# NP
# RB
# RB
# NP-SBJ
# NP-SBJ
# NP-SBJ|<PP-,>
# NP-SBJ|<PP-,>
# ADJP
# ADJP
# JJ
# JJ
# PP
# PP
# RB
# RB
# PP|<TO-NP>
# PP|<TO-NP>
# NNS
# NNS
# NP-SBJ|<,-RRC+VP>
# NP-SBJ|<,-RRC+VP>
# NP-SBJ|<RRC+VP-,>
# NP-SBJ|<RRC+VP-,>
# RRC+VP
# RRC+VP
# RRC+VP|<PP-S>
# RRC+VP|<PP-S>
# NP-LGS
# NP-LGS
# VP
# VP
# VP|<NP-PRD-SBAR-PRP>
# VP|<NP-PRD-SBAR-PRP>
# NP-PRD
# NP-PRD
# NP-PRD|<JJR-NN>
# NP-PRD|<JJR-NN>
# JJR
# JJR
# NN
# NN
# VP
# VP
# VBP
# VBP
# NN
# NN
# VBD
# VBD
# NP
# NP
# PRN
# PRN
# S-1
# S-1
# RB
# RB
# S-1|<PRN-NP-SBJ>
# S-1|<PRN-NP-SBJ>
# PRN
# PRN
# PRN|<SINV-,>
# PRN|<SINV-,>
# SINV
# SINV
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# S-1|<NP-SBJ-``>
# S-1|<NP-SBJ-``>
# S-1|<``-VP>
# S-1|<``-VP>
# S-1|<VP-.>
# S-1|<VP-.>
# MD
# MD
# VP
# VP
# VB
# VB
# VP|<ADVP-DIR-ADVP-TMP>
# VP|<ADVP-DIR-ADVP-TMP>
# ADVP-DIR
# ADVP-DIR
# VP|<ADVP-TMP-SBAR-TMP>
# VP|<ADVP-TMP-SBAR-TMP>
# RB
# RB
# VP|<SBAR-TMP-''>
# VP|<SBAR-TMP-''>
# VP
# VP
# VBP
# VBP
# RP
# RP
# VP|<''-PP-PRP>
# VP|<''-PP-PRP>
# PP-PRP
# PP-PRP
# PP-PRP|<IN-NP>
# PP-PRP|<IN-NP>
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# S
# S
# NP
# NP
# JJ
# JJ
# NNP
# NNP
# NNS
# NNS
# VP
# VP
# VP|<NP-PP-LOC>
# VP|<NP-PP-LOC>
# NP
# NP
# NNP
# NNP
# NN
# NN
# S|<,-PP>
# S|<,-PP>
# S|<PP-,>
# S|<PP-,>
# NN
# NN
# S|<,-VP>
# S|<,-VP>
# VP
# VP
# VBD
# VBD
# VP|<PP-DIR-PP-DIR>
# VP|<PP-DIR-PP-DIR>
# CD
# CD
# CD
# CD
# S
# S
# IN
# IN
# S|<,-NP-SBJ-1>
# S|<,-NP-SBJ-1>
# NP-SBJ-1
# NP-SBJ-1
# NNS
# NNS
# VBP
# VBP
# VB
# VB
# NN
# NN
# NN
# NN
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<PP-EXT-PP-TMP>
# VP|<PP-EXT-PP-TMP>
# NP
# NP
# QP
# QP
# $
# $
# QP|<CD-CD>
# QP|<CD-CD>
# CD
# CD
# -NONE-
# -NONE-
# VP|<PP-TMP-,>
# VP|<PP-TMP-,>
# IN
# IN
# NP
# NP
# NP|<JJS-NN>
# NP|<JJS-NN>
# VP|<,-PP-DIR>
# VP|<,-PP-DIR>
# CD
# CD
# S
# S
# RB
# RB
# NN
# NN
# VP
# VP
# VBP
# VBP
# JJ
# JJ
# VB
# VB
# VP
# VP
# VB
# VB
# IN
# IN
# NP
# NP
# NP|<JJS-NNS>
# NP|<JJS-NNS>
# NP-SBJ|<JJ-NN>
# NP-SBJ|<JJ-NN>
# JJ
# JJ
# NP-SBJ|<NN-NNS>
# NP-SBJ|<NN-NNS>
# VP
# VP
# VP|<ADVP-TMP-VP>
# VP|<ADVP-TMP-VP>
# RB
# RB
# VBG
# VBG
# QP
# QP
# RB
# RB
# CD
# CD
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# JJ
# JJ
# NN
# NN
# VP
# VP
# VBD
# VBD
# VP|<NP-PP-TMP>
# VP|<NP-PP-TMP>
# CD
# CD
# VP|<PP-TMP-,>
# VP|<PP-TMP-,>
# VP|<,-ADVP>
# VP|<,-ADVP>
# ADVP
# ADVP
# RB
# RB
# PP
# PP
# PP|<NP-ADVP-TMP>
# PP|<NP-ADVP-TMP>
# CD
# CD
# ADVP-TMP
# ADVP-TMP
# JJR
# JJR
# VP
# VP
# VBZ
# VBZ
# VP|<ADVP-MNR-PP-CLR>
# VP|<ADVP-MNR-PP-CLR>
# RB
# RB
# VP|<PP-CLR-ADVP-LOC>
# VP|<PP-CLR-ADVP-LOC>
# JJ
# JJ
# NNS
# NNS
# ADVP-LOC
# ADVP-LOC
# RB
# RB
# VP
# VP
# VP
# VP
# VBG
# VBG
# NN
# NN
# NNS
# NNS
# SBAR-ADV
# SBAR-ADV
# WHNP-9
# WHNP-9
# -NONE-
# -NONE-
# VBZ
# VBZ
# NP
# NP
# NP|<JJ-JJ>
# NP|<JJ-JJ>
# JJ
# JJ
# NP
# NP
# NP|<CD-NNS>
# NP|<CD-NNS>
# VP
# VP
# VP|<NP-PRD-,>
# VP|<NP-PRD-,>
# NP-PRD
# NP-PRD
# CD
# CD
# CD
# CD
# S
# S
# NP-SBJ
# NP-SBJ
# NP-SBJ|<JJ-JJ>
# NP-SBJ|<JJ-JJ>
# JJ
# JJ
# VBD
# VBD
# NP|<JJ-CD>
# NP|<JJ-CD>
# NP|<CD-NN>
# NP|<CD-NN>
# CD
# CD
# CD
# CD
# S|<:-S>
# S|<:-S>
# :
# :
# S|<S-.>
# S|<S-.>
# NP-SBJ|<JJ-NN>
# NP-SBJ|<JJ-NN>
# VBD
# VBD
# CD
# CD
# CD
# CD
# S
# S
# NP-SBJ-10
# NP-SBJ-10
# NNP
# NNP
# NNP
# NNP
# NP-SBJ-10|<,-NP>
# NP-SBJ-10|<,-NP>
# NP-SBJ-10|<NP-,>
# NP-SBJ-10|<NP-,>
# NP
# NP
# NP
# NP
# NNP
# NNP
# NP|<NNP-CC>
# NP|<NNP-CC>
# NNP
# NNP
# NP|<,-SBAR>
# NP|<,-SBAR>
# SBAR
# SBAR
# WHNP-10
# WHNP-10
# -NONE-
# -NONE-
# VBZ
# VBZ
# NP
# NP
# NP|<ADJP-NN>
# NP|<ADJP-NN>
# ADJP
# ADJP
# CD
# CD
# JJ
# JJ
# VBN
# VBN
# -NONE-
# -NONE-
# PRP
# PRP
# VBZ
# VBZ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP|<NP-,>
# NP|<NP-,>
# NP
# NP
# RB
# RB
# NP|<DT-NNP>
# NP|<DT-NNP>
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# NP|<NNP-NN>
# NP|<NNP-NN>
# SBAR
# SBAR
# WHNP-11
# WHNP-11
# -NONE-
# -NONE-
# VP
# VP
# VBD
# VBD
# NP
# NP
# NP
# NP
# NP|<NNP-POS>
# NP|<NNP-POS>
# NNP
# NNP
# NP|<CD-NN>
# NP|<CD-NN>
# CD
# CD
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# VBD
# VBD
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NP
# NP
# NP
# NP
# NP|<CD--NONE->
# NP|<CD--NONE->
# CD
# CD
# NP-ADV
# NP-ADV
# NN
# NN
# NP|<,-CC>
# NP|<,-CC>
# CC
# CC
# CD
# CD
# CD
# CD
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NN-VBG>
# NP-SBJ|<NN-VBG>
# NN
# NN
# NP-SBJ|<VBG-NN>
# NP-SBJ|<VBG-NN>
# VBG
# VBG
# VBZ
# VBZ
# VB
# VB
# JJ
# JJ
# NN
# NN
# VP|<CC-VP>
# VP|<CC-VP>
# VP|<VP-PP-TMP>
# VP|<VP-PP-TMP>
# VB
# VB
# NN
# NN
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NNP-CC>
# NP-SBJ|<NNP-CC>
# NNP
# NNP
# NP-SBJ|<CC-NNP>
# NP-SBJ|<CC-NNP>
# NNP
# NNP
# VBD
# VBD
# NN
# NN
# NP|<PP-PP>
# NP|<PP-PP>
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NNP
# NNP
# NP|<NNP-.>
# NP|<NNP-.>
# NNP
# NNP
# NP|<.-NNP>
# NP|<.-NNP>
# CD
# CD
# NP-SBJ
# NP-SBJ
# NP|<JJ-JJ>
# NP|<JJ-JJ>
# JJ
# JJ
# NP|<JJ-VBG>
# NP|<JJ-VBG>
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# NN
# NN
# NN
# NN
# NP-SBJ
# NP-SBJ
# NP-SBJ|<,-VP>
# NP-SBJ|<,-VP>
# NP-SBJ|<VP-,>
# NP-SBJ|<VP-,>
# VBN
# VBN
# NNP
# NNP
# NNP
# NNP
# JJ
# JJ
# NP|<JJ-NNS>
# NP|<JJ-NNS>
# NP|<NNS-NNS>
# NP|<NNS-NNS>
# NNS
# NNS
# NNS
# NNS
# VBZ
# VBZ
# CD
# CD
# NNS
# NNS
# JJ
# JJ
# NN
# NN
# QP
# QP
# QP|<$-CD>
# QP|<$-CD>
# CD
# CD
# JJ
# JJ
# NN
# NN
# VP
# VP
# VBD
# VBD
# NNS
# NNS
# NP
# NP
# NNS
# NNS
# NNS
# NNS
# NNP
# NNP
# VBN
# VBN
# NN
# NN
# NN
# NN
# S-TPC-1
# S-TPC-1
# IN
# IN
# VP
# VP
# VBZ
# VBZ
# S-TPC-1|<,-NP-SBJ>
# S-TPC-1|<,-NP-SBJ>
# S-TPC-1|<NP-SBJ-VP>
# S-TPC-1|<NP-SBJ-VP>
# VP
# VP
# VP|<RB-NP>
# VP|<RB-NP>
# NP
# NP
# NP|<NN-S>
# NP|<NN-S>
# NN
# NN
# VB
# VB
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# NP
# NP
# NP|<NN-POS>
# NP|<NN-POS>
# NN
# NN
# VP
# VP
# VBD
# VBD
# VP|<PP-TMP-NP-TMP>
# VP|<PP-TMP-NP-TMP>
# NN
# NN
# VP|<NP-TMP-PP-DIR>
# VP|<NP-TMP-PP-DIR>
# CD
# CD
# CD
# CD
# CD
# CD
# S
# S
# NP-SBJ-11
# NP-SBJ-11
# NN
# NN
# WHNP-1
# WHNP-1
# VB
# VB
# VBN
# VBN
# -NONE-
# -NONE-
# NN
# NN
# VBG
# VBG
# JJ
# JJ
# NNS
# NNS
# S
# S
# NP-SBJ-1
# NP-SBJ-1
# NNP
# NNP
# VBN
# VBN
# VB
# VB
# CD
# CD
# S|<,-CC>
# S|<,-CC>
# S|<CC-S>
# S|<CC-S>
# CC
# CC
# NP-SBJ-2
# NP-SBJ-2
# NNP
# NNP
# VP
# VP
# VB
# VB
# VP|<PP-TMP-PP-TMP>
# VP|<PP-TMP-PP-TMP>
# IN
# IN
# JJ
# JJ
# JJS
# JJS
# VP
# VP
# VB
# VB
# VP|<PP-TMP-SBAR-ADV>
# VP|<PP-TMP-SBAR-ADV>
# NP
# NP
# IN
# IN
# VP
# VP
# NP
# NP
# RB
# RB
# S
# S
# NP-SBJ-12
# NP-SBJ-12
# NNP
# NNP
# NP-SBJ-12|<NNP-NNP>
# NP-SBJ-12|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# -NONE-
# -NONE-
# NP-PRD
# NP-PRD
# NP
# NP
# JJ
# JJ
# PP
# PP
# -NONE-
# -NONE-
# NP-PRD|<CC-NP>
# NP-PRD|<CC-NP>
# NP-PRD|<NP-PP-1>
# NP-PRD|<NP-PP-1>
# JJ
# JJ
# NN
# NN
# PP-1
# PP-1
# NP|<NNP-NNS>
# NP|<NNP-NNS>
# NP|<NNS-CC>
# NP|<NNS-CC>
# NP|<CC-NN>
# NP|<CC-NN>
# NN
# NN
# NN
# NN
# JJ
# JJ
# NP|<NN-NN>
# NP|<NN-NN>
# NN
# NN
# NP|<NN-NNP>
# NP|<NN-NNP>
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# S
# S
# NN
# NN
# VB
# VB
# NP
# NP
# NP|<NNP-NNS>
# NP|<NNP-NNS>
# NP|<NNS-,>
# NP|<NNS-,>
# NP|<,-NN>
# NP|<,-NN>
# NP|<NN-,>
# NP|<NN-,>
# NN
# NN
# NP|<,-NNS>
# NP|<,-NNS>
# NNS
# NNS
# S
# S
# RB
# RB
# CD
# CD
# VP
# VP
# NP
# NP
# NNP
# NNP
# NP|<NNP-NN>
# NP|<NNP-NN>
# NN
# NN
# VP
# VP
# VBN
# VBN
# VP|<NP-PRD-PP-TMP>
# VP|<NP-PRD-PP-TMP>
# NN
# NN
# CD
# CD
# S
# S
# SBAR-TMP
# SBAR-TMP
# WRB
# WRB
# VP
# VP
# VP|<NP-PRD-ADVP-TMP>
# VP|<NP-PRD-ADVP-TMP>
# NN
# NN
# NP
# NP
# PRP$
# PRP$
# JJ
# JJ
# NN
# NN
# ADVP-TMP
# ADVP-TMP
# S|<,-NP-SBJ>
# S|<,-NP-SBJ>
# S|<NP-SBJ-ADVP>
# S|<NP-SBJ-ADVP>
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP-SBJ|<VBG-NNS>
# NP-SBJ|<VBG-NNS>
# VBG
# VBG
# NNS
# NNS
# S|<ADVP-VP>
# S|<ADVP-VP>
# RB
# RB
# VP
# VP
# VBP
# VBP
# VP|<PRT-PP-DIR>
# VP|<PRT-PP-DIR>
# RP
# RP
# JJ
# JJ
# NNS
# NNS
# NN
# NN
# NNS
# NNS
# IN
# IN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# FRAG
# FRAG
# RB
# RB
# FRAG|<NP-TMP-.>
# FRAG|<NP-TMP-.>
# NP-TMP
# NP-TMP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP|<PP-CLR-PP>
# VP|<PP-CLR-PP>
# NP
# NP
# NNP
# NNP
# NN
# NN
# NNP
# NNP
# NP|<NN-NN>
# NP|<NN-NN>
# NN
# NN
# NN
# NN
# S
# S
# CC
# CC
# NP-SBJ-1
# NP-SBJ-1
# NN
# NN
# VBD
# VBD
# VP
# VP
# VB
# VB
# VP|<NP-PP-MNR>
# VP|<NP-PP-MNR>
# NNS
# NNS
# PP-MNR
# PP-MNR
# PP
# PP
# ADVP
# ADVP
# JJR
# JJR
# NN
# NN
# NN
# NN
# NNS
# NNS
# NNS
# NNS
# FRAG
# FRAG
# NN
# NN
# FRAG|<,-PP>
# FRAG|<,-PP>
# FRAG|<PP-:>
# FRAG|<PP-:>
# NN
# NN
# FRAG|<:-S>
# FRAG|<:-S>
# :
# :
# FRAG|<S-.>
# FRAG|<S-.>
# VP
# VP
# VB
# VB
# VP|<PP-CLR-SBAR>
# VP|<PP-CLR-SBAR>
# NP
# NP
# CD
# CD
# NP|<JJ-NN>
# NP|<JJ-NN>
# JJ
# JJ
# NN
# NN
# NNS
# NNS
# SBAR
# SBAR
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VP|<RB-ADJP-PRD>
# VP|<RB-ADJP-PRD>
# VP|<ADJP-PRD-PP>
# VP|<ADJP-PRD-PP>
# RB
# RB
# JJ
# JJ
# SBAR|<,-SBAR>
# SBAR|<,-SBAR>
# JJ
# JJ
# SBAR
# SBAR
# WHADVP-1
# WHADVP-1
# SBAR|<IN-S>
# SBAR|<IN-S>
# VP
# VP
# VB
# VB
# SINV
# SINV
# PP-LOC-PRD-TPC-1
# PP-LOC-PRD-TPC-1
# IN
# IN
# NP
# NP
# VBG
# VBG
# NN
# NN
# NN
# NN
# PP-LOC-PRD
# PP-LOC-PRD
# NNS
# NNS
# NP
# NP
# NNS
# NNS
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP|<,-CONJP>
# NP|<,-CONJP>
# NP|<CONJP-NP>
# NP|<CONJP-NP>
# CONJP
# CONJP
# IN
# IN
# JJR
# JJR
# NNS
# NNS
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# S
# S
# IN
# IN
# NNS
# NNS
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP-SBJ|<CC-NN>
# NP-SBJ|<CC-NN>
# NN
# NN
# VBD
# VBD
# S
# S
# NP-TMP
# NP-TMP
# NP-TMP|<JJ-NN>
# NP-TMP|<JJ-NN>
# NN
# NN
# S|<PP-,>
# S|<PP-,>
# NN
# NN
# NN
# NN
# NNS
# NNS
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<PP-DIR-,>
# VP|<PP-DIR-,>
# NNP
# NNP
# VP|<,-S-ADV>
# VP|<,-S-ADV>
# S-ADV
# S-ADV
# JJ
# JJ
# NN
# NN
# JJ
# JJ
# NNS
# NNS
# S
# S
# NN
# NN
# VP
# VP
# MD
# MD
# S|<,-IN>
# S|<,-IN>
# S|<IN-S>
# S|<IN-S>
# IN
# IN
# NN
# NN
# VBD
# VBD
# JJ
# JJ
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<NN-NN>
# NP-SBJ-1|<NN-NN>
# NN
# NN
# NN
# NN
# VBN
# VBN
# VP|<NP-PP-LOC>
# VP|<NP-PP-LOC>
# VP|<PP-LOC-,>
# VP|<PP-LOC-,>
# NN
# NN
# VP|<,-SBAR-LOC>
# VP|<,-SBAR-LOC>
# SBAR-LOC
# SBAR-LOC
# WHADVP-3
# WHADVP-3
# NP-SBJ-2
# NP-SBJ-2
# NN
# NN
# NP-SBJ-2|<CC-NNS>
# NP-SBJ-2|<CC-NNS>
# NNS
# NNS
# VBN
# VBN
# VP|<NP-PP>
# VP|<NP-PP>
# VP|<PP-ADVP-LOC>
# VP|<PP-ADVP-LOC>
# JJ
# JJ
# NNS
# NNS
# S
# S
# RB
# RB
# S|<PP-,>
# S|<PP-,>
# NN
# NN
# NN
# NN
# VBD
# VBD
# VP|<PRT-NP>
# VP|<PRT-NP>
# RP
# RP
# VP|<NP-PP-PRP>
# VP|<NP-PP-PRP>
# CD
# CD
# NNS
# NNS
# NNS
# NNS
# NP
# NP
# NP|<DT-JJ>
# NP|<DT-JJ>
# NP|<JJ-NNP>
# NP|<JJ-NNP>
# JJ
# JJ
# NP|<NNP-CD>
# NP|<NNP-CD>
# CD
# CD
# NN
# NN
# PP-PRP
# PP-PRP
# JJ
# JJ
# NN
# NN
# NN
# NN
# IN
# IN
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NP-SBJ|<CD-NNS>
# NP-SBJ|<CD-NNS>
# VP
# VP
# VBD
# VBD
# VP|<PP-MNR-PP-CLR>
# VP|<PP-MNR-PP-CLR>
# PP-MNR
# PP-MNR
# NNS
# NNS
# NNS
# NNS
# S
# S
# S-ADV
# S-ADV
# NP-PRD
# NP-PRD
# DT
# DT
# NNS
# NNS
# NP-SBJ-1
# NP-SBJ-1
# VP
# VP
# VBD
# VBD
# VP|<PRT-SBAR>
# VP|<PRT-SBAR>
# S
# S
# S|<ADVP-VP>
# S|<ADVP-VP>
# RB
# RB
# NN
# NN
# NNS
# NNS
# DT
# DT
# NN
# NN
# NN
# NN
# CD
# CD
# S
# S
# ADVP-LOC
# ADVP-LOC
# RB
# RB
# NN
# NN
# NNS
# NNS
# VBD
# VBD
# VP|<PRT-NP>
# VP|<PRT-NP>
# NNS
# NNS
# NN
# NN
# PP-TMP
# PP-TMP
# VP
# VP
# VBG
# VBG
# VP|<NP-ADVP>
# VP|<NP-ADVP>
# NNS
# NNS
# S
# S
# VP
# VP
# NP
# NP
# NN
# NN
# NP|<CC-NN>
# NP|<CC-NN>
# NN
# NN
# NP|<:-ADVP-LOC>
# NP|<:-ADVP-LOC>
# ADVP-LOC
# ADVP-LOC
# NN
# NN
# RB
# RB
# IN
# IN
# NNS
# NNS
# NP
# NP
# NP|<VBN-NNP>
# NP|<VBN-NNP>
# VBN
# VBN
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# CD
# CD
# JJS
# JJS
# NNS
# NNS
# NN
# NN
# VP
# VP
# VBD
# VBD
# VP|<NP-NP>
# VP|<NP-NP>
# PRP
# PRP
# NP
# NP
# NN
# NN
# NN
# NN
# NP|<NP-,>
# NP|<NP-,>
# NN
# NN
# NN
# NN
# NN
# NN
# NN
# NN
# JJ
# JJ
# NN
# NN
# NN
# NN
# NN
# NN
# S
# S
# S-ADV
# S-ADV
# VP
# VP
# VBG
# VBG
# VP|<NP-SBAR-TMP>
# VP|<NP-SBAR-TMP>
# ADJP
# ADJP
# JJ
# JJ
# PRN
# PRN
# PRN|<CC-JJ>
# PRN|<CC-JJ>
# PRN|<JJ-:>
# PRN|<JJ-:>
# JJ
# JJ
# NN
# NN
# WRB
# WRB
# VP
# VP
# VBP
# VBP
# S|<,-NP-SBJ-2>
# S|<,-NP-SBJ-2>
# S|<NP-SBJ-2-VP>
# S|<NP-SBJ-2-VP>
# NP-SBJ-2
# NP-SBJ-2
# VBD
# VBD
# JJ
# JJ
# NN
# NN
# NP
# NP
# JJR
# JJR
# NNS
# NNS
# VBP
# VBP
# JJ
# JJ
# NN
# NN
# VBZ
# VBZ
# VP
# VP
# VB
# VB
# VP|<PP-DIR-PP-PRP>
# VP|<PP-DIR-PP-PRP>
# NN
# NN
# JJ
# JJ
# S
# S
# S|<PP-TMP-,>
# S|<PP-TMP-,>
# PP-TMP
# PP-TMP
# VP
# VP
# VBG
# VBG
# VP|<ADVP-CLR-PP-CLR>
# VP|<ADVP-CLR-PP-CLR>
# ADVP-CLR
# ADVP-CLR
# RB
# RB
# NN
# NN
# PRN
# PRN
# PRN|<NP-LOC-PP-TMP>
# PRN|<NP-LOC-PP-TMP>
# NP-LOC
# NP-LOC
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VBD
# VBD
# NN
# NN
# NN
# NN
# CD
# CD
# VP|<PP-TMP-,>
# VP|<PP-TMP-,>
# NNP
# NNP
# VP|<,-S-ADV>
# VP|<,-S-ADV>
# VP|<S-ADV-,>
# VP|<S-ADV-,>
# VBG
# VBG
# NP
# NP
# NN
# NN
# JJ
# JJ
# NN
# NN
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<NP-NP-TMP>
# VP|<NP-NP-TMP>
# NNP
# NNP
# JJ
# JJ
# NNS
# NNS
# NP
# NP
# NNP
# NNP
# NP|<CC-NNP>
# NP|<CC-NNP>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP|<NP-,>
# VP|<NP-,>
# JJ
# JJ
# JJ
# JJ
# NN
# NN
# VP
# VP
# VBG
# VBG
# NN
# NN
# JJ
# JJ
# NN
# NN
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<PP-LOC-CLR-SBAR-TMP>
# VP|<PP-LOC-CLR-SBAR-TMP>
# CD
# CD
# ADJP
# ADJP
# QP
# QP
# QP|<JJ-CD>
# QP|<JJ-CD>
# JJ
# JJ
# CD
# CD
# NN
# NN
# NP
# NP
# NP|<NN-JJR>
# NP|<NN-JJR>
# IN
# IN
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<ADVP-MNR-PP-DIR>
# VP|<ADVP-MNR-PP-DIR>
# RB
# RB
# NP
# NP
# CD
# CD
# NP|<,-ADVP>
# NP|<,-ADVP>
# ADVP
# ADVP
# RB
# RB
# ADVP|<NP-PP-TMP>
# ADVP|<NP-PP-TMP>
# JJ
# JJ
# NN
# NN
# SBAR
# SBAR
# WHNP-12
# WHNP-12
# -NONE-
# -NONE-
# VP
# VP
# VBD
# VBD
# CD
# CD
# VP
# VP
# VP|<NP-TMP-PP-PRP>
# VP|<NP-TMP-PP-PRP>
# NP
# NP
# VBN
# VBN
# NN
# NN
# NNS
# NNS
# NNS
# NNS
# JJ
# JJ
# NNS
# NNS
# NN
# NN
# MD
# MD
# VP
# VP
# VB
# VB
# NN
# NN
# CD
# CD
# JJ
# JJ
# NN
# NN
# VBN
# VBN
# VP|<NP-ADVP-TMP>
# VP|<NP-ADVP-TMP>
# NN
# NN
# CD
# CD
# VP|<ADVP-TMP-NP-TMP>
# VP|<ADVP-TMP-NP-TMP>
# ADVP-TMP
# ADVP-TMP
# IN
# IN
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NP-SBJ|<VBN-NNS>
# NP-SBJ|<VBN-NNS>
# VBN
# VBN
# VP
# VP
# VP|<NP-EXT-PP-TMP>
# VP|<NP-EXT-PP-TMP>
# NP-EXT
# NP-EXT
# CD
# CD
# VP|<PP-TMP-PP-DIR>
# VP|<PP-TMP-PP-DIR>
# NP|<JJ-NN>
# NP|<JJ-NN>
# JJ
# JJ
# NP|<NN-JJ>
# NP|<NN-JJ>
# CD
# CD
# NNS
# NNS
# VP
# VP
# VP|<PP-LOC-PRD-,>
# VP|<PP-LOC-PRD-,>
# PP-LOC-PRD
# PP-LOC-PRD
# NP+NP
# NP+NP
# CD
# CD
# ADVP
# ADVP
# CD
# CD
# S
# S
# NP-SBJ-1
# NP-SBJ-1
# NNP
# NNP
# S|<,-S>
# S|<,-S>
# S|<S-,>
# S|<S-,>
# NP-SBJ-2
# NP-SBJ-2
# VP
# VP
# VBG
# VBG
# VP
# VP
# VB
# VB
# VP|<NP-CLR-PP-CLR>
# VP|<NP-CLR-PP-CLR>
# NP-CLR
# NP-CLR
# NN
# NN
# NP
# NP
# NP
# NP
# JJ
# JJ
# NP
# NP
# NNP
# NNP
# NN
# NN
# VBD
# VBD
# NN
# NN
# CD
# CD
# VB
# VB
# NN
# NN
# NN
# NN
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# JJ
# JJ
# VP
# VP
# VBN
# VBN
# VP|<NP-NP>
# VP|<NP-NP>
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# SBAR
# SBAR
# WHNP-13
# WHNP-13
# -NONE-
# -NONE-
# VP
# VP
# VBP
# VBP
# NNS
# NNS
# VP
# VP
# VBG
# VBG
# VP|<CC-VBG>
# VP|<CC-VBG>
# VP|<VBG-NP>
# VP|<VBG-NP>
# VBG
# VBG
# NN
# NN
# VP
# VP
# VBN
# VBN
# NP-PRD
# NP-PRD
# JJ
# JJ
# NNS
# NNS
# NN
# NN
# NNS
# NNS
# VBP
# VBP
# JJ
# JJ
# NN
# NN
# IN
# IN
# NP|<NP-,>
# NP|<NP-,>
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NNP
# NNP
# NP-SBJ|<,-RRC>
# NP-SBJ|<,-RRC>
# NP-SBJ|<RRC-,>
# NP-SBJ|<RRC-,>
# NP-PRD
# NP-PRD
# NP-SBJ
# NP-SBJ
# VP
# VP
# VB
# VB
# VP|<NP-EXT-PP-TMP>
# VP|<NP-EXT-PP-TMP>
# CD
# CD
# NP-SBJ
# NP-SBJ
# JJ
# JJ
# NP|<,-JJ>
# NP|<,-JJ>
# JJ
# JJ
# NN
# NN
# VB
# VB
# CD
# CD
# S
# S
# NNP
# NNP
# S|<NP-SBJ-1-VP>
# S|<NP-SBJ-1-VP>
# NP-SBJ-1
# NP-SBJ-1
# VP
# VP
# VBD
# VBD
# NP
# NP
# NP|<VBN-NN>
# NP|<VBN-NN>
# VBN
# VBN
# NN
# NN
# NN
# NN
# VP
# VP
# RB
# RB
# S|<:-S>
# S|<:-S>
# S|<S-:>
# S|<S-:>
# NP|<JJR-NN>
# NP|<JJR-NN>
# JJR
# JJR
# S|<NP-SBJ-VP>
# S|<NP-SBJ-VP>
# NP
# NP
# VP
# VP
# VP|<ADVP-ADJP-PRD>
# VP|<ADVP-ADJP-PRD>
# RB
# RB
# VP|<ADJP-PRD-PP-2>
# VP|<ADJP-PRD-PP-2>
# ADJP-PRD
# ADJP-PRD
# NP-ADV
# NP-ADV
# CD
# CD
# PP-2
# PP-2
# IN
# IN
# NN
# NN
# VBZ
# VBZ
# QP|<$-CD>
# QP|<$-CD>
# CD
# CD
# NP-SBJ-1
# NP-SBJ-1
# VP
# VP
# VP|<ADVP-TMP-S>
# VP|<ADVP-TMP-S>
# RB
# RB
# VB
# VB
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBZ
# VBZ
# VP|<NP-PP-DIR>
# VP|<NP-PP-DIR>
# NNS
# NNS
# VP|<PP-DIR-PP-2>
# VP|<PP-DIR-PP-2>
# PP-2
# PP-2
# PP-2|<``-NP>
# PP-2|<``-NP>
# NN
# NN
# VP
# VP
# VB
# VB
# VP|<PP-MNR-NP>
# VP|<PP-MNR-NP>
# PP-MNR
# PP-MNR
# PP-MNR|<``-NP>
# PP-MNR|<``-NP>
# PP-MNR|<NP-''>
# PP-MNR|<NP-''>
# NNS
# NNS
# VP|<NP-,>
# VP|<NP-,>
# WHNP-1
# WHNP-1
# S
# S
# VP
# VP
# VBP
# VBP
# VP|<CC-VBP>
# VP|<CC-VBP>
# VP|<VBP-NP>
# VP|<VBP-NP>
# VBP
# VBP
# CD
# CD
# VP|<,-ADVP-TMP>
# VP|<,-ADVP-TMP>
# ADVP
# ADVP
# RB
# RB
# RB
# RB
# VP
# VP
# VBD
# VBD
# VP|<NP-2-PP-TMP-3>
# VP|<NP-2-PP-TMP-3>
# NP-2
# NP-2
# NP-2|<CD--NONE->
# NP-2|<CD--NONE->
# CD
# CD
# PP-TMP-3
# PP-TMP-3
# VP
# VP
# NP=2
# NP=2
# NP=2|<CD--NONE->
# NP=2|<CD--NONE->
# CD
# CD
# PP-TMP=3
# PP-TMP=3
# VP
# VP
# VP|<RB-NP-PRD>
# VP|<RB-NP-PRD>
# NP-PRD
# NP-PRD
# NP-PRD|<NN-S>
# NP-PRD|<NN-S>
# NN
# NN
# VP
# VP
# VB
# VB
# NP
# NP
# NN
# NN
# NP|<PP-LOC-PP-TMP>
# NP|<PP-LOC-PP-TMP>
# NNS
# NNS
# NP|<JJ-CD>
# NP|<JJ-CD>
# JJ
# JJ
# NNS
# NNS
# VBD
# VBD
# CD
# CD
# NP
# NP
# NN
# NN
# NP|<PP-PP-DIR>
# NP|<PP-PP-DIR>
# CD
# CD
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# S-TPC-1
# S-TPC-1
# S
# S
# SBAR-NOM-SBJ
# SBAR-NOM-SBJ
# WHNP-14
# WHNP-14
# WP
# WP
# -NONE-
# -NONE-
# VBZ
# VBZ
# VP
# VP
# SBAR-NOM-PRD
# SBAR-NOM-PRD
# WHNP-15
# WHNP-15
# WP
# WP
# VP
# VP
# VBG
# VBG
# -NONE-
# -NONE-
# S-TPC-1|<,-CC>
# S-TPC-1|<,-CC>
# S-TPC-1|<CC-S>
# S-TPC-1|<CC-S>
# DT
# DT
# NN
# NN
# PRP
# PRP
# VP
# VP
# VBG
# VBG
# VP|<ADVP-MNR-NP-TMP>
# VP|<ADVP-MNR-NP-TMP>
# RB
# RB
# DT
# DT
# VP
# VP
# VP
# VP
# VBG
# VBG
# VP|<NP-PP-TMP>
# VP|<NP-PP-TMP>
# VP|<PP-TMP-PP-MNR>
# VP|<PP-TMP-PP-MNR>
# IN
# IN
# JJ
# JJ
# NN
# NN
# NP
# NP
# JJ
# JJ
# NNS
# NNS
# NP|<PP-DIR-,>
# NP|<PP-DIR-,>
# NNS
# NNS
# NP|<,-PP>
# NP|<,-PP>
# NP
# NP
# NNS
# NNS
# NNS
# NNS
# RB
# RB
# NN
# NN
# JJ
# JJ
# VBD
# VBD
# NNS
# NNS
# VBG
# VBG
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NP|<JJS-RB>
# NP|<JJS-RB>
# JJS
# JJS
# RB
# RB
# CD
# CD
# NN
# NN
# CD
# CD
# CD
# CD
# VP|<NP-PRD-,>
# VP|<NP-PRD-,>
# NP-PRD
# NP-PRD
# CD
# CD
# ADJP-PRD
# ADJP-PRD
# JJ
# JJ
# CD
# CD
# CD
# CD
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<NNP-NNP>
# NP-SBJ-1|<NNP-NNP>
# NP-SBJ-1|<NNP-NNP>
# NP-SBJ-1|<NNP-NNP>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP|<ADVP-DIR-CLR-PP-CLR>
# VP|<ADVP-DIR-CLR-PP-CLR>
# ADVP-DIR-CLR
# ADVP-DIR-CLR
# IN
# IN
# VP|<PP-CLR-,>
# VP|<PP-CLR-,>
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBG
# VBG
# S
# S
# NNS
# NNS
# VP
# VP
# ADJP-PRD-3
# ADJP-PRD-3
# RB
# RB
# ADJP-PRD-3|<JJ-S>
# ADJP-PRD-3|<JJ-S>
# -NONE-
# -NONE-
# S|<CC-S>
# S|<CC-S>
# S|<S-S-4>
# S|<S-S-4>
# S
# S
# NP-SBJ=2
# NP-SBJ=2
# NP-SBJ=2|<JJ-NN>
# NP-SBJ=2|<JJ-NN>
# JJ
# JJ
# NN
# NN
# ADVP-PRD-LOC=3
# ADVP-PRD-LOC=3
# ADVP-PRD-LOC=3|<RB-PP-LOC>
# ADVP-PRD-LOC=3|<RB-PP-LOC>
# ADVP-PRD-LOC=3|<PP-LOC-S>
# ADVP-PRD-LOC=3|<PP-LOC-S>
# NN
# NN
# S-4
# S-4
# VB
# VB
# NN
# NN
# NN
# NN
# VP
# VP
# VBZ
# VBZ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NP|<VBG-JJ>
# NP|<VBG-JJ>
# JJ
# JJ
# NNS
# NNS
# NNP
# NNP
# RB
# RB
# VBN
# VBN
# NP
# NP
# JJ
# JJ
# NN
# NN
# NP|<PP-LOC-SBAR>
# NP|<PP-LOC-SBAR>
# NP
# NP
# NN
# NN
# CD
# CD
# NN
# NN
# NNS
# NNS
# SBAR
# SBAR
# WHPP-2
# WHPP-2
# WHNP
# WHNP
# VP
# VP
# JJ
# JJ
# PP-LOC
# PP-LOC
# S
# S
# NP-SBJ-4
# NP-SBJ-4
# NP-SBJ-4|<,-VP>
# NP-SBJ-4|<,-VP>
# NP-SBJ-4|<VP-,>
# NP-SBJ-4|<VP-,>
# NNP
# NNP
# VP
# VP
# VP|<NP-S-PRP>
# VP|<NP-S-PRP>
# CD
# CD
# VP|<S-PRP-,>
# VP|<S-PRP-,>
# S-PRP
# S-PRP
# VB
# VB
# VP|<,-PP-1>
# VP|<,-PP-1>
# PP-1
# PP-1
# PP-1|<IN-NP>
# PP-1|<IN-NP>
# IN
# IN
# ADJP
# ADJP
# CD
# CD
# NN
# NN
# WHNP-2
# WHNP-2
# VP
# VP
# NNS
# NNS
# NN
# NN
# NP
# NP
# NP|<QP--NONE->
# NP|<QP--NONE->
# CD
# CD
# WHNP-3
# WHNP-3
# VP
# VP
# VBZ
# VBZ
# NP-SBJ
# NP-SBJ
# VP
# VP
# ADJP-PRD
# ADJP-PRD
# IN
# IN
# S
# S
# NP-SBJ-13
# NP-SBJ-13
# -NONE-
# -NONE-
# NNP
# NNP
# NNP
# NNP
# S
# S
# NP-SBJ-14
# NP-SBJ-14
# -NONE-
# -NONE-
# NNP
# NNP
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NP-SBJ|<,-NP-LOC>
# NP-SBJ|<,-NP-LOC>
# NP-SBJ|<NP-LOC-,>
# NP-SBJ|<NP-LOC-,>
# NP-LOC
# NP-LOC
# NNP
# NNP
# NP-LOC|<,-NP>
# NP-LOC|<,-NP>
# NNP
# NNP
# VBZ
# VBZ
# CD
# CD
# NNP
# NNP
# NNP
# NNP
# NP|<CC-NP>
# NP|<CC-NP>
# NP|<NP-PP-1>
# NP|<NP-PP-1>
# NP
# NP
# JJ
# JJ
# JJ
# JJ
# NN
# NN
# NN
# NN
# NN
# NN
# VP
# VP
# VB
# VB
# S|<CC-S>
# S|<CC-S>
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# NP-SBJ|<VP-PRN>
# NP-SBJ|<VP-PRN>
# VBN
# VBN
# PRN
# PRN
# PRN|<PP-:>
# PRN|<PP-:>
# NN
# NN
# NN
# NN
# NN
# NN
# VBN
# VBN
# NN
# NN
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP
# VP
# VB
# VB
# JJ
# JJ
# S
# S
# S|<SBAR-TMP-,>
# S|<SBAR-TMP-,>
# NP-SBJ-2
# NP-SBJ-2
# VP
# VP
# VBD
# VBD
# VP|<S-ADVP-TMP>
# VP|<S-ADVP-TMP>
# VBG
# VBG
# S|<S-,>
# S|<S-,>
# VP
# VP
# VBD
# VBD
# VP|<ADJP-PRD-PP-TMP>
# VP|<ADJP-PRD-PP-TMP>
# ADJP-PRD
# ADJP-PRD
# JJ
# JJ
# ADJP-PRD|<CC-JJ>
# ADJP-PRD|<CC-JJ>
# JJ
# JJ
# NNS
# NNS
# VP
# VP
# ADVP-LOC-PRD
# ADVP-LOC-PRD
# JJ
# JJ
# NN
# NN
# S
# S
# NP-SBJ
# NP-SBJ
# WDT
# WDT
# VBD
# VBD
# ADJP-PRD
# ADJP-PRD
# RB
# RB
# VB
# VB
# S|<,-''>
# S|<,-''>
# S|<''-NP-SBJ>
# S|<''-NP-SBJ>
# VBD
# VBD
# VBD
# VBD
# NP-SBJ
# NP-SBJ
# JJ
# JJ
# NNS
# NNS
# VBN
# VBN
# S-TPC-1
# S-TPC-1
# ADVP
# ADVP
# ADVP|<NN-SBAR-NOM>
# ADVP|<NN-SBAR-NOM>
# NN
# NN
# SBAR-NOM
# SBAR-NOM
# WHNP-16
# WHNP-16
# -NONE-
# -NONE-
# VBZ
# VBZ
# S-TPC-1|<,-SBAR-TMP>
# S-TPC-1|<,-SBAR-TMP>
# S-TPC-1|<SBAR-TMP-NP-SBJ>
# S-TPC-1|<SBAR-TMP-NP-SBJ>
# VP
# VP
# VBZ
# VBZ
# NP-SBJ
# NP-SBJ
# VP
# VP
# S
# S
# S|<NP-SBJ-VP>
# S|<NP-SBJ-VP>
# DT
# DT
# S|<VP-:>
# S|<VP-:>
# VBZ
# VBZ
# :
# :
# S
# S
# S-1
# S-1
# NP
# NP
# RB
# RB
# NP|<DT-CD>
# NP|<DT-CD>
# NP
# NP
# NNS
# NNS
# SBAR
# SBAR
# WHNP-17
# WHNP-17
# -NONE-
# -NONE-
# VP
# VP
# PP-DIR-CLR
# PP-DIR-CLR
# NP
# NP
# VP
# VP
# VB
# VB
# PP-DIR-CLR
# PP-DIR-CLR
# S
# S
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# JJ
# JJ
# NN
# NN
# NP
# NP
# NP|<JJ-NN>
# NP|<JJ-NN>
# JJ
# JJ
# NNS
# NNS
# NN
# NN
# MD
# MD
# VB
# VB
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NN-SBAR>
# NP-SBJ|<NN-SBAR>
# NN
# NN
# VBD
# VBD
# NP
# NP
# NNS
# NNS
# PRN
# PRN
# PRN|<NP-PP-DIR>
# PRN|<NP-PP-DIR>
# NP
# NP
# CD
# CD
# NP|<NN--NONE->
# NP|<NN--NONE->
# PRN|<PP-DIR-:>
# PRN|<PP-DIR-:>
# IN
# IN
# IN
# IN
# CD
# CD
# NNS
# NNS
# NP-LGS
# NP-LGS
# NP-LGS|<JJ-CD>
# NP-LGS|<JJ-CD>
# NP-LGS|<CD-JJ>
# NP-LGS|<CD-JJ>
# NP-LGS|<JJ-NNS>
# NP-LGS|<JJ-NNS>
# VP
# VP
# IN
# IN
# NNS
# NNS
# NN
# NN
# VBD
# VBD
# S
# S
# S|<S-TPC-1-,>
# S|<S-TPC-1-,>
# S-TPC-1
# S-TPC-1
# RB
# RB
# NN
# NN
# ADJP-PRD
# ADJP-PRD
# RBR
# RBR
# VBN
# VBN
# RB
# RB
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP|<PRT-PP-TMP>
# VP|<PRT-PP-TMP>
# VP|<PP-TMP-NP>
# VP|<PP-TMP-NP>
# NP
# NP
# NN
# NN
# NP|<PP-VP>
# NP|<PP-VP>
# VBG
# VBG
# JJ
# JJ
# NN
# NN
# VB
# VB
# VP|<CC-VP>
# VP|<CC-VP>
# VP|<VP-SBAR-PRP>
# VP|<VP-SBAR-PRP>
# VP
# VP
# VP|<VBZ-PP-CLR>
# VP|<VBZ-PP-CLR>
# VBZ
# VBZ
# VBN
# VBN
# NN
# NN
# NP
# NP
# NNP
# NNP
# SBAR-PRP
# SBAR-PRP
# SBAR-PRP|<IN-S>
# SBAR-PRP|<IN-S>
# VP|<NP-PP-TMP>
# VP|<NP-PP-TMP>
# NN
# NN
# NP-PRD
# NP-PRD
# NN
# NN
# NP-LGS
# NP-LGS
# NP-LGS|<NN-NN>
# NP-LGS|<NN-NN>
# NN
# NN
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# VP
# VP
# VBD
# VBD
# VP|<NP-TMP-PP-CLR>
# VP|<NP-TMP-PP-CLR>
# NN
# NN
# VP|<PP-CLR-PP-LOC>
# VP|<PP-CLR-PP-LOC>
# NP
# NP
# CD
# CD
# NP|<,-PP-DIR>
# NP|<,-PP-DIR>
# NP|<PP-DIR-,>
# NP|<PP-DIR-,>
# IN
# IN
# CD
# CD
# NNS
# NNS
# NNP
# NNP
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# NNP
# NNP
# NP|<NNP-JJ>
# NP|<NNP-JJ>
# NNP
# NNP
# JJ
# JJ
# NN
# NN
# S
# S
# NP-SBJ-15
# NP-SBJ-15
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NP|<,-UCP>
# NP|<,-UCP>
# CD
# CD
# NP
# NP
# NX
# NX
# NX
# NX
# NX|<CC-NX>
# NX|<CC-NX>
# NX
# NX
# NN
# NN
# NX|<VBG-NN>
# NX|<VBG-NN>
# VBG
# VBG
# NP
# NP
# NNPS
# NNPS
# NP|<``-NNP>
# NP|<``-NNP>
# NP|<NNP-''>
# NP|<NNP-''>
# NNP
# NNP
# NP|<''-NNP>
# NP|<''-NNP>
# NNP
# NNP
# NP-SBJ-15|<,-CC>
# NP-SBJ-15|<,-CC>
# NP-SBJ-15|<CC-NP>
# NP-SBJ-15|<CC-NP>
# NP-SBJ-15|<NP-,>
# NP-SBJ-15|<NP-,>
# NNP
# NNP
# NNP
# NNP
# CD
# CD
# NNP
# NNP
# NNP
# NNP
# -NONE-
# -NONE-
# NNS
# NNS
# NP|<NN-NNS>
# NP|<NN-NNS>
# NN
# NN
# NNS
# NNS
# NP|<CC-NNS>
# NP|<CC-NNS>
# NP|<NNS-NN>
# NP|<NNS-NN>
# NNS
# NNS
# NN
# NN
# NN
# NN
# PRP
# PRP
# VP
# VP
# VBP
# VBP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# VBN
# VBN
# NNP
# NNP
# NNP
# NNP
# NP|<CC-NP>
# NP|<CC-NP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NN
# NN
# JJ
# JJ
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBN
# VBN
# VP|<NP-2-S>
# VP|<NP-2-S>
# NP-2
# NP-2
# VP
# VP
# VB
# VB
# VP|<NP-PP-DIR-CLR>
# VP|<NP-PP-DIR-CLR>
# CD
# CD
# VP|<PP-DIR-CLR-PP-PRP>
# VP|<PP-DIR-CLR-PP-PRP>
# NP
# NP
# NP|<JJ-CC>
# NP|<JJ-CC>
# NP|<CC-JJ>
# NP|<CC-JJ>
# NNS
# NNS
# JJ
# JJ
# VP
# VP
# VBN
# VBN
# NN
# NN
# NNS
# NNS
# JJ
# JJ
# NN
# NN
# NN
# NN
# ADJP
# ADJP
# NP-ADV
# NP-ADV
# S
# S
# NP-SBJ-1
# NP-SBJ-1
# S|<ADVP-TMP-VP>
# S|<ADVP-TMP-VP>
# RB
# RB
# NP-LGS
# NP-LGS
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# VP
# VP
# RB
# RB
# VP|<VBN-NP>
# VP|<VBN-NP>
# VBN
# VBN
# NP
# NP
# NP|<UCP-NN>
# NP|<UCP-NN>
# UCP
# UCP
# UCP|<CC-JJ>
# UCP|<CC-JJ>
# JJ
# JJ
# NN
# NN
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP-SBJ|<NN-NNP>
# NP-SBJ|<NN-NNP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP|<NP-1-S>
# VP|<NP-1-S>
# NP-1
# NP-1
# NNS
# NNS
# NP
# NP
# QP|<$-CD>
# QP|<$-CD>
# QP|<CD-TO>
# QP|<CD-TO>
# CD
# CD
# QP|<TO-$>
# QP|<TO-$>
# CD
# CD
# ADVP
# ADVP
# DT
# DT
# NP
# NP
# NNS
# NNS
# NP|<SBAR-,>
# NP|<SBAR-,>
# SBAR
# SBAR
# WHNP-18
# WHNP-18
# -NONE-
# -NONE-
# VP
# VP
# VBN
# VBN
# JJ
# JJ
# NNP
# NNP
# QP
# QP
# SBAR
# SBAR
# WHNP-19
# WHNP-19
# -NONE-
# -NONE-
# VP
# VP
# VBN
# VBN
# NP-1
# NP-1
# VP
# VP
# VB
# VB
# NNP
# NNP
# CD
# CD
# VB
# VB
# NNS
# NNS
# NP
# NP
# NP|<NNS-S>
# NP|<NNS-S>
# NNS
# NNS
# VB
# VB
# PRP$
# PRP$
# NN
# NN
# S
# S
# S|<S-TPC-2-,>
# S|<S-TPC-2-,>
# S-TPC-2
# S-TPC-2
# NN
# NN
# S-TPC-2|<:-VP>
# S-TPC-2|<:-VP>
# VP
# VP
# VP|<S-PP-TMP>
# VP|<S-PP-TMP>
# NP-PRD
# NP-PRD
# NN
# NN
# IN
# IN
# NN
# NN
# RB
# RB
# VBG
# VBG
# NP|<VBG-NN>
# NP|<VBG-NN>
# VBG
# VBG
# NN
# NN
# VBG
# VBG
# S
# S
# NP-SBJ-16
# NP-SBJ-16
# JJ
# JJ
# NN
# NN
# VP
# VP
# VBN
# VBN
# VP|<NP-NP-TMP>
# VP|<NP-NP-TMP>
# -NONE-
# -NONE-
# VP|<NP-TMP-PP>
# VP|<NP-TMP-PP>
# NP-TMP
# NP-TMP
# PP
# PP
# JJ
# JJ
# NNS
# NNS
# VBN
# VBN
# NNP
# NNP
# CD
# CD
# NN
# NN
# VP
# VP
# VB
# VB
# VP
# VP
# VB
# VB
# VP|<NP-PP-EXT>
# VP|<NP-PP-EXT>
# NP
# NP
# NNS
# NNS
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# NP-SBJ|<NNP-NNP>
# NP-SBJ|<NNP-NNP>
# NN
# NN
# S
# S
# S-NOM-SBJ
# S-NOM-SBJ
# VP
# VP
# VBG
# VBG
# NP
# NP
# NP|<QP-NNS>
# NP|<QP-NNS>
# SBAR
# SBAR
# WHNP-20
# WHNP-20
# WP$
# WP$
# NNS
# NNS
# -NONE-
# -NONE-
# VBN
# VBN
# NP
# NP
# NP|<JJ-QP>
# NP|<JJ-QP>
# JJ
# JJ
# CD
# CD
# CD
# CD
# VP
# VP
# VP|<``-NP-PRD>
# VP|<``-NP-PRD>
# JJ
# JJ
# NN
# NN
# S
# S
# S|<NP-TMP-,>
# S|<NP-TMP-,>
# VP
# VP
# VP|<PP-CLR-,>
# VP|<PP-CLR-,>
# CD
# CD
# CD
# CD
# S
# S
# NP-SBJ-17
# NP-SBJ-17
# NP
# NP
# NP|<ADJP-NNP>
# NP|<ADJP-NNP>
# CD
# CD
# NNP
# NNP
# IN
# IN
# NNP
# NNP
# NNP
# NNP
# VBN
# VBN
# -NONE-
# -NONE-
# CD
# CD
# NP
# NP
# NP|<VBN-CD>
# NP|<VBN-CD>
# VBN
# VBN
# VP|<NP-PP-EXT>
# VP|<NP-PP-EXT>
# NP
# NP
# VP|<PP-EXT-S-PRP>
# VP|<PP-EXT-S-PRP>
# CD
# CD
# VB
# VB
# S
# S
# NNS
# NNS
# VBD
# VBD
# NN
# NN
# VBD
# VBD
# S
# S
# NNP
# NNP
# NNP
# NNP
# NP-1
# NP-1
# VB
# VB
# NN
# NN
# NNS
# NNS
# JJ
# JJ
# VP
# VP
# VBG
# VBG
# VP|<PP-PRP-PP-DIR>
# VP|<PP-PRP-PP-DIR>
# NP
# NP
# JJ
# JJ
# VBD
# VBD
# QP|<CD-CD>
# QP|<CD-CD>
# CD
# CD
# QP|<CD-CC>
# QP|<CD-CC>
# QP|<CC-$>
# QP|<CC-$>
# CD
# CD
# VP
# VP
# VBN
# VBN
# PP
# PP
# CC
# CC
# NP|<JJ-QP>
# NP|<JJ-QP>
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# NN
# NN
# VBD
# VBD
# S
# S
# S|<ADVP-TMP-VP>
# S|<ADVP-TMP-VP>
# VBZ
# VBZ
# JJ
# JJ
# JJ
# JJ
# NP|<NN-JJ>
# NP|<NN-JJ>
# JJ
# JJ
# WHNP-1
# WHNP-1
# NNP
# NNP
# VBN
# VBN
# CD
# CD
# VBP
# VBP
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NNP-CD>
# NP-SBJ|<NNP-CD>
# NP-SBJ|<CD-NN>
# NP-SBJ|<CD-NN>
# VB
# VB
# NN
# NN
# NN
# NN
# VBG
# VBG
# NP
# NP
# NNP
# NNP
# NP
# NP
# CD
# CD
# NP|<PP-SBAR-PRP>
# NP|<PP-SBAR-PRP>
# SBAR-PRP
# SBAR-PRP
# VP
# VP
# VB
# VB
# VP|<PP-CLR-PP-TMP>
# VP|<PP-CLR-PP-TMP>
# NP
# NP
# S
# S
# VP
# VP
# CD
# CD
# JJ
# JJ
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NP
# NP
# NNP
# NNP
# JJ
# JJ
# NP-SBJ|<PP-PP-TMP>
# NP-SBJ|<PP-PP-TMP>
# NP
# NP
# NNS
# NNS
# VP
# VP
# VP|<NP-EXT-PP-DIR>
# VP|<NP-EXT-PP-DIR>
# PP-DIR
# PP-DIR
# CD
# CD
# NNS
# NNS
# NN
# NN
# NP-SBJ
# NP-SBJ
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# NP|<NNP-NNPS>
# NP|<NNP-NNPS>
# NNP
# NNP
# NP|<NNPS-POS>
# NP|<NNPS-POS>
# NNPS
# NNPS
# JJ
# JJ
# JJ
# JJ
# CD
# CD
# CD
# CD
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NP-SBJ|<JJ-NNS>
# NP-SBJ|<JJ-NNS>
# VP
# VP
# VBG
# VBG
# NNS
# NNS
# NP-TMP
# NP-TMP
# DT
# DT
# NNP
# NNP
# VBN
# VBN
# JJ
# JJ
# VP
# VP
# VBD
# VBD
# ADVP-DIR
# ADVP-DIR
# CD
# CD
# NNS
# NNS
# NN
# NN
# CD
# CD
# CD
# CD
# NP-SBJ|<PP-,>
# NP-SBJ|<PP-,>
# JJ
# JJ
# SBAR
# SBAR
# WHNP-21
# WHNP-21
# -NONE-
# -NONE-
# VBD
# VBD
# NN
# NN
# NNS
# NNS
# VP
# VP
# VBG
# VBG
# NN
# NN
# NN
# NN
# NN
# NN
# VP
# VP
# ADVP
# ADVP
# VP|<VBD-PP-DIR>
# VP|<VBD-PP-DIR>
# VBD
# VBD
# CD
# CD
# PP-DIR
# PP-DIR
# PP-DIR|<NP-PP-TMP>
# PP-DIR|<NP-PP-TMP>
# CD
# CD
# NP
# NP
# NNP
# NNP
# NP|<NNPS-NNP>
# NP|<NNPS-NNP>
# NNPS
# NNPS
# NP|<NNPS-NNP>
# NP|<NNPS-NNP>
# VP
# VP
# VBD
# VBD
# VP|<NP-PP-LOC>
# VP|<NP-PP-LOC>
# -NONE-
# -NONE-
# VP|<PP-LOC-SBAR-3>
# VP|<PP-LOC-SBAR-3>
# SBAR-3
# SBAR-3
# VB
# VB
# NN
# NN
# NNS
# NNS
# S-TPC-1
# S-TPC-1
# NP-SBJ-2
# NP-SBJ-2
# NP-SBJ-2|<,-VP>
# NP-SBJ-2|<,-VP>
# NP-SBJ-2|<VP-,>
# NP-SBJ-2|<VP-,>
# VBN
# VBN
# NNP
# NNP
# PP-LOC
# PP-LOC
# NP-ADV
# NP-ADV
# CD
# CD
# NNS
# NNS
# PP-LOC|<IN-NP>
# PP-LOC|<IN-NP>
# NNP
# NNP
# VB
# VB
# VB
# VB
# ADJP
# ADJP
# ADJP|<CC-VBG>
# ADJP|<CC-VBG>
# VBG
# VBG
# VB
# VB
# NN
# NN
# NNS
# NNS
# NN
# NN
# NP-SBJ-1
# NP-SBJ-1
# NN
# NN
# NP-SBJ-1|<PP-PP>
# NP-SBJ-1|<PP-PP>
# NP
# NP
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NN
# NN
# NN
# NN
# VP
# VP
# VB
# VB
# NP
# NP
# NP|<NN-PRN>
# NP|<NN-PRN>
# NN
# NN
# PRN
# PRN
# PRN|<CC-NN>
# PRN|<CC-NN>
# PRN|<NN-:>
# PRN|<NN-:>
# NN
# NN
# NP
# NP
# NX
# NX
# NN
# NN
# NNP
# NNP
# SINV
# SINV
# CONJP
# CONJP
# SINV|<SINV-,>
# SINV|<SINV-,>
# SINV
# SINV
# SINV|<NP-SBJ-1-VP>
# SINV|<NP-SBJ-1-VP>
# NN
# NN
# JJ
# JJ
# NN
# NN
# VP
# VP
# VBD
# VBD
# VP|<NP-ADVP-MNR>
# VP|<NP-ADVP-MNR>
# VP|<ADVP-MNR-PP-DIR-CLR>
# VP|<ADVP-MNR-PP-DIR-CLR>
# RB
# RB
# SINV|<,-SINV>
# SINV|<,-SINV>
# SINV|<SINV-.>
# SINV|<SINV-.>
# SINV
# SINV
# ADVP-PRD-TPC-2
# ADVP-PRD-TPC-2
# SINV|<VP-NP-SBJ>
# SINV|<VP-NP-SBJ>
# VP
# VP
# ADVP-PRD
# ADVP-PRD
# NP-SBJ
# NP-SBJ
# NN
# NN
# NN
# NN
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# NP-SBJ|<VP-PP>
# NP-SBJ|<VP-PP>
# VBN
# VBN
# NP
# NP
# NP|<NNPS-CC>
# NP|<NNPS-CC>
# NNPS
# NNPS
# VBG
# VBG
# VBD
# VBD
# NNP
# NNP
# VP
# VP
# VP|<NP-SBAR-ADV>
# VP|<NP-SBAR-ADV>
# QP
# QP
# CD
# CD
# NN
# NN
# VP
# VP
# VBG
# VBG
# NN
# NN
# SBAR-ADV
# SBAR-ADV
# SBAR-ADV|<CC-SBAR>
# SBAR-ADV|<CC-SBAR>
# S
# S
# NP-SBJ-18
# NP-SBJ-18
# JJ
# JJ
# NN
# NN
# VBZ
# VBZ
# VBN
# VBN
# -NONE-
# -NONE-
# NNS
# NNS
# IN
# IN
# NP-SBJ
# NP-SBJ
# NP-SBJ|<JJ-NNP>
# NP-SBJ|<JJ-NNP>
# JJ
# JJ
# VP
# VP
# VBG
# VBG
# NNP
# NNP
# ADJP-PRD
# ADJP-PRD
# NP-ADV
# NP-ADV
# QP
# QP
# QP|<JJS-DT>
# QP|<JJS-DT>
# JJS
# JJS
# ADJP-PRD|<RB-PP-DIR>
# ADJP-PRD|<RB-PP-DIR>
# RB
# RB
# JJ
# JJ
# NN
# NN
# JJR
# JJR
# EX
# EX
# VP
# VP
# VP|<NP-PRD-ADVP-TMP>
# VP|<NP-PRD-ADVP-TMP>
# NNS
# NNS
# VP|<ADVP-TMP-,>
# VP|<ADVP-TMP-,>
# ADVP-TMP
# ADVP-TMP
# JJ
# JJ
# NNS
# NNS
# S
# S
# SBAR
# SBAR
# IN
# IN
# S-ADV
# S-ADV
# NP-SBJ-19
# NP-SBJ-19
# JJ
# JJ
# VP
# VP
# VBN
# VBN
# -NONE-
# -NONE-
# NP-SBJ
# NP-SBJ
# JJ
# JJ
# RB
# RB
# VP|<NP-PP-TMP>
# VP|<NP-PP-TMP>
# VP|<PP-TMP-ADVP-TMP>
# VP|<PP-TMP-ADVP-TMP>
# NNP
# NNP
# S|<,-NP-SBJ-3>
# S|<,-NP-SBJ-3>
# S|<NP-SBJ-3-VP>
# S|<NP-SBJ-3-VP>
# NP-SBJ-3
# NP-SBJ-3
# NNS
# NNS
# VBD
# VBD
# JJ
# JJ
# RB
# RB
# NN
# NN
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VP|<S-PP-LOC>
# VP|<S-PP-LOC>
# NN
# NN
# NN
# NN
# VP
# VP
# SBAR-PRD
# SBAR-PRD
# S
# S
# PRP
# PRP
# S|<NP-SBJ-20-VP>
# S|<NP-SBJ-20-VP>
# NP-SBJ-20
# NP-SBJ-20
# -NONE-
# -NONE-
# VB
# VB
# VB
# VB
# SBAR
# SBAR
# WHNP-22
# WHNP-22
# -NONE-
# -NONE-
# VB
# VB
# VBZ
# VBZ
# VBG
# VBG
# NP
# NP
# RB
# RB
# NP|<DT-QP>
# NP|<DT-QP>
# CD
# CD
# PP-TMP
# PP-TMP
# VBG
# VBG
# VBD
# VBD
# NP-SBJ
# NP-SBJ
# NP-PRD
# NP-PRD
# NP-PRD|<DT-JJ>
# NP-PRD|<DT-JJ>
# NP-PRD|<JJ-''>
# NP-PRD|<JJ-''>
# JJ
# JJ
# NP-PRD|<''-NN>
# NP-PRD|<''-NN>
# NN
# NN
# NN
# NN
# NNS
# NNS
# VBD
# VBD
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<NNP-NN>
# NP-SBJ-1|<NNP-NN>
# NN
# NN
# VP
# VP
# VB
# VB
# VP|<NP-EXT-NP-TMP>
# VP|<NP-EXT-NP-TMP>
# NP-EXT
# NP-EXT
# NP-EXT|<CD--NONE->
# NP-EXT|<CD--NONE->
# CD
# CD
# VP|<NP-TMP-S-CLR>
# VP|<NP-TMP-S-CLR>
# VP
# VP
# VB
# VB
# VP|<PP-LOC-CLR-PP-LOC>
# VP|<PP-LOC-CLR-PP-LOC>
# CD
# CD
# NNS
# NNS
# VP
# VP
# VP|<NP-TMP-SBAR>
# VP|<NP-TMP-SBAR>
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NN-S>
# NP-SBJ|<NN-S>
# VB
# VB
# NP
# NP
# NP|<ADJP-JJ>
# NP|<ADJP-JJ>
# CD
# CD
# JJ
# JJ
# NN
# NN
# NN
# NN
# VB
# VB
# NN
# NN
# S
# S
# NP-SBJ-21
# NP-SBJ-21
# -NONE-
# -NONE-
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NNP
# NNP
# NP|<,-NP-LOC>
# NP|<,-NP-LOC>
# NNP
# NNP
# NP-PRD
# NP-PRD
# NP-PRD|<NN-NN>
# NP-PRD|<NN-NN>
# NN
# NN
# S
# S
# S|<S-CC>
# S|<S-CC>
# S
# S
# PRP
# PRP
# S|<RB-VP>
# S|<RB-VP>
# RB
# RB
# VBP
# VBP
# VB
# VB
# S|<S-.>
# S|<S-.>
# VP
# VP
# VBP
# VBP
# VP
# VP
# IN
# IN
# NN
# NN
# VBP
# VBP
# NP
# NP
# NP
# NP
# JJ
# JJ
# JJ
# JJ
# NN
# NN
# NN
# NN
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NNP-NNS>
# NP-SBJ|<NNP-NNS>
# NNP
# NNP
# VP
# VP
# VBP
# VBP
# VP|<NP-2-PP-CLR>
# VP|<NP-2-PP-CLR>
# NP-2
# NP-2
# NNS
# NNS
# NP-2|<,-SBAR>
# NP-2|<,-SBAR>
# NP-2|<SBAR-,>
# NP-2|<SBAR-,>
# S
# S
# NP-SBJ-22
# NP-SBJ-22
# -NONE-
# -NONE-
# NN
# NN
# NN
# NN
# VP
# VP
# VBG
# VBG
# ADJP
# ADJP
# ADJP|<JJ-CC>
# ADJP|<JJ-CC>
# JJ
# JJ
# ADJP|<CC-JJ>
# ADJP|<CC-JJ>
# JJ
# JJ
# VB
# VB
# JJ
# JJ
# NN
# NN
# NN
# NN
# NN
# NN
# VB
# VB
# CD
# CD
# NNS
# NNS
# PRN
# PRN
# ADJP
# ADJP
# ADJP
# ADJP
# RB
# RB
# ADJP|<RB-JJ>
# ADJP|<RB-JJ>
# NP
# NP
# NP|<JJS-JJ>
# NP|<JJS-JJ>
# VB
# VB
# JJ
# JJ
# NP|<,-PP-DIR>
# NP|<,-PP-DIR>
# PP-DIR
# PP-DIR
# PP-DIR|<IN-NP>
# PP-DIR|<IN-NP>
# SBAR
# SBAR
# SBAR
# SBAR
# WHNP-23
# WHNP-23
# -NONE-
# -NONE-
# QP
# QP
# RB
# RB
# JJ
# JJ
# SBAR|<CC-SBAR>
# SBAR|<CC-SBAR>
# SBAR
# SBAR
# WHNP-24
# WHNP-24
# -NONE-
# -NONE-
# VB
# VB
# NN
# NN
# JJ
# JJ
# NN
# NN
# CD
# CD
# VB
# VB
# NP
# NP
# NP|<NNP-NNPS>
# NP|<NNP-NNPS>
# NNP
# NNP
# NNPS
# NNPS
# NP
# NP
# NP
# NP
# JJ
# JJ
# CD
# CD
# NP|<:-NP>
# NP|<:-NP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VBZ
# VBZ
# VP
# VP
# NP
# NP
# QP
# QP
# JJR
# JJR
# NNS
# NNS
# VBN
# VBN
# VP|<NP-PP>
# VP|<NP-PP>
# VP|<PP-PRN>
# VP|<PP-PRN>
# CD
# CD
# NP
# NP
# RB
# RB
# NP|<DT-NNP>
# NP|<DT-NNP>
# NN
# NN
# S
# S
# NNS
# NNS
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<NNP-NNS>
# NP-SBJ-1|<NNP-NNS>
# NNS
# NNS
# VP
# VP
# VB
# VB
# VP|<NP-PP>
# VP|<NP-PP>
# NP
# NP
# VP|<PP-PP-LOC>
# VP|<PP-PP-LOC>
# NP
# NP
# QP
# QP
# NP|<NNP-NNP>
# NP|<NNP-NNP>
# VBP
# VBP
# NN
# NN
# VB
# VB
# NNS
# NNS
# S
# S
# NP-SBJ-23
# NP-SBJ-23
# VBN
# VBN
# -NONE-
# -NONE-
# RB
# RB
# NNS
# NNS
# VB
# VB
# S
# S
# S|<PP-PRD-S>
# S|<PP-PRD-S>
# PP-PRD
# PP-PRD
# IN
# IN
# NN
# NN
# VB
# VB
# VBN
# VBN
# VB
# VB
# NNP
# NNP
# VP
# VP
# VBP
# VBP
# NN
# NN
# CD
# CD
# PP
# PP
# IN
# IN
# VBG
# VBG
# CD
# CD
# NNS
# NNS
# NP
# NP
# RB
# RB
# ADJP
# ADJP
# NP
# NP
# CD
# CD
# SBAR
# SBAR
# WHNP-25
# WHNP-25
# -NONE-
# -NONE-
# NN
# NN
# NP-SBJ
# NP-SBJ
# JJ
# JJ
# NNS
# NNS
# VP
# VP
# RB
# RB
# VP|<VBP-SBAR-NOM>
# VP|<VBP-SBAR-NOM>
# SBAR-NOM
# SBAR-NOM
# WRB
# WRB
# VP
# VP
# VBD
# VBD
# VP|<NP-ADVP-PRP>
# VP|<NP-ADVP-PRP>
# ADVP-PRP
# ADVP-PRP
# S
# S
# IN
# IN
# NP|<NNP-NN>
# NP|<NNP-NN>
# NP|<NN-CC>
# NP|<NN-CC>
# NP-SBJ-2
# NP-SBJ-2
# VP
# VP
# ADJP-PRD
# ADJP-PRD
# JJ
# JJ
# VB
# VB
# NN
# NN
# NP|<PP-PP>
# NP|<PP-PP>
# CD
# CD
# NP|<PP-PP-3>
# NP|<PP-PP-3>
# NP
# NP
# NP|<JJ-DT>
# NP|<JJ-DT>
# DT
# DT
# PP-3
# PP-3
# RB
# RB
# PP-3|<IN-NP>
# PP-3|<IN-NP>
# CD
# CD
# VBD
# VBD
# S
# S
# NN
# NN
# S|<,-SBAR-ADV+SINV>
# S|<,-SBAR-ADV+SINV>
# S|<SBAR-ADV+SINV-,>
# S|<SBAR-ADV+SINV-,>
# SBAR-ADV+SINV
# SBAR-ADV+SINV
# SBAR-ADV+SINV|<NP-SBJ-VP>
# SBAR-ADV+SINV|<NP-SBJ-VP>
# VP
# VP
# VBN
# VBN
# VBN
# VBN
# CD
# CD
# NN
# NN
# S
# S
# NP-SBJ-24
# NP-SBJ-24
# VBN
# VBN
# -NONE-
# -NONE-
# NN
# NN
# VP
# VP
# VP
# VP
# VB
# VB
# NP
# NP
# NP|<JJ-NAC-LOC>
# NP|<JJ-NAC-LOC>
# NP|<NAC-LOC-NN>
# NP|<NAC-LOC-NN>
# NAC-LOC
# NAC-LOC
# NNP
# NNP
# NAC-LOC|<NNPS-,>
# NAC-LOC|<NNPS-,>
# NNPS
# NNPS
# NNP
# NNP
# NN
# NN
# NP
# NP
# NN
# NN
# NP|<SBAR-PP>
# NP|<SBAR-PP>
# S
# S
# S-ADV
# S-ADV
# -NONE-
# -NONE-
# VBN
# VBN
# NN
# NN
# S|<,-NP-SBJ-25>
# S|<,-NP-SBJ-25>
# S|<NP-SBJ-25-VP>
# S|<NP-SBJ-25-VP>
# NP-SBJ-25
# NP-SBJ-25
# VBN
# VBN
# VP|<NP-NP>
# VP|<NP-NP>
# VP|<NP-PP-LOC>
# VP|<NP-PP-LOC>
# CD
# CD
# VP|<PP-LOC-NP-TMP>
# VP|<PP-LOC-NP-TMP>
# S
# S
# IN
# IN
# S|<,-NP-SBJ-26>
# S|<,-NP-SBJ-26>
# S|<NP-SBJ-26-VP>
# S|<NP-SBJ-26-VP>
# NP-SBJ-26
# NP-SBJ-26
# -NONE-
# -NONE-
# CD
# CD
# NNP
# NNP
# VBZ
# VBZ
# NNP
# NNP
# NNP
# NNP
# CD
# CD
# NP
# NP
# NP|<:-NP>
# NP|<:-NP>
# NP|<NP-:>
# NP|<NP-:>
# NNP
# NNP
# NNP
# NNP
# CD
# CD
# NP|<NP-:>
# NP|<NP-:>
# NP
# NP
# NNP
# NNP
# NP|<NN-NNP>
# NP|<NN-NNP>
# NN
# NN
# NNP
# NNP
# CD
# CD
# NN
# NN
# NP|<:-CC>
# NP|<:-CC>
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# DT
# DT
# VP
# VP
# VBD
# VBD
# SBAR
# SBAR
# WHNP-26
# WHNP-26
# -NONE-
# -NONE-
# CD
# CD
# VP
# VP
# CD
# CD
# S
# S
# NP-SBJ-27
# NP-SBJ-27
# NNP
# NNP
# NP-SBJ-27|<,-ADJP>
# NP-SBJ-27|<,-ADJP>
# NP-SBJ-27|<ADJP-,>
# NP-SBJ-27|<ADJP-,>
# -NONE-
# -NONE-
# NP-PRD
# NP-PRD
# NP
# NP
# NP-PRD|<,-NP>
# NP-PRD|<,-NP>
# DT
# DT
# NNS
# NNS
# VB
# VB
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NN
# NN
# S
# S
# NP-SBJ-28
# NP-SBJ-28
# NNP
# NNP
# NNP
# NNP
# NP-SBJ-28|<,-NP>
# NP-SBJ-28|<,-NP>
# NP-SBJ-28|<NP-,>
# NP-SBJ-28|<NP-,>
# CD
# CD
# -NONE-
# -NONE-
# VP
# VP
# VP|<ADVP-TMP-NP-PRD>
# VP|<ADVP-TMP-NP-PRD>
# NNP
# NNP
# NP-SBJ-1
# NP-SBJ-1
# NNP
# NNP
# NP-SBJ-1|<,-NP>
# NP-SBJ-1|<,-NP>
# NP-SBJ-1|<NP-,>
# NP-SBJ-1|<NP-,>
# VB
# VB
# S
# S
# NP
# NP
# RB
# RB
# S
# S
# NP-SBJ-29
# NP-SBJ-29
# NNP
# NNP
# NP-SBJ-29|<,-NP>
# NP-SBJ-29|<,-NP>
# NP-SBJ-29|<NP-,>
# NP-SBJ-29|<NP-,>
# -NONE-
# -NONE-
# NP
# NP
# NNPS
# NNPS
# NP-PRD
# NP-PRD
# S
# S
# S|<,-S-ADV>
# S|<,-S-ADV>
# S|<S-ADV-,>
# S|<S-ADV-,>
# VBG
# VBG
# NN
# NN
# NN
# NN
# VBD
# VBD
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# VP
# VP
# VP|<VBG-NP>
# VP|<VBG-NP>
# VBG
# VBG
# S-NOM
# S-NOM
# NP-SBJ-3
# NP-SBJ-3
# VP
# VP
# RB
# RB
# VP|<VBG-S>
# VP|<VBG-S>
# VBG
# VBG
# VB
# VB
# NP
# NP
# NX
# NX
# NX
# NX
# NNS
# NNS
# NX|<,-NX>
# NX|<,-NX>
# NX|<NX-CC>
# NX|<NX-CC>
# NNS
# NNS
# NX
# NX
# NX|<JJ-NNS>
# NX|<JJ-NNS>
# JJ
# JJ
# NNS
# NNS
# S-TPC-1
# S-TPC-1
# NP-SBJ
# NP-SBJ
# NP
# NP
# NP-SBJ|<:-NP>
# NP-SBJ|<:-NP>
# NP-SBJ|<NP-:>
# NP-SBJ|<NP-:>
# NP
# NP
# NNP
# NNP
# NP|<,-NNP>
# NP|<,-NNP>
# NP|<NNP-,>
# NP|<NNP-,>
# NNP
# NNP
# NNP
# NNP
# NP|<,-NNP>
# NP|<,-NNP>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VP|<PP-LOC-PRD-PP-PRP>
# VP|<PP-LOC-PRD-PP-PRP>
# JJ
# JJ
# NN
# NN
# NN
# NN
# NN
# NN
# JJ
# JJ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NP|<JJ-NNP>
# NP|<JJ-NNP>
# NN
# NN
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# NNS
# NNS
# VB
# VB
# NN
# NN
# JJ
# JJ
# NN
# NN
# NN
# NN
# NNP
# NNP
# PRP
# PRP
# VP
# VP
# VBD
# VBD
# VP|<NP-PP-DIR-CLR>
# VP|<NP-PP-DIR-CLR>
# VBG
# VBG
# NNS
# NNS
# NN
# NN
# VP
# VP
# VP|<``-NP>
# VP|<``-NP>
# NP
# NP
# JJ
# JJ
# NN
# NN
# NP|<''-PP-LOC>
# NP|<''-PP-LOC>
# JJ
# JJ
# NN
# NN
# PRP
# PRP
# VP
# VP
# VP|<``-NP-PRD>
# VP|<``-NP-PRD>
# VP|<NP-PRD-''>
# VP|<NP-PRD-''>
# NP-PRD
# NP-PRD
# VBG
# VBG
# NP-PRD|<NN-SBAR>
# NP-PRD|<NN-SBAR>
# NN
# NN
# VP|<''-PP-LOC>
# VP|<''-PP-LOC>
# VP|<PP-LOC-SBAR-1>
# VP|<PP-LOC-SBAR-1>
# NN
# NN
# SBAR-1
# SBAR-1
# NN
# NN
# VBZ
# VBZ
# NP
# NP
# VBG
# VBG
# NP|<,-CC>
# NP|<,-CC>
# NP|<CC-ADVP>
# NP|<CC-ADVP>
# NP|<ADVP-NP>
# NP|<ADVP-NP>
# NP
# NP
# NP|<``-NN>
# NP|<``-NN>
# NN
# NN
# NP
# NP
# NP|<-LRB--VBG>
# NP|<-LRB--VBG>
# -LRB-
# -LRB-
# NP|<VBG--RRB->
# NP|<VBG--RRB->
# VBG
# VBG
# NP|<-RRB--NN>
# NP|<-RRB--NN>
# -RRB-
# -RRB-
# JJ
# JJ
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# NNS
# NNS
# JJ
# JJ
# NNS
# NNS
# VBG
# VBG
# PRP
# PRP
# PP
# PP
# VBG
# VBG
# NP
# NP
# NP|<JJ-NNS>
# NP|<JJ-NNS>
# NNS
# NNS
# NNS
# NNS
# PP|<CC-PP>
# PP|<CC-PP>
# VP
# VP
# VBG
# VBG
# NP-2
# NP-2
# NP-2|<NN-NNS>
# NP-2|<NN-NNS>
# NN
# NN
# NNS
# NNS
# VP
# VP
# VBG
# VBG
# VP|<CC-VP>
# VP|<CC-VP>
# VP|<VP-ADVP-LOC>
# VP|<VP-ADVP-LOC>
# VBG
# VBG
# NP
# NP
# JJS
# JJS
# RB
# RB
# VP
# VP
# VBD
# VBD
# VP|<NP-1-PP-CLR>
# VP|<NP-1-PP-CLR>
# NP-1
# NP-1
# VBG
# VBG
# NN
# NN
# NN
# NN
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# VBN
# VBN
# VB
# VB
# NN
# NN
# NNS
# NNS
# VBN
# VBN
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# SBAR
# SBAR
# WHADVP-2
# WHADVP-2
# VB
# VB
# ADVP-MNR
# ADVP-MNR
# S
# S
# NP-SBJ-2
# NP-SBJ-2
# VP
# VP
# NN
# NN
# PP-MNR
# PP-MNR
# VBG
# VBG
# JJ
# JJ
# NN
# NN
# NN
# NN
# VP|<VP-CC>
# VP|<VP-CC>
# VBG
# VBG
# NN
# NN
# VBG
# VBG
# NN
# NN
# SBAR
# SBAR
# VB
# VB
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# JJ
# JJ
# NNS
# NNS
# VP|<PP-CLR-ADVP-MNR>
# VP|<PP-CLR-ADVP-MNR>
# JJ
# JJ
# NNS
# NNS
# NNS
# NNS
# NN
# NN
# VB
# VB
# NP
# NP
# NNP
# NNP
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# PP-PRP
# PP-PRP
# VBG
# VBG
# S-TPC-1
# S-TPC-1
# NP-SBJ-2
# NP-SBJ-2
# S-TPC-1|<PRN-VP>
# S-TPC-1|<PRN-VP>
# PRN
# PRN
# PRN|<PP-,>
# PRN|<PP-,>
# NN
# NN
# VBN
# VBN
# VB
# VB
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# VB
# VB
# PP-CLR
# PP-CLR
# NN
# NN
# PP-CLR|<CONJP-PP>
# PP-CLR|<CONJP-PP>
# CONJP
# CONJP
# CONJP|<RB-IN>
# CONJP|<RB-IN>
# JJ
# JJ
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# DT
# DT
# VP
# VP
# VP|<RB-PP-PRD>
# VP|<RB-PP-PRD>
# VP|<PP-PRD-,>
# VP|<PP-PRD-,>
# PP-PRD
# PP-PRD
# RB
# RB
# PP-PRD|<IN-NP>
# PP-PRD|<IN-NP>
# NN
# NN
# RB
# RB
# JJ
# JJ
# SBAR
# SBAR
# WHNP-27
# WHNP-27
# -NONE-
# -NONE-
# CD
# CD
# NP-SBJ-1
# NP-SBJ-1
# DT
# DT
# IN
# IN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VP|<ADVP-TMP-PP-PRD>
# VP|<ADVP-TMP-PP-PRD>
# VP|<PP-PRD-PP>
# VP|<PP-PRD-PP>
# NN
# NN
# VBN
# VBN
# VB
# VB
# JJ
# JJ
# NNS
# NNS
# NP
# NP
# JJ
# JJ
# NN
# NN
# NP|<``-NN>
# NP|<``-NN>
# NP|<NN-''>
# NP|<NN-''>
# NP|<''-NN>
# NP|<''-NN>
# NNP
# NNP
# NN
# NN
# VBG
# VBG
# NNS
# NNS
# NN
# NN
# NP-SBJ|<PP-,>
# NP-SBJ|<PP-,>
# NN
# NN
# VBN
# VBN
# NP|<VBG-NN>
# NP|<VBG-NN>
# NP|<NN-SBAR>
# NP|<NN-SBAR>
# NN
# NN
# VBG
# VBG
# VP
# VP
# VBD
# VBD
# NNS
# NNS
# NP-LGS
# NP-LGS
# NP-LGS|<,-NP>
# NP-LGS|<,-NP>
# NP-LGS|<NP-CC>
# NP-LGS|<NP-CC>
# NP-LGS|<CC-NP>
# NP-LGS|<CC-NP>
# S-TPC-1
# S-TPC-1
# SBAR-NOM-SBJ
# SBAR-NOM-SBJ
# WHNP-28
# WHNP-28
# VP
# VP
# VBZ
# VBZ
# -NONE-
# -NONE-
# SBAR-PRD
# SBAR-PRD
# NP-SBJ
# NP-SBJ
# VBN
# VBN
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# VP|<PP-CLR-PP-PRP>
# VP|<PP-CLR-PP-PRP>
# NP
# NP
# NNS
# NNS
# VB
# VB
# VP
# VP
# VP|<ADVP-TMP-ADJP-PRD>
# VP|<ADVP-TMP-ADJP-PRD>
# ADJP-PRD
# ADJP-PRD
# VBN
# VBN
# PP
# PP
# PP|<``-NP>
# PP|<``-NP>
# JJ
# JJ
# NNS
# NNS
# NNP
# NNP
# NP
# NP
# VBG
# VBG
# JJ
# JJ
# NNP
# NNP
# VP
# VP
# JJ
# JJ
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NNP-NN>
# NP-SBJ|<NNP-NN>
# NNS
# NNS
# VP
# VP
# VBN
# VBN
# NN
# NN
# NN
# NN
# NN
# NN
# NP
# NP
# JJ
# JJ
# NP-SBJ
# NP-SBJ
# NP-SBJ|<CD-NN>
# NP-SBJ|<CD-NN>
# NN
# NN
# VBZ
# VBZ
# ADVP-TMP
# ADVP-TMP
# IN
# IN
# VBD
# VBD
# S
# S
# ADJP-PRD
# ADJP-PRD
# JJ
# JJ
# ADJP-PRD|<RB-S>
# ADJP-PRD|<RB-S>
# RB
# RB
# S
# S
# S|<VP-PP-LOC>
# S|<VP-PP-LOC>
# VB
# VB
# VBN
# VBN
# NN
# NN
# NP|<JJ-JJ>
# NP|<JJ-JJ>
# CD
# CD
# NN
# NN
# NNP
# NNP
# VP
# VP
# VB
# VB
# NP-1
# NP-1
# NN
# NN
# NNS
# NNS
# VB
# VB
# CD
# CD
# JJS
# JJS
# VBG
# VBG
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VBN
# VBN
# NP-PRD
# NP-PRD
# SBAR-TMP
# SBAR-TMP
# S
# S
# NP-SBJ-3
# NP-SBJ-3
# NP-SBJ-3|<DT-NN>
# NP-SBJ-3|<DT-NN>
# NN
# NN
# VP
# VP
# VBN
# VBN
# VP|<PP-PP>
# VP|<PP-PP>
# VP|<PP-ADVP-TMP>
# VP|<PP-ADVP-TMP>
# NP-LGS
# NP-LGS
# JJ
# JJ
# NN
# NN
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# RB
# RB
# VBZ
# VBZ
# VB
# VB
# NN
# NN
# JJ
# JJ
# VP
# VP
# VP|<S-PP-MNR>
# VP|<S-PP-MNR>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VBD
# VBD
# VP|<PP-TMP-PP-CLR>
# VP|<PP-TMP-PP-CLR>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<NN-NNP>
# NP-SBJ-1|<NN-NNP>
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VP|<PP-LOC-PRD-NP-TMP>
# VP|<PP-LOC-PRD-NP-TMP>
# VP|<NP-TMP-S-PRP>
# VP|<NP-TMP-S-PRP>
# NNP
# NNP
# NNP
# NNP
# NP|<,-SBAR>
# NP|<,-SBAR>
# NP|<SBAR-,>
# NP|<SBAR-,>
# SBAR
# SBAR
# WHNP-29
# WHNP-29
# -NONE-
# -NONE-
# NN
# NN
# CD
# CD
# VBZ
# VBZ
# JJ
# JJ
# NN
# NN
# JJ
# JJ
# S
# S
# NP-SBJ-31
# NP-SBJ-31
# NP-SBJ-31|<NN-NN>
# NP-SBJ-31|<NN-NN>
# VP
# VP
# VBN
# VBN
# -NONE-
# -NONE-
# VP
# VP
# VP|<ADVP-TMP-SBAR>
# VP|<ADVP-TMP-SBAR>
# ADVP-TMP
# ADVP-TMP
# VBZ
# VBZ
# NP-SBJ-2
# NP-SBJ-2
# PDT
# PDT
# NP-SBJ-2|<DT-NN>
# NP-SBJ-2|<DT-NN>
# VBN
# VBN
# S
# S
# -LRB-
# -LRB-
# IN
# IN
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# S|<VP-.>
# S|<VP-.>
# NN
# NN
# SBAR
# SBAR
# WHNP-30
# WHNP-30
# -NONE-
# -NONE-
# VP
# VP
# VBP
# VBP
# NNS
# NNS
# NN
# NN
# S|<.--RRB->
# S|<.--RRB->
# -RRB-
# -RRB-
# S
# S
# NP-SBJ-32
# NP-SBJ-32
# CD
# CD
# NNS
# NNS
# SBAR
# SBAR
# WHNP-31
# WHNP-31
# WDT
# WDT
# -NONE-
# -NONE-
# VBD
# VBD
# NN
# NN
# JJ
# JJ
# NN
# NN
# VBN
# VBN
# -NONE-
# -NONE-
# CD
# CD
# S
# S
# NNP
# NNP
# NNP
# NNP
# NP-SBJ|<,-NP>
# NP-SBJ|<,-NP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# VP
# VP
# JJ
# JJ
# S
# S
# S|<PRN-VP>
# S|<PRN-VP>
# VB
# VB
# NN
# NN
# NNS
# NNS
# NNS
# NNS
# VBD
# VBD
# NNS
# NNS
# NNS
# NNS
# NP-PRD
# NP-PRD
# JJ
# JJ
# NN
# NN
# S
# S
# NP-SBJ-33
# NP-SBJ-33
# VBN
# VBN
# VP|<NP-PP-LOC>
# VP|<NP-PP-LOC>
# -NONE-
# -NONE-
# VP|<PP-LOC-PP>
# VP|<PP-LOC-PP>
# NN
# NN
# VP|<PP-PP-BNF>
# VP|<PP-PP-BNF>
# NP-LGS
# NP-LGS
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# PP-BNF
# PP-BNF
# NNS
# NNS
# NNP
# NNP
# NNP
# NNP
# NP-PRD
# NP-PRD
# NP-PRD|<JJ-$>
# NP-PRD|<JJ-$>
# JJ
# JJ
# NP-PRD|<$-CD>
# NP-PRD|<$-CD>
# NP-PRD|<CD--NONE->
# NP-PRD|<CD--NONE->
# CD
# CD
# ADJP
# ADJP
# JJ
# JJ
# ADJP-PRD
# ADJP-PRD
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<JJ-NNS>
# NP-SBJ-1|<JJ-NNS>
# NNS
# NNS
# VBD
# VBD
# JJ
# JJ
# NN
# NN
# NN
# NN
# NNS
# NNS
# NP
# NP
# NN
# NN
# NN
# NN
# VP
# VP
# VP|<ADVP-PRD-LOC-PP-TMP>
# VP|<ADVP-PRD-LOC-PP-TMP>
# ADVP-PRD-LOC
# ADVP-PRD-LOC
# S
# S
# S|<NP-SBJ-PRN>
# S|<NP-SBJ-PRN>
# NP-SBJ
# NP-SBJ
# NP-SBJ|<JJ-CD>
# NP-SBJ|<JJ-CD>
# PP
# PP
# JJ
# JJ
# NP
# NP
# JJ
# JJ
# NNS
# NNS
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# VP
# VP
# VB
# VB
# NNS
# NNS
# JJ
# JJ
# ADJP-PRD
# ADJP-PRD
# JJR
# JJR
# NN
# NN
# NN
# NN
# ADJP
# ADJP
# QP
# QP
# JJR
# JJR
# NNS
# NNS
# NP-PRD
# NP-PRD
# NP-PRD|<NN-NN>
# NP-PRD|<NN-NN>
# NN
# NN
# NP-PRD|<NN-NNS>
# NP-PRD|<NN-NNS>
# NN
# NN
# NNS
# NNS
# S
# S
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# S|<PP-TMP-VP>
# S|<PP-TMP-VP>
# CD
# CD
# VBD
# VBD
# JJ
# JJ
# NN
# NN
# VP
# VP
# VBD
# VBD
# VP|<NP-PRD-SBAR-TMP>
# VP|<NP-PRD-SBAR-TMP>
# NN
# NN
# SBAR-TMP
# SBAR-TMP
# NP-ADV
# NP-ADV
# SBAR-TMP|<IN-S>
# SBAR-TMP|<IN-S>
# NNP
# NNP
# VBD
# VBD
# NNS
# NNS
# CD
# CD
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NP|<NP-PP>
# NP|<NP-PP>
# NNP
# NNP
# NNP
# NNP
# SBAR
# SBAR
# WHNP-32
# WHNP-32
# -NONE-
# -NONE-
# NN
# NN
# NNS
# NNS
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# NNP
# NNP
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# SBAR
# SBAR
# WHNP-33
# WHNP-33
# -NONE-
# -NONE-
# VBP
# VBP
# VB
# VB
# IN
# IN
# NN
# NN
# NN
# NN
# VB
# VB
# VP|<NP-PP-TMP>
# VP|<NP-PP-TMP>
# VP|<PP-TMP-SBAR-TMP>
# VP|<PP-TMP-SBAR-TMP>
# NP-SBJ
# NP-SBJ
# VBD
# VBD
# NN
# NN
# S|<,-NP-SBJ>
# S|<,-NP-SBJ>
# S|<NP-SBJ-ADVP-TMP>
# S|<NP-SBJ-ADVP-TMP>
# NNS
# NNS
# RB
# RB
# VP
# VP
# VBP
# VBP
# QP
# QP
# CD
# CD
# ADVP-LOC
# ADVP-LOC
# NNP
# NNP
# NNP
# NNP
# NP|<JJ-NNS>
# NP|<JJ-NNS>
# JJ
# JJ
# NP|<NNS-NN>
# NP|<NNS-NN>
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NN
# NN
# VBD
# VBD
# NNP
# NNP
# CD
# CD
# NP
# NP
# NP|<ADJP-NNS>
# NP|<ADJP-NNS>
# JJ
# JJ
# SBAR
# SBAR
# WHNP-34
# WHNP-34
# -NONE-
# -NONE-
# VP
# VP
# VBZ
# VBZ
# NNP
# NNP
# NN
# NN
# NN
# NN
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP-SBJ|<,-PP>
# NP-SBJ|<,-PP>
# NP-SBJ|<PP-,>
# NP-SBJ|<PP-,>
# RB
# RB
# NP
# NP
# NP|<JJ-VBN>
# NP|<JJ-VBN>
# JJ
# JJ
# NP|<VBN-NN>
# NP|<VBN-NN>
# VBN
# VBN
# NNS
# NNS
# VBZ
# VBZ
# NN
# NN
# CD
# CD
# S
# S
# NP-SBJ-34
# NP-SBJ-34
# NN
# NN
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# VP
# VP
# VBN
# VBN
# VP|<NP-PP-EXT>
# VP|<NP-PP-EXT>
# -NONE-
# -NONE-
# CD
# CD
# NNS
# NNS
# CD
# CD
# NN
# NN
# NNP
# NNP
# NP
# NP
# VBN
# VBN
# S
# S
# NP-SBJ-35
# NP-SBJ-35
# VBN
# VBN
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# -NONE-
# -NONE-
# ...
# VBN
# NNS
# NNS
# NNS
# NNS
# VBD
# VBD
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# WHNP-1
# WHNP-1
# NN
# NN
# JJ
# JJ
# VP|<ADVP-MNR-PP-CLR>
# VP|<ADVP-MNR-PP-CLR>
# NNP
# NNP
# VBD
# VBD
# NNPS
# NNPS
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# NN
# NN
# VBD
# VBD
# NNP
# NNP
# NP
# NP
# VB
# VB
# NN
# NN
# VB
# VB
# VBD
# VBD
# PP-CLR|<``-ADJP>
# PP-CLR|<``-ADJP>
# PP-CLR|<ADJP-''>
# PP-CLR|<ADJP-''>
# JJ
# JJ
# VBD
# VBD
# VBG
# VBG
# NNS
# NNS
# S
# S
# NNP
# NNP
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# NN
# NN
# NN
# NN
# NP-SBJ-1
# NP-SBJ-1
# NNP
# NNP
# NP-SBJ-1|<NN-NNP>
# NP-SBJ-1|<NN-NNP>
# NNP
# NNP
# VP|<,-''>
# VP|<,-''>
# VP|<''-S-ADV>
# VP|<''-S-ADV>
# NNS
# NNS
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# S|<S-ADV-,>
# S|<S-ADV-,>
# S-ADV
# S-ADV
# S-ADV|<PP-PRD-PP-PRP>
# S-ADV|<PP-PRD-PP-PRP>
# NNS
# NNS
# NNPS
# NNPS
# VP
# VP
# VBD
# VBD
# NNP
# NNP
# VBD
# VBD
# JJ
# JJ
# VBN
# VBN
# VP|<NP-NP-TMP>
# VP|<NP-NP-TMP>
# JJ
# JJ
# NN
# NN
# NNS
# NNS
# S|<,-NP-SBJ>
# S|<,-NP-SBJ>
# S|<NP-SBJ-PP-TMP>
# S|<NP-SBJ-PP-TMP>
# NN
# NN
# NN
# NN
# NP-SBJ|<JJ-NNP>
# NP-SBJ|<JJ-NNP>
# VBP
# VBP
# VP
# VP
# VP|<NP-TMP-NP>
# VP|<NP-TMP-NP>
# NNS
# NNS
# NNP
# NNP
# NP
# NP
# VBN
# VBN
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# NP
# NP
# VBG
# VBG
# NNP
# NNP
# VBG
# VBG
# JJ
# JJ
# NN
# NN
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NN
# NN
# VB
# VB
# NNP
# NNP
# NNS
# NNS
# NNP
# NNP
# VBD
# VBD
# NNP
# NNP
# JJ
# JJ
# NNP
# NNP
# NN
# NN
# VB
# VB
# NN
# NN
# NNS
# NNS
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VBD
# VBD
# VB
# VB
# VBZ
# VBZ
# NNS
# NNS
# JJ
# JJ
# NP-LGS
# NP-LGS
# NP-LGS|<PP-PP-TMP>
# NP-LGS|<PP-PP-TMP>
# NNS
# NNS
# VP
# VP
# NP
# NP
# NNP
# NNP
# NN
# NN
# VBD
# VBD
# NN
# NN
# VBD
# VBD
# VBG
# VBG
# NP-SBJ-2
# NP-SBJ-2
# NNP
# NNP
# NNP
# NNP
# VBD
# VBD
# NN
# NN
# JJ
# JJ
# JJ
# JJ
# NP-SBJ-1|<,-ADJP>
# NP-SBJ-1|<,-ADJP>
# NP-SBJ-1|<ADJP-,>
# NP-SBJ-1|<ADJP-,>
# ADJP
# ADJP
# NNS
# NNS
# NNP
# NNP
# JJ
# JJ
# VBN
# VBN
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP-SBJ|<NP-TMP-PP>
# NP-SBJ|<NP-TMP-PP>
# VP
# VP
# VP|<NP-CLR-PP-LOC>
# VP|<NP-CLR-PP-LOC>
# NNP
# NNP
# CD
# CD
# NN
# NN
# VP|<NP-''>
# VP|<NP-''>
# NN
# NN
# JJ
# JJ
# NN
# NN
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# VBP
# VBP
# VBN
# VBN
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# VBN
# VBN
# IN
# IN
# NN
# NN
# VBD
# VBD
# VP|<PP-LOC-NP-TMP>
# VP|<PP-LOC-NP-TMP>
# NNP
# NNP
# VB
# VB
# JJ
# JJ
# FRAG
# FRAG
# VBD
# VBD
# FRAG|<:-NP-SBJ>
# FRAG|<:-NP-SBJ>
# FRAG|<NP-SBJ-,>
# FRAG|<NP-SBJ-,>
# NNP
# NNP
# NP
# NP
# NNP
# NNP
# FRAG|<,-NP-TMP>
# FRAG|<,-NP-TMP>
# FRAG|<NP-TMP-,>
# FRAG|<NP-TMP-,>
# FRAG|<,-PP-LOC>
# FRAG|<,-PP-LOC>
# FRAG|<PP-LOC-,>
# FRAG|<PP-LOC-,>
# FRAG|<,-PP-MNR>
# FRAG|<,-PP-MNR>
# FRAG|<PP-MNR-.>
# FRAG|<PP-MNR-.>
# JJ
# JJ
# JJ
# JJ
# NNPS
# NNPS
# VBG
# VBG
# CD
# CD
# VP|<NP-CLR-PP-CLR>
# VP|<NP-CLR-PP-CLR>
# NN
# NN
# CD
# CD
# NP-ADV
# NP-ADV
# CD
# CD
# SINV
# SINV
# JJ
# JJ
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VBN
# VBN
# NP
# NP
# NNP
# NNP
# NP|<CC-NNP>
# NP|<CC-NNP>
# NNP
# NNP
# VBG
# VBG
# VP|<NP-NP-TMP>
# VP|<NP-NP-TMP>
# VP
# VP
# VBN
# VBN
# JJ
# JJ
# S
# S
# NN
# NN
# CD
# CD
# CD
# CD
# CD
# CD
# JJ
# JJ
# VP
# VP
# ADVP-EXT
# ADVP-EXT
# VP
# VP
# SBAR-PRP-PRD
# SBAR-PRP-PRD
# SBAR-PRP-PRD|<IN-S>
# SBAR-PRP-PRD|<IN-S>
# VBP
# VBP
# NN
# NN
# NNS
# NNS
# VBN
# VBN
# NNP
# NNP
# JJ
# JJ
# NP-TMP-CLR
# NP-TMP-CLR
# CD
# CD
# NP
# NP
# CD
# CD
# NP|<,-PRN>
# NP|<,-PRN>
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# JJ
# JJ
# CD
# CD
# CD
# CD
# JJ
# JJ
# NP
# NP
# VP
# VP
# VBD
# VBD
# VP|<ADVP-DIR-NP>
# VP|<ADVP-DIR-NP>
# JJ
# JJ
# NNS
# NNS
# CD
# CD
# CD
# CD
# NN
# NN
# S
# S
# ADVP-PRP
# ADVP-PRP
# RB
# RB
# VB
# VB
# CD
# CD
# VBN
# VBN
# CD
# CD
# CD
# CD
# JJ
# JJ
# NN
# NN
# VBZ
# VBZ
# NNS
# NNS
# VBD
# VBD
# VP
# VP
# VP|<PP-CLR-ADVP-PRP>
# VP|<PP-CLR-ADVP-PRP>
# ADVP-PRP
# ADVP-PRP
# JJ
# JJ
# VP|<ADJP-PRD-ADVP>
# VP|<ADJP-PRD-ADVP>
# NP-ADV
# NP-ADV
# NP|<JJS-NN>
# NP|<JJS-NN>
# NP-ADV|<ADVP-SBAR-1>
# NP-ADV|<ADVP-SBAR-1>
# VP|<NP-EXT-,>
# VP|<NP-EXT-,>
# VP|<,-PP-DIR>
# VP|<,-PP-DIR>
# VP|<PP-DIR-,>
# VP|<PP-DIR-,>
# NNS
# NNS
# NP
# NP
# NNS
# NNS
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# VP|<PP-CLR-PP-1>
# VP|<PP-CLR-PP-1>
# JJ
# JJ
# VBZ
# VBZ
# NN
# NN
# S
# S
# S|<ADJP-PRD-SBAR-1>
# S|<ADJP-PRD-SBAR-1>
# VBG
# VBG
# VBZ
# VBZ
# NP-SBJ
# NP-SBJ
# NN
# NN
# VB
# VB
# NP
# NP
# VP|<PP-DIR-NP-TMP>
# VP|<PP-DIR-NP-TMP>
# NP
# NP
# NNS
# NNS
# CD
# CD
# CD
# CD
# CD
# CD
# NNS
# NNS
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# NN
# NN
# CD
# CD
# CD
# CD
# NN
# NN
# NNS
# NNS
# NP
# NP
# VBN
# VBN
# NP-SBJ
# NP-SBJ
# PDT
# PDT
# NN
# NN
# JJ
# JJ
# JJ
# JJ
# NNP
# NNP
# NP
# NP
# NP|<ADJP-NAC-LOC>
# NP|<ADJP-NAC-LOC>
# CD
# CD
# NNS
# NNS
# JJ
# JJ
# VBP
# VBP
# NP
# NP
# NP|<PP-NP-ADV>
# NP|<PP-NP-ADV>
# VP
# VP
# VBZ
# VBZ
# VP|<ADVP-DIR-PP-LOC>
# VP|<ADVP-DIR-PP-LOC>
# NNS
# NNS
# VBG
# VBG
# VP
# VP
# VBN
# VBN
# VP|<PP-LOC-,>
# VP|<PP-LOC-,>
# VP|<ADVP-,>
# VP|<ADVP-,>
# VP|<,-NP-TMP>
# VP|<,-NP-TMP>
# NP
# NP
# VP
# VP
# NN
# NN
# VB
# VB
# JJ
# JJ
# CD
# CD
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP
# NP
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# VBG
# VBG
# VB
# VB
# JJ
# JJ
# JJ
# JJ
# NP|<NN-CC>
# NP|<NN-CC>
# NP|<CC-RB>
# NP|<CC-RB>
# VBP
# VBP
# VP|<CC-VP>
# VP|<CC-VP>
# VP|<VP-ADVP-PRP>
# VP|<VP-ADVP-PRP>
# VBD
# VBD
# CD
# CD
# S
# S
# S|<SBAR-ADV-NP-SBJ>
# S|<SBAR-ADV-NP-SBJ>
# IN
# IN
# VP
# VP
# PRN|<PP-,>
# PRN|<PP-,>
# PRN|<,-SBAR-ADV>
# PRN|<,-SBAR-ADV>
# PRN|<SBAR-ADV-:>
# PRN|<SBAR-ADV-:>
# NN
# NN
# NN
# NN
# VBZ
# VBZ
# NN
# NN
# S
# S
# NP-SBJ
# NP-SBJ
# VBN
# VBN
# NNP
# NNP
# RB
# RB
# JJ
# JJ
# QP|<JJ-IN>
# QP|<JJ-IN>
# NNS
# NNS
# NN
# NN
# NP-SBJ-4
# NP-SBJ-4
# VBN
# VBN
# VP|<NP-,>
# VP|<NP-,>
# VP|<,-SBAR-MNR>
# VP|<,-SBAR-MNR>
# NNP
# NNP
# NP-PRD
# NP-PRD
# NP-PRD|<VBN-NN>
# NP-PRD|<VBN-NN>
# NP-PRD
# NP-PRD
# NP-PRD|<,-VP>
# NP-PRD|<,-VP>
# PP-CLR
# PP-CLR
# PP-CLR|<PRN-NP>
# PP-CLR|<PRN-NP>
# PRN
# PRN
# VBD
# VBD
# S-TPC-3
# S-TPC-3
# NP|<CC-NP>
# NP|<CC-NP>
# VBN
# VBN
# SBAR-1
# SBAR-1
# S
# S
# JJ
# JJ
# VB
# VB
# JJ
# JJ
# VP|<RB-ADVP>
# VP|<RB-ADVP>
# NNP
# NNP
# NNP
# NNP
# VP|<RB-ADJP-PRD>
# VP|<RB-ADJP-PRD>
# NNP
# NNP
# NNP
# NNP
# PRN
# PRN
# PRN|<NP-:>
# PRN|<NP-:>
# NNP
# NNP
# PRN|<:-NP>
# PRN|<:-NP>
# NN
# NN
# NNP
# NNP
# NN
# NN
# NNS
# NNS
# NP
# NP
# NP-TMP
# NP-TMP
# CD
# CD
# JJ
# JJ
# CD
# CD
# CC
# CC
# CD
# CD
# VB
# VB
# JJ
# JJ
# NNP
# NNP
# VP|<NP-NP>
# VP|<NP-NP>
# NN
# NN
# NN
# NN
# JJ
# JJ
# NN
# NN
# JJ
# JJ
# NNP
# NNP
# NNP
# NNP
# VBN
# VBN
# JJ
# JJ
# VBG
# VBG
# NN
# NN
# NN
# NN
# NN
# NN
# VB
# VB
# NN
# NN
# NN
# NN
# NN
# NN
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# VP|<``-PP-CLR>
# VP|<``-PP-CLR>
# VP|<PP-CLR-''>
# VP|<PP-CLR-''>
# NN
# NN
# NN
# NN
# NN
# NN
# JJ
# JJ
# NNS
# NNS
# NNP
# NNP
# VP|<NP-NP-TMP>
# VP|<NP-NP-TMP>
# NP
# NP
# NP|<DT-``>
# NP|<DT-``>
# JJ
# JJ
# PP
# PP
# PP|<IN-ADJP>
# PP|<IN-ADJP>
# ADJP
# ADJP
# ADJP|<RB-VBN>
# ADJP|<RB-VBN>
# VBN
# VBN
# NNP
# NNP
# JJ
# JJ
# VB
# VB
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNS
# NNS
# VBG
# VBG
# VBD
# VBD
# NN
# NN
# CD
# CD
# NN
# NN
# NNP
# NNP
# PP-PRP
# PP-PRP
# PP-PRP|<IN-``>
# PP-PRP|<IN-``>
# PP-PRP|<``-NP>
# PP-PRP|<``-NP>
# NX
# NX
# NN
# NN
# NX|<-LRB--CC>
# NX|<-LRB--CC>
# NX|<CC--RRB->
# NX|<CC--RRB->
# NX|<-RRB--NX>
# NX|<-RRB--NX>
# NX
# NX
# VBD
# VBD
# NNP
# NNP
# VP
# VP
# NP|<``-ADJP>
# NP|<``-ADJP>
# NP|<ADJP-''>
# NP|<ADJP-''>
# NP|<''-VBG>
# NP|<''-VBG>
# VBG
# VBG
# NNS
# NNS
# VP
# VP
# VP|<``-ADVP-MNR>
# VP|<``-ADVP-MNR>
# VP|<ADVP-MNR-''>
# VP|<ADVP-MNR-''>
# RB
# RB
# NN
# NN
# NP|<ADJP-''>
# NP|<ADJP-''>
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NP|<JJ-ADJP>
# NP|<JJ-ADJP>
# ADJP
# ADJP
# ADJP|<,-NNP>
# ADJP|<,-NNP>
# ADJP|<NNP-JJ>
# ADJP|<NNP-JJ>
# JJ
# JJ
# VBN
# VBN
# NP
# NP
# NNS
# NNS
# NNS
# NNS
# NNP
# NNP
# NP|<NNP-.>
# NP|<NNP-.>
# NNP
# NNP
# NP|<.-NN>
# NP|<.-NN>
# NP|<NN-NN>
# NP|<NN-NN>
# NN
# NN
# VBG
# VBG
# VP
# VP
# NP|<NNS-NN>
# NP|<NNS-NN>
# VBG
# VBG
# CD
# CD
# NN
# NN
# NP|<VBN-JJ>
# NP|<VBN-JJ>
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<NN-S>
# NP-SBJ-1|<NN-S>
# NNS
# NNS
# JJ
# JJ
# NNS
# NNS
# VBG
# VBG
# S
# S
# VB
# VB
# NP
# NP
# NP|<PP-SBAR-2>
# NP|<PP-SBAR-2>
# NN
# NN
# VBZ
# VBZ
# NNP
# NNP
# PP-TMP
# PP-TMP
# UCP
# UCP
# UCP|<CC-ADVP>
# UCP|<CC-ADVP>
# VB
# VB
# NN
# NN
# NNS
# NNS
# JJ
# JJ
# CD
# CD
# NNP
# NNP
# NP-LOC|<,-NNP>
# NP-LOC|<,-NNP>
# NP-LOC|<NNP-,>
# NP-LOC|<NNP-,>
# NP|<PP-,>
# NP|<PP-,>
# NN
# NN
# NN
# NN
# CD
# CD
# VB
# VB
# VBP
# VBP
# WHNP-1
# WHNP-1
# PRN
# PRN
# PRN|<CC-WHNP>
# PRN|<CC-WHNP>
# PRN|<WHNP-,>
# PRN|<WHNP-,>
# NN
# NN
# NNP
# NNP
# NP
# NP
# NN
# NN
# VBD
# VBD
# VP|<SBAR-,>
# VP|<SBAR-,>
# VP
# VP
# JJ
# JJ
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# VP
# VP
# VBP
# VBP
# VB
# VB
# NP+QP|<IN-CD>
# NP+QP|<IN-CD>
# NP+QP|<CD-TO>
# NP+QP|<CD-TO>
# CD
# CD
# NP+QP|<TO-CD>
# NP+QP|<TO-CD>
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# VP
# VP
# VB
# VB
# NN
# NN
# ADVP-TMP
# ADVP-TMP
# ADVP-TMP|<DT-NN>
# ADVP-TMP|<DT-NN>
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# NN
# NN
# VBN
# VBN
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NP|<NNS-NN>
# NP|<NNS-NN>
# NP-SBJ
# NP-SBJ
# NP
# NP
# NNP
# NNP
# NNP
# NNP
# NP-SBJ|<PRN-,>
# NP-SBJ|<PRN-,>
# NNP
# NNP
# CD
# CD
# CD
# CD
# NP|<RB-VBN>
# NP|<RB-VBN>
# VBN
# VBN
# NNP
# NNP
# JJ
# JJ
# ADVP-LOC
# ADVP-LOC
# ADVP
# ADVP
# NN
# NN
# NN
# NN
# NNP
# NNP
# NN
# NN
# S
# S
# VP|<NP-NP>
# VP|<NP-NP>
# VP|<NP-PP>
# VP|<NP-PP>
# NP
# NP
# NN
# NN
# NP|<PP-DIR-PP-DIR>
# NP|<PP-DIR-PP-DIR>
# NP|<NNP-,>
# NP|<NNP-,>
# S
# S
# JJ
# JJ
# S|<,-NP-SBJ-5>
# S|<,-NP-SBJ-5>
# S|<NP-SBJ-5-VP>
# S|<NP-SBJ-5-VP>
# PP
# PP
# VP
# VP
# VP|<SBAR-ADVP-PRP>
# VP|<SBAR-ADVP-PRP>
# JJ
# JJ
# JJ
# JJ
# NN
# NN
# VBG
# VBG
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# NNS
# NNS
# S
# S
# NN
# NN
# NN
# NN
# S|<,-NP-SBJ>
# S|<,-NP-SBJ>
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# NN
# NN
# VBD
# VBD
# NN
# NN
# JJ
# JJ
# JJ
# JJ
# NNP
# NNP
# VBZ
# VBZ
# NNP
# NNP
# VP
# VP
# VBG
# VBG
# VBD
# VBD
# NP|<NN-CD>
# NP|<NN-CD>
# NP|<CD--LRB->
# NP|<CD--LRB->
# NP|<-LRB--NN>
# NP|<-LRB--NN>
# NP|<NN--RRB->
# NP|<NN--RRB->
# NN
# NN
# NP|<-RRB--NN>
# NP|<-RRB--NN>
# NP|<NN-,>
# NP|<NN-,>
# NN
# NN
# VBZ
# VBZ
# VP|<NP-ADVP-MNR>
# VP|<NP-ADVP-MNR>
# VP|<ADVP-MNR-PP-DTV>
# VP|<ADVP-MNR-PP-DTV>
# RB
# RB
# SBAR-ADV
# SBAR-ADV
# NN
# NN
# VP
# VP
# VBN
# VBN
# NNP
# NNP
# NNP
# NNP
# VB
# VB
# CD
# CD
# VP
# VP
# VP|<PP-LOC-,>
# VP|<PP-LOC-,>
# PP-LOC
# PP-LOC
# PP-LOC|<NP-ADVP>
# PP-LOC|<NP-ADVP>
# VP|<,-NP-PRD>
# VP|<,-NP-PRD>
# NP
# NP
# NP
# NP
# PP-PRD
# PP-PRD
# NNS
# NNS
# JJ
# JJ
# JJ
# JJ
# VP|<S-PP>
# VP|<S-PP>
# JJ
# JJ
# NNP
# NNP
# NNP
# NNP
# NP
# NP
# VBD
# VBD
# PP-DIR
# PP-DIR
# VBG
# VBG
# NP
# NP
# NP|<NN-:>
# NP|<NN-:>
# NP|<:-NNP>
# NP|<:-NNP>
# CD
# CD
# VBG
# VBG
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# NN
# NN
# VBG
# VBG
# NP
# NP
# ADVP-LOC
# ADVP-LOC
# PP
# PP
# PP|<CC-PP>
# PP|<CC-PP>
# PP|<PP-NP-2>
# PP|<PP-NP-2>
# NP-2
# NP-2
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# ADJP
# ADJP
# VBN
# VBN
# NN
# NN
# VP|<NP-CLR-PP-CLR>
# VP|<NP-CLR-PP-CLR>
# NP-CLR
# NP-CLR
# NN
# NN
# NP
# NP
# RB
# RB
# JJ
# JJ
# NP|<''-NN>
# NP|<''-NN>
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# SBAR-TMP
# SBAR-TMP
# NP-SBJ
# NP-SBJ
# VBN
# VBN
# NN
# NN
# JJ
# JJ
# NN
# NN
# NP
# NP
# NN
# NN
# NN
# NN
# VP
# VP
# VP|<NP-ADVP-LOC-CLR>
# VP|<NP-ADVP-LOC-CLR>
# ADVP-LOC-CLR
# ADVP-LOC-CLR
# NN
# NN
# VBD
# VBD
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# JJ
# JJ
# JJ
# JJ
# NN
# NN
# NP-SBJ
# NP-SBJ
# NP-SBJ|<NNP-NNP>
# NP-SBJ|<NNP-NNP>
# NP-SBJ|<NNP-''>
# NP-SBJ|<NNP-''>
# JJ
# JJ
# NNS
# NNS
# NN
# NN
# NNS
# NNS
# NN
# NN
# NP-TMP
# NP-TMP
# VBD
# VBD
# NN
# NN
# NNS
# NNS
# NP
# NP
# NNPS
# NNPS
# NNS
# NNS
# NP-SBJ
# NP-SBJ
# VP
# VP
# UCP-PRD
# UCP-PRD
# VBG
# VBG
# UCP-PRD|<,-CC>
# UCP-PRD|<,-CC>
# UCP-PRD|<CC-ADJP-PRD>
# UCP-PRD|<CC-ADJP-PRD>
# JJ
# JJ
# JJ
# JJ
# ADVP
# ADVP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NNP
# NNP
# NN
# NN
# NN
# NN
# VBN
# VBN
# VBN
# VBN
# VBG
# VBG
# NP|<NP-''>
# NP|<NP-''>
# NNS
# NNS
# VBP
# VBP
# NN
# NN
# NP|<NN--RRB->
# NP|<NN--RRB->
# NP|<-RRB--JJ>
# NP|<-RRB--JJ>
# WHNP
# WHNP
# NNS
# NNS
# VP
# VP
# VP|<NP-CLR-PP>
# VP|<NP-CLR-PP>
# VP
# VP
# JJ
# JJ
# JJ
# JJ
# NNS
# NNS
# NP
# NP
# PP-PRD
# PP-PRD
# PP-PRD|<IN-S-NOM>
# PP-PRD|<IN-S-NOM>
# VBG
# VBG
# NNS
# NNS
# VP
# VP
# VP|<PRT-S-PRP-CLR>
# VP|<PRT-S-PRP-CLR>
# RP
# RP
# VP|<S-PRP-CLR-ADVP-TMP>
# VP|<S-PRP-CLR-ADVP-TMP>
# VB
# VB
# JJ
# JJ
# NNS
# NNS
# NP-SBJ|<,-PP>
# NP-SBJ|<,-PP>
# NP-SBJ|<PP-NP>
# NP-SBJ|<PP-NP>
# NNP
# NNP
# NNS
# NNS
# VP
# VP
# JJ
# JJ
# SQ
# SQ
# SQ|<NP-SBJ-2-RB>
# SQ|<NP-SBJ-2-RB>
# SQ|<RB-VP>
# SQ|<RB-VP>
# VP
# VP
# SINV
# SINV
# PP-LOC-3
# PP-LOC-3
# PP-LOC-3|<CC-IN>
# PP-LOC-3|<CC-IN>
# PP-LOC-3|<IN-NP>
# PP-LOC-3|<IN-NP>
# VP
# VP
# NN
# NN
# WRB
# WRB
# VBG
# VBG
# VP|<CC-VP>
# VP|<CC-VP>
# VP|<VP-ADVP-TMP>
# VP|<VP-ADVP-TMP>
# VP
# VP
# VBG
# VBG
# VP|<,-VBG>
# VP|<,-VBG>
# VBG
# VBG
# NN
# NN
# NN
# NN
# NP|<DT-NN>
# NP|<DT-NN>
# WHNP-1
# WHNP-1
# WHNP-1|<JJ-NN>
# WHNP-1|<JJ-NN>
# WHNP-1|<NN-NNS>
# WHNP-1|<NN-NNS>
# WHNP-1|<NNS-CC>
# WHNP-1|<NNS-CC>
# WHNP-1|<CC-NNS>
# WHNP-1|<CC-NNS>
# VBP
# VBP
# VBP
# VBP
# NNP
# NNP
# VP|<NP-PRD-,>
# VP|<NP-PRD-,>
# NP|<CC-NN>
# NP|<CC-NN>
# NNP
# NNP
# VP|<,-NP-TMP>
# VP|<,-NP-TMP>
# CD
# CD
# JJ
# JJ
# NNP
# NNP
# VP
# VP
# VP|<PP-MNR-S>
# VP|<PP-MNR-S>
# VB
# VB
# S
# S
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# VBN
# VBN
# VP|<NP-PP-CLR>
# VP|<NP-PP-CLR>
# VP|<PP-CLR-SBAR-PRP-3>
# VP|<PP-CLR-SBAR-PRP-3>
# JJ
# JJ
# NNS
# NNS
# SBAR-PRP-3
# SBAR-PRP-3
# VP|<VB-NP>
# VP|<VB-NP>
# VB
# VB
# S-TPC-3
# S-TPC-3
# NNS
# NNS
# NN
# NN
# VB
# VB
# JJ
# JJ
# NP
# NP
# NNS
# NNS
# VBG
# VBG
# NN
# NN
# NNS
# NNS
# JJ
# JJ
# VB
# VB
# NP
# NP
# NP|<VBG-QP>
# NP|<VBG-QP>
# NP|<QP-NN>
# NP|<QP-NN>
# CD
# CD
# NP-SBJ
# NP-SBJ
# NP-PRD
# NP-PRD
# NP-PRD|<NNP-NNP>
# NP-PRD|<NNP-NNP>
# NNPS
# NNPS
# VBD
# VBD
# NP
# NP
# NP|<-NONE--NNS>
# NP|<-NONE--NNS>
# NNP
# NNP
# NP-SBJ-2
# NP-SBJ-2
# NP-SBJ-2|<NNS-S>
# NP-SBJ-2|<NNS-S>
# VBN
# VBN
# NP
# NP
# UCP|<CC-NN>
# UCP|<CC-NN>
# UCP|<NN-NN>
# UCP|<NN-NN>
# S-TPC-3
# S-TPC-3
# S-TPC-3|<,-NP-SBJ-2>
# S-TPC-3|<,-NP-SBJ-2>
# S-TPC-3|<NP-SBJ-2-VP>
# S-TPC-3|<NP-SBJ-2-VP>
# VB
# VB
# NNP
# NNP
# NNP
# NNP
# VBD
# VBD
# JJ
# JJ
# NNP
# NNP
# VBD
# VBD
# VP
# VP
# VP|<VBD-NP-TMP>
# VP|<VBD-NP-TMP>
# VBD
# VBD
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# NN
# NN
# CD
# CD
# NN
# NN
# NN
# NN
# NNP
# NNP
# NN
# NN
# NN
# NN
# S-TPC-3
# S-TPC-3
# JJ
# JJ
# NN
# NN
# NN
# NN
# NN
# NN
# NNS
# NNS
# VBD
# VBD
# NN
# NN
# NP
# NP
# NP-ADV
# NP-ADV
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<NNP-NN>
# NP-SBJ-1|<NNP-NN>
# NNP
# NNP
# CD
# CD
# VP|<,-ADVP-CLR>
# VP|<,-ADVP-CLR>
# VP|<ADVP-CLR-,>
# VP|<ADVP-CLR-,>
# NNS
# NNS
# NP-LGS
# NP-LGS
# JJ
# JJ
# ADJP
# ADJP
# VBN
# VBN
# NN
# NN
# SBAR-ADV
# SBAR-ADV
# VP
# VP
# VP|<NP-PP-TMP>
# VP|<NP-PP-TMP>
# VP|<PP-TMP-ADVP-LOC>
# VP|<PP-TMP-ADVP-LOC>
# RB
# RB
# JJ
# JJ
# CD
# CD
# JJ
# JJ
# NNP
# NNP
# NP|<NNP-NN>
# NP|<NNP-NN>
# JJ
# JJ
# NN
# NN
# NNS
# NNS
# NN
# NN
# NNS
# NNS
# NN
# NN
# NNS
# NNS
# NNS
# NNS
# VBN
# VBN
# NNS
# NNS
# VBG
# VBG
# NN
# NN
# NN
# NN
# VP
# VP
# VP|<NP-EXT-NP-TMP>
# VP|<NP-EXT-NP-TMP>
# NN
# NN
# VBG
# VBG
# NN
# NN
# VB
# VB
# VBP
# VBP
# VP|<PP-TMP-,>
# VP|<PP-TMP-,>
# NP
# NP
# VP|<PP-CLR-PP-TMP>
# VP|<PP-CLR-PP-TMP>
# SBAR-ADV
# SBAR-ADV
# NN
# NN
# VP|<ADJP-PRD-NP-TMP>
# VP|<ADJP-PRD-NP-TMP>
# NNP
# NNP
# SBAR
# SBAR
# VBG
# VBG
# NNP
# NNP
# RB
# RB
# NNS
# NNS
# JJ
# JJ
# VBG
# VBG
# NNS
# NNS
# VBP
# VBP
# S|<,-NP-SBJ-2>
# S|<,-NP-SBJ-2>
# VP
# VP
# VP
# VP
# VP|<ADJP-ADV-ADVP-LOC>
# VP|<ADJP-ADV-ADVP-LOC>
# ADJP-ADV
# ADJP-ADV
# RB
# RB
# NNP
# NNP
# NNPS
# NNPS
# NNP
# NNP
# VBZ
# VBZ
# VP|<NP-ADVP-TMP>
# VP|<NP-ADVP-TMP>
# VP|<ADVP-TMP-PP-PRP>
# VP|<ADVP-TMP-PP-PRP>
# NNS
# NNS
# NN
# NN
# VP
# VP
# VBD
# VBD
# S
# S
# S|<NP-TMP-PP-LOC-3>
# S|<NP-TMP-PP-LOC-3>
# S|<PP-LOC-3-VP>
# S|<PP-LOC-3-VP>
# PP-LOC-3
# PP-LOC-3
# VB
# VB
# PP
# PP
# VP
# VP
# VP|<NP-EXT-SBAR-TMP>
# VP|<NP-EXT-SBAR-TMP>
# VBN
# VBN
# JJ
# JJ
# VBP
# VBP
# NP-SBJ
# NP-SBJ
# NP-SBJ|<VBG-JJ>
# NP-SBJ|<VBG-JJ>
# VBG
# VBG
# JJ
# JJ
# NP-SBJ-1|<NN-NNS>
# NP-SBJ-1|<NN-NNS>
# NP-SBJ-1|<NNS-CC>
# NP-SBJ-1|<NNS-CC>
# VB
# VB
# S
# S
# VP
# VP
# VP|<NP-ADV-S-CLR>
# VP|<NP-ADV-S-CLR>
# NN
# NN
# CD
# CD
# NN
# NN
# VP|<NP-TMP-PP>
# VP|<NP-TMP-PP>
# NN
# NN
# VB
# VB
# NNS
# NNS
# VBN
# VBN
# NP-LGS
# NP-LGS
# NP-LGS|<CD-NN>
# NP-LGS|<CD-NN>
# VBG
# VBG
# VBG
# VBG
# VP
# VP
# VBP
# VBP
# VB
# VB
# VBN
# VBN
# VP|<ADVP-DIR-NP>
# VP|<ADVP-DIR-NP>
# NN
# NN
# VBZ
# VBZ
# CD
# CD
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VBZ
# VBZ
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# VP
# VP
# VP|<PP-DIR-PP-MNR>
# VP|<PP-DIR-PP-MNR>
# VB
# VB
# VP|<NP-PP-MNR>
# VP|<NP-PP-MNR>
# VP|<PP-MNR-PP-DIR>
# VP|<PP-MNR-PP-DIR>
# NN
# NN
# NN
# NN
# NNS
# NNS
# NNPS
# NNPS
# NNP
# NNP
# VB
# VB
# NP
# NP
# VBG
# VBG
# VP|<RB-ADJP-PRD>
# VP|<RB-ADJP-PRD>
# VBN
# VBN
# ADVP-TMP
# ADVP-TMP
# VBN
# VBN
# NP-LGS
# NP-LGS
# NP-LGS|<CONJP-NP>
# NP-LGS|<CONJP-NP>
# FRAG
# FRAG
# FRAG|<NP-TMP-:>
# FRAG|<NP-TMP-:>
# NN
# NN
# NP-SBJ-1
# NP-SBJ-1
# NP-SBJ-1|<JJ-ADJP>
# NP-SBJ-1|<JJ-ADJP>
# NN
# NN
# VBG
# VBG
# NN
# NN
# CD
# CD
# ADVP-CLR
# ADVP-CLR
# ADVP-CLR|<NP-PP-LOC>
# ADVP-CLR|<NP-PP-LOC>
# CD
# CD
# NN
# NN
# NP-TMP-CLR
# NP-TMP-CLR
# NNP
# NNP
# NNPS
# NNPS
# NP-SBJ
# NP-SBJ
# CD
# CD
# CD
# CD
# NN
# NN
# CD
# CD
# CD
# CD
# NN
# NN
# VP
# VP
# VP|<PP-PRD-PP-CLR>
# VP|<PP-PRD-PP-CLR>
# CD
# CD
# CD
# CD
# JJ
# JJ
# NP-SBJ-1|<,-NP>
# NP-SBJ-1|<,-NP>
# NP-SBJ-1|<NP-PP>
# NP-SBJ-1|<NP-PP>
# VBN
# VBN
# VP|<NP-PP>
# VP|<NP-PP>
# VP|<PP-SBAR-ADV>
# VP|<PP-SBAR-ADV>
# VP|<SBAR-ADV-,>
# VP|<SBAR-ADV-,>
# NNP
# NNP
# NNPS
# NNPS
# NNS
# NNS
# VP
# VP
# VP|<ADVP-MNR-,>
# VP|<ADVP-MNR-,>
# NN
# NN
# NP
# NP
# NP|<RB-JJ>
# NP|<RB-JJ>
# NNS
# NNS
# VP
# VP
# VP|<PP-EXT-PP-CLR>
# VP|<PP-EXT-PP-CLR>
# CD
# CD
# CD
# CD
# NNS
# NNS
# VB
# VB
# CD
# CD
# CD
# CD
# S-TPC-3
# S-TPC-3
# S-TPC-3|<,-NP-SBJ-2>
# S-TPC-3|<,-NP-SBJ-2>
# S-TPC-3|<NP-SBJ-2-NP-TMP>
# S-TPC-3|<NP-SBJ-2-NP-TMP>
# NNP
# NNP
# NNP
# NNP
# JJ
# JJ
# NNP
# NNP
# NNP
# NNP
# S-TPC-3|<NP-TMP-VP>
# S-TPC-3|<NP-TMP-VP>
# VP
# VP
# VP|<NP-NP-TMP-CLR>
# VP|<NP-NP-TMP-CLR>
# NNS
# NNS
# NN
# NN
# JJ
# JJ
# SBAR
# SBAR
# SINV
# SINV
# ADJP-PRD-TPC-1
# ADJP-PRD-TPC-1
# ADJP-PRD-TPC-1|<JJ-PP>
# ADJP-PRD-TPC-1|<JJ-PP>
# NN
# NN
# S-2
# S-2
# JJ
# JJ
# NN
# NN
# VBN
# VBN
# SINV-4
# SINV-4
# VP-TPC-3
# VP-TPC-3
# VP-TPC-3|<VBG-PP-CLR>
# VP-TPC-3|<VBG-PP-CLR>
# SINV-4|<PRN-VP>
# SINV-4|<PRN-VP>
# SINV-4|<VP-NP-SBJ>
# SINV-4|<VP-NP-SBJ>
# SINV-4|<NP-SBJ-.>
# SINV-4|<NP-SBJ-.>
# NP
# NP
# VBZ
# VBZ
# NP|<VBG-NNS>
# NP|<VBG-NNS>
# SBAR-NOM
# SBAR-NOM
# CD
# CD
# NNS
# NNS
# CD
# CD
# VBZ
# VBZ
# NNP
# NNP
# NNP
# NNP
# JJ
# JJ
# VBN
# VBN
# NN
# NN
# VP
# VP
# NN
# NN
# NNP
# NNP
# NNP
# NNP
# NP-SBJ-1
# NP-SBJ-1
# JJ
# JJ
# VBG
# VBG
# JJ
# JJ
# NNS
# NNS
# S|<ADVP-,>
# S|<ADVP-,>
# NP-SBJ-3
# NP-SBJ-3
# NP-SBJ-3|<NN-NN>
# NP-SBJ-3|<NN-NN>
# NNP
# NNP
# NN
# NN
# VBP
# VBP
# NNS
# NNS
# NP
# NP
# NNP
# NNP
# WHNP-51
# WHNP-51
# CD
# CD
# NN
# NN
# NNP
# NNP
# PP-CLR
# PP-CLR
# S
# S
# NP-SBJ-3
# NP-SBJ-3
# VBG
# VBG
# NNP
# NNP
# CD
# CD
# NNP
# NNP
# VBD
# VBD
# VP
# VP
# VP|<ADVP-CLR-,>
# VP|<ADVP-CLR-,>
# VP|<,-PP-CLR>
# VP|<,-PP-CLR>
# CD
# CD
# VBD
# VBD
# NNS
# NNS
# NNP
# NNP
# NP-LGS
# NP-LGS
# JJR
# JJR
# NP
# NP
# NP|<ADJP-NX>
# NP|<ADJP-NX>
# NN
# NN
# NX
# NX
# JJ
# JJ
# NX|<VBN-NN>
# NX|<VBN-NN>
# VBN
# VBN
# JJ
# JJ
# JJ
# JJ
# NP-PRD
# NP-PRD
# NP-SBJ-1
# NP-SBJ-1
# NNP
# NNP
# CD
# CD
# NP-SBJ-1|<NNP-NNP>
# NP-SBJ-1|<NNP-NNP>
# NP-SBJ-1|<NNP-CC>
# NP-SBJ-1|<NNP-CC>
# NP-SBJ-1|<CC-NNP>
# NP-SBJ-1|<CC-NNP>
# NN
# NN
# VBG
# VBG
# NNP
# NNP
# NNS
# NNS
# VP
# VP
# VP|<NP-PP-EXT>
# VP|<NP-PP-EXT>
# CD
# CD
# CD
# CD
# NP-LGS
# NP-LGS
# NNP
# NNP
# CD
# CD
# VP
# VP
# PP-PRD
# PP-PRD
# ADJP
# ADJP
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# CD
# NNP
# NNP
# NP-SBJ-1|<NP-,>
# NP-SBJ-1|<NP-,>
# NP-SBJ-1|<,-ADVP-TMP>
# NP-SBJ-1|<,-ADVP-TMP>
# NP-SBJ-1|<ADVP-TMP-NP>
# NP-SBJ-1|<ADVP-TMP-NP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NN
# NN
# UCP|<,-JJ>
# UCP|<,-JJ>
# UCP|<JJ-CC>
# UCP|<JJ-CC>
# UCP|<CC-NN>
# UCP|<CC-NN>
# UCP|<NN-NNS>
# UCP|<NN-NNS>
# NNP
# NNP
# NP-SBJ
# NP-SBJ
# NN
# NN
# NP-SBJ
# NP-SBJ
# NNP
# NNP
# NX
# NX
# NX|<NNP-PP>
# NX|<NNP-PP>
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# VB
# VB
# NN
# NN
# VB
# VB
# VP
# VP
# VP|<SBAR-S-PRP>
# VP|<SBAR-S-PRP>
# RB
# RB
# NNP
# NNP
# PRN|<NP-LOC--RRB->
# PRN|<NP-LOC--RRB->
# PRN|<-RRB--,>
# PRN|<-RRB--,>
# NNS
# NNS
# NNS
# NNS
# NN
# NN
# NN
# NN
# VBZ
# VBZ
# JJ
# JJ
# VBD
# VBD
# QP|<IN-DT>
# QP|<IN-DT>
# VP
# VP
# VP|<PP-CLR-PP-TMP-1>
# VP|<PP-CLR-PP-TMP-1>
# NNP
# NNP
# S|<,-CC>
# S|<,-CC>
# S|<CC-``>
# S|<CC-``>
# VBN
# VBN
# NP-SBJ
# NP-SBJ
# JJ
# JJ
# VBZ
# VBZ
# VP|<NP-NP>
# VP|<NP-NP>
# VP
# VP
# NP-PRD
# NP-PRD
# JJ
# JJ
# NP-PRD|<PP-''>
# NP-PRD|<PP-''>
# NNP
# NNP
# NN
# NN
# NNS
# NNS
# NNP
# NNP
# NNP
# NNP

# %%
Unary={}
Binary={}
for i in range(len(grammar.productions())):
    if len(grammar.productions()[i].rhs())==1:
        A=str(grammar.productions()[i]).split(' -> ')[0]
        BC=str(grammar.productions()[i]).split(' -> ')[1].split()[:-1]
        if A in Unary.keys():
            Unary[A].append(BC[0])
        else:
            Unary[A]=[]
            Unary[A].append(BC[0])
    else:
        A=str(grammar.productions()[i]).split(' -> ')[0]
        BC=str(grammar.productions()[i]).split(' -> ')[1].split()[:-1]
        if A in Binary.keys():
            Binary[A].append(BC)
        else:
            Binary[A]=[]
            Binary[A].append(BC)

# %%
Binary
# Out:
# {'S': [['NP-SBJ', 'S|<VP-.>'],
#   ['NP-SBJ-1', 'S|<VP-.>'],
#   ['NP-SBJ', 'NP-PRD'],
#   ['S-TPC-1', 'S|<,-NP-SBJ>'],
#   ['S-TPC-2', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ', 'VP'],
#   ['SBAR-ADV', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ-2', 'VP'],
#   ['NP-SBJ-1', 'VP'],
#   ['PP-LOC', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ-4', 'VP'],
#   ['NP-SBJ-5', 'VP'],
#   ['PP-TMP', 'S|<,-NP-SBJ>'],
#   ['PP-TMP', 'S|<,-NP-SBJ-6>'],
#   ['NP-SBJ-7', 'S|<VP-.>'],
#   ['NP-SBJ-8', 'VP'],
#   ['``', 'S|<CC-NP-SBJ-1>'],
#   ['NP-SBJ-9', 'S|<VP-.>'],
#   ['NP-SBJ', 'S|<,-PP>'],
#   ['PP', 'S|<,-NP-SBJ-1>'],
#   ['ADVP', 'S|<,-NP-SBJ>'],
#   ['S', 'S|<:-S>'],
#   ['NP-SBJ-10', 'S|<VP-.>'],
#   ['NP-SBJ-11', 'S|<VP-.>'],
#   ['S', 'S|<,-CC>'],
#   ['NP-SBJ-12', 'S|<VP-.>'],
#   ['PP-LOC', 'S|<NP-SBJ-VP>'],
#   ['ADVP-TMP', 'S|<,-NP-SBJ>'],
#   ['SBAR-TMP', 'S|<,-NP-SBJ>'],
#   ['CC', 'S|<NP-SBJ-1-VP>'],
#   ['PP', 'S|<,-NP-SBJ>'],
#   ['NP-TMP', 'S|<,-PP>'],
#   ['S', 'S|<,-IN>'],
#   ['ADVP-TMP', 'S|<,-PP>'],
#   ['S-ADV', 'S|<,-NP-SBJ-1>'],
#   ['NP-SBJ', 'S|<ADVP-VP>'],
#   ['ADVP-LOC', 'S|<,-NP-SBJ-1>'],
#   ['NP-TMP', 'S|<,-NP-SBJ>'],
#   ['S-ADV', 'S|<,-NP-SBJ-2>'],
#   ['CC', 'S|<PP-TMP-,>'],
#   ['NP-SBJ-1', 'S|<,-S>'],
#   ['PP-TMP', 'S|<,-NP-SBJ-1>'],
#   ['PP-TMP', 'S|<NP-SBJ-VP>'],
#   ['SBAR-NOM-SBJ', 'VP'],
#   ['S', 'S|<CC-S>'],
#   ['NP-SBJ=2', 'ADVP-PRD-LOC=3'],
#   ['NP-SBJ-4', 'S|<VP-.>'],
#   ['NP-SBJ-13', 'VP'],
#   ['NP-SBJ-14', 'VP'],
#   ['``', 'S|<SBAR-TMP-,>'],
#   ['S-TPC-2', "S|<,-''>"],
#   ['``', 'S|<NP-SBJ-VP>'],
#   ['S-1', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ', 'S|<,-VP>'],
#   ['``', 'S|<S-TPC-1-,>'],
#   ['NP-SBJ-15', 'S|<VP-.>'],
#   ['NP-SBJ-1', 'S|<ADVP-TMP-VP>'],
#   ['``', 'S|<S-TPC-2-,>'],
#   ['NP-SBJ-16', 'S|<VP-.>'],
#   ['S-NOM-SBJ', 'VP'],
#   ['PP-LOC', 'S|<NP-TMP-,>'],
#   ['NP-SBJ-17', 'S|<VP-.>'],
#   ['CC', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ', 'ADJP-PRD'],
#   ['NP-SBJ', 'S|<ADVP-TMP-VP>'],
#   ['NP-TMP', 'S|<NP-SBJ-1-VP>'],
#   ['NP-SBJ-18', 'VP'],
#   ['SBAR', 'S|<,-NP-SBJ-3>'],
#   ['PP', 'S|<NP-SBJ-20-VP>'],
#   ['NP-SBJ-21', 'VP'],
#   ['``', 'S|<S-CC>'],
#   ['NP-SBJ', 'S|<RB-VP>'],
#   ['NP-SBJ-22', 'VP'],
#   ['PP-LOC', 'S|<,-NP-SBJ-1>'],
#   ['NP-SBJ-23', 'S|<VP-.>'],
#   ['NP-SBJ', 'S|<PP-PRD-S>'],
#   ['PP', 'S|<,-NP-SBJ-2>'],
#   ['PP', 'S|<,-SBAR-ADV+SINV>'],
#   ['NP-SBJ-24', 'VP'],
#   ['S-ADV', 'S|<,-NP-SBJ-25>'],
#   ['PP-LOC', 'S|<,-NP-SBJ-26>'],
#   ['NP-SBJ-27', 'S|<VP-.>'],
#   ['NP-SBJ-28', 'S|<VP-.>'],
#   ['ADVP-TMP', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ-29', 'S|<VP-.>'],
#   ['NP-SBJ-1', 'S|<,-S-ADV>'],
#   ['NP-SBJ-2', 'S|<VP-.>'],
#   ['NP-SBJ-1', 'ADJP-PRD'],
#   ['NP-SBJ', 'S|<VP-PP-LOC>'],
#   ['NP-SBJ-3', 'VP'],
#   ['NP-SBJ-31', 'VP'],
#   ['-LRB-', 'S|<PP-TMP-,>'],
#   ['NP-SBJ-32', 'S|<VP-.>'],
#   ['NP-TMP', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ-1', 'S|<PRN-VP>'],
#   ['NP-SBJ-33', 'VP'],
#   ['CC', 'S|<NP-SBJ-PRN>'],
#   ['NP-SBJ', 'S|<PP-TMP-VP>'],
#   ['NP-SBJ-34', 'S|<VP-.>'],
#   ['NP-SBJ-35', 'VP'],
#   ['NP-SBJ=3', 'NP-TMP=2'],
#   ['NP-SBJ-36', 'VP'],
#   ['ADVP-TMP', 'S|<,-NP-SBJ-37>'],
#   ['NP-SBJ', 'PP-PRD'],
#   ['NP-SBJ-38', 'S|<VP-.>'],
#   ['NP-SBJ-39', 'S|<VP-.>'],
#   ['NP-SBJ-40', 'VP'],
#   ['NP-SBJ-41', 'S|<VP-.>'],
#   ['NP-SBJ-42', 'S|<VP-.>'],
#   ['ADVP', 'S|<,-NP-SBJ-1>'],
#   ['NP-SBJ-43', 'VP'],
#   ['NP-SBJ-2', 'S|<ADVP-VP>'],
#   ['NP-SBJ-44', 'S|<VP-.>'],
#   ['NP-SBJ', 'S|<PRN-VP>'],
#   ['NP-SBJ-45', 'S|<VP-.>'],
#   ['NP-TMP', 'S|<,-NP-SBJ-46>'],
#   ['SBAR-TMP', 'S|<,-NP-SBJ-1>'],
#   ['SBAR-TMP', 'S|<PRN-S>'],
#   ['CC', 'S|<NP-SBJ-47-VP>'],
#   ['SBAR-NOM-SBJ', 'S|<VP-.>'],
#   ['NP-SBJ', 'S|<NP-TMP-VP>'],
#   ['CC', 'S|<NP-SBJ-ADVP-TMP>'],
#   ['NP-SBJ-48', 'S|<VP-.>'],
#   ['NP-MNR', 'S|<NP-SBJ-1-VP>'],
#   ['NP-SBJ-49', 'VP'],
#   ['NP-SBJ-50', 'VP'],
#   ['ADVP', 'S|<,-PP-TMP>'],
#   ['ADJP-TMP', 'S|<,-NP-SBJ>'],
#   ['CC', 'S|<NP-SBJ-51-VP>'],
#   ['NP-SBJ-52', 'VP'],
#   ['NP-SBJ', 'S|<,-ADVP>'],
#   ['``', "S|<SBARQ-TPC-1-''>"],
#   ['NP-SBJ-3', 'S|<VP-.>'],
#   ['NP-SBJ-53', 'VP'],
#   ['NP-SBJ-54', 'VP'],
#   ['NP-SBJ-1+NP', 'S|<PRN-VP>'],
#   ['NP-SBJ+NP', 'S|<VP-.>'],
#   ['SBAR-TMP', 'S|<,-NP-SBJ-2>'],
#   ['NP-SBJ-56', 'S|<VP-.>'],
#   ['PP-TPC-1', 'S|<,-S>'],
#   ['S-ADV', 'S|<,-NP-SBJ>'],
#   ['SBAR-ADV', 'S|<,-NP-SBJ-2>'],
#   ['``', "S|<NP-TTL-SBJ-''>"],
#   ['NP-SBJ-57', 'VP'],
#   ['``', "S|<NP-SBJ-''>"],
#   ['CC', 'S|<ADVP-,>'],
#   ['NP-SBJ-59', 'VP'],
#   ['NP-SBJ=1', 'PP-CLR=2'],
#   ['NP-SBJ-60', 'VP'],
#   ['NP-SBJ+QP', 'S|<VP-.>'],
#   ['NP-SBJ-61', 'VP'],
#   ['NP-SBJ-62', 'VP'],
#   ['SBAR-TMP', 'S|<,-NP-SBJ-64>'],
#   ['NP-SBJ-63', 'VP'],
#   ['NP-SBJ-67', 'VP'],
#   ['NP-SBJ-68', 'VP'],
#   ['NP-SBJ-69', 'S|<VP-.>'],
#   ['``', "S|<NP-TTL-SBJ-1-''>"],
#   ['NP-SBJ-70', 'VP'],
#   ['PP-TMP', 'S|<,-PP>'],
#   ['ADVP-TMP', 'S|<,-ADVP-TMP>'],
#   ['PP', 'S|<,-SBAR-ADV>'],
#   ['PP-LOC', 'S|<NP-SBJ-2-VP>'],
#   ['-LRB-', 'S|<NP-SBJ-ADVP>'],
#   ['ADVP-TMP', 'S|<,-SBAR-ADV>'],
#   ['NP-SBJ-72', 'VP'],
#   ['NP-SBJ-74', 'VP'],
#   ['S-PRP', 'S|<,-NP-SBJ-1>'],
#   ['ADVP', 'S|<NP-SBJ-VP>'],
#   ['SBAR-ADV', 'S|<,-S>'],
#   ['PP-TMP', "S|<,-''>"],
#   ['NP-SBJ-1', 'S|<,-PP-TMP>'],
#   ['IN', 'S|<PP-LOC-,>'],
#   ['``', 'S|<NP-SBJ-1-VP>'],
#   ['CC', 'S|<,-PP>'],
#   ['PP-TMP', 'S|<,-ADVP-TMP>'],
#   ['NP-SBJ', 'S|<VP-:>'],
#   ['CC', 'S|<ADVP-TMP-NP-SBJ>'],
#   ['S-SBJ', 'S|<,-NP-SBJ-2>'],
#   ['ADVP-TMP', 'S|<,-SBAR-TMP>'],
#   ['ADVP', 'S|<NP-TMP-,>'],
#   ['S', "S|<,-''>"],
#   ['S-1', 'S|<,-CC>'],
#   ['NP-SBJ-1', 'S|<:-VP>'],
#   ['S', 'S|<,-S>'],
#   ['ADVP', 'S|<,-PP>'],
#   ['PP-TMP', 'S|<,-PP-LOC>'],
#   ['CC', 'S|<NP-SBJ-ADVP>'],
#   ['PP-LOC', 'S|<PRN-NP-SBJ>'],
#   ['NP-SBJ', "S|<,-''>"],
#   ['PP-PRP', 'S|<,-NP-SBJ>'],
#   ['PP-TMP', 'S|<,-S-ADV>'],
#   ['PP-LOC', 'S|<,-PP>'],
#   ['NP-SBJ-1', 'S|<ADVP-VP>'],
#   ['``', 'S|<S-1-,>'],
#   ['``', 'S|<NP-SBJ-1-PRN>'],
#   ['CC', 'S|<S-NOM-SBJ-VP>'],
#   ['``', 'S|<SBAR-ADV-,>'],
#   ['NP-SBJ', 'S|<NP-PRD-S-2>'],
#   ['``', 'S|<RB-NP-SBJ>'],
#   ['NP-SBJ', 'S|<ADVP-TMP-``>'],
#   ['NP-SBJ', 'S|<:-VP>'],
#   ['PP-MNR', 'S|<,-NP-SBJ-3>'],
#   ['SBAR-TMP', 'S|<PRN-NP-SBJ>'],
#   ['NP-SBJ', 'S|<``-VP>'],
#   ['PP-PRP', 'S|<,-ADVP>'],
#   ['``', 'S|<S-,>'],
#   ['ADVP-TMP', 'S|<,-NP-SBJ-1>'],
#   ['NP-SBJ', 'ADVP-PRD'],
#   ['PP-PRP', 'S|<NP-SBJ-1-VP>'],
#   ['ADVP-TMP', 'S|<,-ADVP>'],
#   ['NP-TMP', 'S|<,-PP-TMP>'],
#   ['SBAR-PRP', 'S|<,-NP-SBJ-1>'],
#   ['``', "S|<SQ-TPC-1-''>"],
#   ['S-TPC-1', "S|<,-''>"],
#   ['PP', 'S|<NP-SBJ-VP>'],
#   ['PP-LOC', 'S|<,-ADVP-TMP>'],
#   ['NP-SBJ', 'NP-PRD-TTL'],
#   ['SBAR-ADV', 'S|<,-NP-SBJ-1>'],
#   ['CC', 'S|<NP-TTL-SBJ-VP>'],
#   ['NP-TTL-SBJ', 'S|<VP-.>'],
#   ['NP-TTL-SBJ', 'VP'],
#   ['NP-SBJ-1', 'S|<``-VP>'],
#   ['NP-TTL-SBJ', 'S|<ADVP-TMP-VP>'],
#   ['NP-TTL-SBJ-1', 'VP'],
#   ['NP-TMP', 'S|<,-NP-SBJ-1>'],
#   ['``', 'S|<S-TPC-3-,>'],
#   ['CC', 'S|<NP-SBJ-1-,>'],
#   ['UCP', 'S|<,-NP-SBJ-1>'],
#   ['ADVP', 'S|<PP-LOC-,>'],
#   ['NP-TMP', 'S|<NP-SBJ-3-VP>'],
#   ['CC', 'S|<PP-LOC-,>'],
#   ['``', 'S|<S-TPC-4-,>'],
#   ['S', 'S|<:-CC>'],
#   ['SBAR-TMP', 'S|<,-ADVP-TMP>'],
#   ['S-ADV', "S|<,-''>"],
#   ['ADVP-TMP', 'S|<NP-TMP-,>'],
#   ['PP-TMP', 'S|<,-NP-SBJ-2>'],
#   ['ADVP', 'S|<NP-SBJ-1-VP>'],
#   ['CC', 'S|<NP-SBJ-4-VP>'],
#   ['``', 'S|<PP-,>'],
#   ['ADVP-TMP', 'S|<S-CC>'],
#   ['SBAR-TMP', 'S|<NP-SBJ-1-VP>'],
#   ['PP-LOC', 'S|<PP-LOC-,>'],
#   ['PP-LOC', 'S|<PP-LOC-NP-TMP>'],
#   ['CC', 'S|<S-,>'],
#   ['NP-SBJ-76', 'VP'],
#   ['``', 'S|<PP-LOC-,>'],
#   ['NP-SBJ-78', 'VP'],
#   ['S-ADV', 'S|<,-NP-TTL-SBJ-2>'],
#   ['NP-SBJ', 'S|<``-PP-TTL>'],
#   ['PP', 'S|<,-NP-TTL-SBJ>'],
#   ['NP-SBJ-79', 'VP'],
#   ['NP-SBJ', 'NP-TTL-PRD'],
#   ['NP-SBJ-81', 'VP'],
#   ['-LRB-', 'S|<NP-SBJ-1-VP>'],
#   ['NP-SBJ-83', 'VP'],
#   ['NP-SBJ-84', 'VP'],
#   ['NP-SBJ-85', 'VP'],
#   ['NP-SBJ-86', 'S|<VP-.>'],
#   ['S-ADV', 'S|<NP-SBJ-2-VP>'],
#   ["''", 'S|<NP-SBJ-2-VP>'],
#   ['-LRB-', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ-89', 'S|<ADVP-TMP-VP>'],
#   ['NP-SBJ-90', 'VP'],
#   ['NP-SBJ-91', 'VP'],
#   ['PP-TMP', 'S|<,-NP-SBJ-92>'],
#   ['NP-SBJ-93', 'S|<VP-.>'],
#   ['PP-TMP', 'S|<NP-SBJ-2-VP>'],
#   ['NP-SBJ-94', 'VP'],
#   ['NP-SBJ-95', 'S|<VP-.>'],
#   ['NP-SBJ-96', 'S|<VP-.>'],
#   ['PP', 'S|<,-NP-SBJ-3>'],
#   ['PP-TMP', 'S|<,-ADVP>'],
#   ['``', 'S|<SBAR-NOM-SBJ-VP>'],
#   ['SBAR-TMP', 'S|<NP-SBJ-VP>'],
#   ['LST', 'S|<INTJ-,>'],
#   ['LST', 'S|<S-CC>'],
#   ['INTJ', 'S|<,-NP-SBJ>'],
#   ['LST', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ-97', 'VP'],
#   ['PP', 'S|<NP-SBJ-98-VP>'],
#   ['SBAR-TMP', 'S|<,-NP-SBJ-3>'],
#   ['NP-SBJ-1', 'S|<VP-CC>'],
#   ['NP-SBJ-99', 'VP'],
#   ['NP-SBJ-1', 'S|<VP-,>'],
#   ['NP-SBJ-100', 'VP'],
#   ['NP-SBJ', 'PP-LOC-PRD'],
#   ['CC', 'S|<NP-SBJ-101-ADVP>'],
#   ['PP-PRP', 'S|<,-NP-SBJ-102>'],
#   ['NP-SBJ-103', 'VP'],
#   ['NP-SBJ-104', 'S|<VP-.>'],
#   ['NP-SBJ-105', 'VP'],
#   ['NP-SBJ-106', 'VP'],
#   ['CC', 'S|<PP-,>'],
#   ['NP-SBJ-1', 'S|<VP-:>'],
#   ['``', 'S|<S-PRP-,>'],
#   ['NP-SBJ-107', 'VP'],
#   ['NP-SBJ-108', 'VP'],
#   ['NP-SBJ-109', 'VP'],
#   ['NP-SBJ-110', 'VP'],
#   ['NP-SBJ', 'S|<DT-VP>'],
#   ['NP-SBJ-112', 'S|<VP-.>'],
#   ['NP-SBJ-113', 'VP'],
#   ['SBAR-ADV', 'S|<NP-SBJ-ADVP>'],
#   ['NP-SBJ-114', 'VP'],
#   ['NP-SBJ-115', 'VP'],
#   ['SBAR-ADV', 'S|<:-ADVP>'],
#   ['NP-SBJ-116', 'VP'],
#   ['PP', 'S|<,-PP-LOC>'],
#   ['NP-SBJ-117', 'VP'],
#   ['NP-SBJ', 'S|<VP-PP-TMP>'],
#   ['PP', 'S|<,-ADVP>'],
#   ['NP-TMP', 'S|<,-NP-SBJ-118>'],
#   ['SBAR-PRP', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ-119', 'S|<VP-.>'],
#   ['NP-SBJ-120', 'S|<VP-.>'],
#   ['NP-SBJ-121', 'S|<VP-.>'],
#   ['S-ADV', 'S|<,-NP-SBJ-4>'],
#   ['ADVP-MNR', 'S|<NP-SBJ-VP>'],
#   ['S', 'S|<:-JJ>'],
#   ['NP-SBJ-122', 'VP'],
#   ['SBAR-LOC', 'S|<,-NP-SBJ-1>'],
#   ['``', 'S|<IN-NP-SBJ-1>'],
#   ['S-NOM-SBJ', 'ADJP-PRD'],
#   ['S', 'S|<:-NN>'],
#   ['NP-SBJ-123', 'VP'],
#   ['NP-SBJ-124', 'VP'],
#   ['VP', 'S|<NP-SBJ-:>'],
#   ['CC', 'S|<PP-NP-SBJ>'],
#   ['NP-SBJ', 'UCP-PRD'],
#   ['RB', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ-125', 'VP'],
#   ['NP-SBJ-126', 'VP'],
#   ['ADVP-TMP', 'S|<NP-TMP-NP-SBJ-1>'],
#   ['NP-SBJ-127', 'VP'],
#   ['CC', 'S|<SBAR-TMP-,>'],
#   ['NP-SBJ-128', 'VP'],
#   ['NP-SBJ-129', 'VP'],
#   ['NP-SBJ-130', 'S|<VP-.>'],
#   ['NP-SBJ-131', 'S|<ADVP-TMP-VP>'],
#   ['NP-SBJ-132', 'VP'],
#   ['PP-TMP', 'S|<PP-TMP-,>'],
#   ['NP-SBJ-133', 'VP'],
#   ['NP-SBJ-134', 'S|<VP-.>'],
#   [':', 'S|<S-:>'],
#   ['PP-TPC-2', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ-135', 'VP'],
#   ['NP-SBJ-136', 'S|<VP-.>'],
#   ['RB', 'S|<,-PP-TMP>'],
#   ['NP-SBJ', 'S|<``-NP-PRD>'],
#   ['ADVP-LOC', 'S|<PP-LOC-,>'],
#   ['NP-SBJ-137', 'VP'],
#   ['NP-SBJ-138', 'VP'],
#   ['``', 'S|<SINV-TPC-2-,>'],
#   ['NP-SBJ-139', 'VP'],
#   ['PP-TPC', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ-140', 'VP'],
#   ['NP-SBJ-141', 'VP'],
#   ['PP-TMP', 'S|<,-``>'],
#   ['``', 'S|<CC-NP-SBJ>'],
#   ['PP-TMP', 'S|<PRN-NP-SBJ>'],
#   ['S-TPC-3', 'S|<,-NP-SBJ>'],
#   ['PP', 'S|<,-``>'],
#   ['S-TPC-2', 'S|<NP-SBJ-VP>'],
#   ['RB', 'S|<,-SBAR-ADV>'],
#   ['PP-TMP', 'S|<:-NP-SBJ>'],
#   ['NP-SBJ', 'S|<,-ADVP-TMP>'],
#   ['NP-SBJ-142', 'S|<VP-.>'],
#   ['SBAR-ADV', 'S|<,-``>'],
#   ['NP-SBJ', 'S|<ADJP-PRD-NP-TMP>'],
#   ['NP-SBJ-144', 'VP'],
#   ['NP-SBJ-145', 'VP'],
#   ['S-ADV', 'S|<,-NP-SBJ-146>'],
#   ['NP-SBJ+NP', 'VP'],
#   ['NP-SBJ-147', 'VP'],
#   ['ADJP-PRD', 'SBAR-SBJ'],
#   ['ADVP', 'S|<,-SBAR-TMP>'],
#   ['ADVP-LOC', 'S|<,-PP-LOC>'],
#   ['NP-SBJ-149', 'VP'],
#   ['PP', "S|<,-''>"],
#   ['NP-SBJ-150', 'VP'],
#   ['NP-SBJ-151', 'VP'],
#   ['ADVP', 'S|<,-NP-SBJ-152>'],
#   ['NP-SBJ-153', 'S|<VP-.>'],
#   ['ADVP', 'S|<,-NP-SBJ-154>'],
#   ['NP-SBJ-155', 'S|<ADVP-VP>'],
#   ['NP-SBJ-156', 'S|<ADVP-VP>'],
#   ['NP-SBJ-157', 'S|<VP-.>'],
#   ['PP-MNR', 'S|<,-NP-SBJ-1>'],
#   ['NP-SBJ-158', 'VP'],
#   ['NP-SBJ-3', 'S|<VP-:>'],
#   ['``', 'S|<NP-SBJ-ADVP-TMP>'],
#   ['NP-SBJ-159', 'VP'],
#   ['NP-SBJ', 'S|<PRN-ADVP>'],
#   ['CC', 'S|<PP-PRP-,>'],
#   ['NP-SBJ-160', 'VP'],
#   ['-LRB-', 'S|<NP-SBJ-NP-TMP>'],
#   ['NP-SBJ', 'S|<ADVP-LOC-:>'],
#   ['NP-SBJ-162', 'S|<VP-.>'],
#   ['IN', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ-163', 'VP'],
#   ['CC', 'S|<``-SBAR-PRP>'],
#   ['NP-SBJ-164', 'VP'],
#   ['NP-SBJ-165', 'VP'],
#   ['NP-SBJ-166', 'S|<VP-.>'],
#   ['``', 'S|<S-2-,>'],
#   ['SBAR-ADV', 'S|<,-PP>'],
#   ['CC', 'S|<NP-SBJ-1-ADVP>'],
#   ['NP-SBJ', 'S|<VP-ADVP-TMP>'],
#   ['S-TPC-1', 'S|<NP-SBJ-VP>'],
#   ['CC', 'S|<SBAR-ADV-,>'],
#   ['NP-SBJ-6', 'S|<VP-,>'],
#   ['PP-LOC', 'S|<NP-SBJ-7-VP>'],
#   ['NP-SBJ-9', 'VP'],
#   ['NP-SBJ-10', 'VP'],
#   ['NP-SBJ-1', 'S|<,-VP>'],
#   ['PP-TMP', 'S|<,-NP-SBJ-3>'],
#   ['NP-SBJ-12', 'VP'],
#   ['PP-LOC', 'S|<NP-SBJ-1-VP>'],
#   ['PP-LOC', 'S|<,-NP-SBJ-14>'],
#   ['S-NOM-SBJ', 'S|<ADVP-VP>'],
#   ['``', "S|<S-TPC-1-''>"],
#   ['S-1', 'S|<:-S>'],
#   ['NP-SBJ', 'S|<``-RB>'],
#   ['SBAR-ADV', 'S|<,-NP-SBJ-16>'],
#   ['NP-SBJ-15', 'VP'],
#   ['NP-SBJ-2', 'ADJP-PRD'],
#   ['NP-SBJ-17', 'VP'],
#   ['PP', 'S|<NP-SBJ-1-VP>'],
#   ['NP-SBJ', 'S|<CONJP-VP>'],
#   ['NP-SBJ-19', 'VP'],
#   ['SBAR', 'S|<,-S-NOM-SBJ>'],
#   ['NP-SBJ-20', 'VP'],
#   ['S-ADV', 'S|<:-``>'],
#   ['NP-SBJ-23', 'VP'],
#   ['SBAR-ADV', 'S|<,-NP-SBJ-25>'],
#   ['NP-SBJ', 'S|<,-SBAR-ADV>'],
#   ['NP-SBJ-26', 'VP'],
#   ['NP-SBJ-27', 'VP'],
#   ['NP-SBJ-28', 'VP'],
#   ['NP-SBJ-29', 'S|<ADVP-VP>'],
#   ['NP-SBJ-30', 'S|<VP-.>'],
#   ['``', 'S|<SINV-TPC-1-,>'],
#   ['S', 'S|<,-RB>'],
#   ['NP-SBJ-32', 'VP'],
#   ['CC', 'S|<,-ADVP>'],
#   [':', 'S|<NP-SBJ-VP>'],
#   [',', 'S|<PP-,>'],
#   ['NP-SBJ-34', 'VP'],
#   [':', 'S|<CC-NP-SBJ>'],
#   [',', 'S|<SBAR-ADV-,>'],
#   ['IN', 'S|<ADVP-TMP-NP-SBJ>'],
#   ['``', 'S|<S-TPC-1-NP-SBJ>'],
#   ['NP-SBJ-37', 'S|<VP-.>'],
#   ['NP-SBJ-38', 'VP'],
#   ['NP-SBJ-39', 'VP'],
#   ['ADVP', 'S|<,-NP-SBJ-40>'],
#   ['NP-SBJ-42', 'VP'],
#   ['ADVP-TMP', 'S|<NP-SBJ-ADVP>'],
#   ['SBAR-ADV', 'S|<,-NP-SBJ-44>'],
#   ['NP-SBJ-45', 'VP'],
#   ['NP-SBJ-46', 'VP'],
#   ['NP-SBJ', 'S|<VP-CC>'],
#   ['NP-SBJ-47', 'S|<VP-ADVP-TMP>'],
#   ['NP-SBJ-48', 'VP'],
#   ['NP-SBJ-49', 'S|<ADVP-TMP-VP>'],
#   ['NP-SBJ-50', 'S|<VP-.>'],
#   ['NP-SBJ-51', 'VP'],
#   ['S', 'S|<:-``>'],
#   ['NP-SBJ-56', 'VP'],
#   ['ADVP', 'S|<NP-SBJ-ADVP>'],
#   ['NP-SBJ-58', 'VP'],
#   ['SBAR-ADV', 'S|<,-NP-SBJ-59>'],
#   ['NP-SBJ-2', 'S|<,-PP-MNR>'],
#   ['SBAR-ADV', 'S|<PRN-,>'],
#   ['S-2', "S|<,-''>"],
#   ['PP-LOC', 'S|<,-ADVP>'],
#   ['NP-SBJ', 'S|<VP-,>'],
#   ['NP-SBJ-61', 'S|<VP-.>'],
#   ['NP-SBJ-63', 'S|<VP-.>'],
#   ['``', 'S|<ADVP-,>'],
#   ['S-ADV', 'S|<,-NP-SBJ-64>'],
#   ['ADVP-MNR', 'S|<,-NP-SBJ>'],
#   ['``', "S|<FRAG-TTL-SBJ-1-''>"],
#   ['CC', 'S|<ADVP-NP-SBJ>'],
#   ['S-TPC-3', "S|<,-''>"],
#   ['ADVP', 'S|<,-NP-SBJ-66>'],
#   ['``', 'S|<PP-MNR-NP-SBJ-1>'],
#   ['S-TPC-4', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ-67', 'S|<VP-.>'],
#   ['ADJP-PRD', 'NP-SBJ'],
#   ['NP-SBJ-68', 'S|<VP-.>'],
#   ['PP-TMP', 'S|<,-NP-SBJ-69>'],
#   ['NP-SBJ-1', 'S|<,-PP>'],
#   ['NP-SBJ-1', 'S|<,-PP-LOC>'],
#   ['NP-SBJ-71', 'VP'],
#   ['SBAR-ADV', 'S|<,-ADVP-TMP>'],
#   ['CC', 'S|<NP-SBJ-1-PRN>'],
#   ['NP-SBJ', 'S|<ADJP-PRD-PP>'],
#   ['NP-SBJ-72', 'S|<VP-.>'],
#   ['NP-SBJ', 'S|<ADVP-MNR-VP>'],
#   ['CC', 'S|<NP-SBJ-2-ADVP>'],
#   ['NP-TMP', 'S|<,-NP-SBJ-73>'],
#   ['NP-SBJ-75', 'VP'],
#   ['S-SBJ', "S|<''-VP>"],
#   ['PP', 'S|<,-S>'],
#   ['ADVP-TMP', 'S|<,-PP-TMP>'],
#   ['ADVP-TMP', 'S|<NP-SBJ-76-VP>'],
#   ['NP-SBJ-77', 'VP'],
#   ['NP-SBJ-3', 'S|<ADVP-VP>'],
#   ['NP-SBJ', 'S|<ADJP-PRD-S-1>'],
#   ['SBAR-ADV', 'S|<NP-SBJ-VP>'],
#   ['PP-LOC', 'S|<,-S>'],
#   ['-LRB-', 'S|<S-,>'],
#   ['``', "S|<NP-SBJ-1-''>"],
#   ['NP-VOC', 'S|<INTJ-NP-SBJ>'],
#   ['NP-SBJ-80', 'VP'],
#   ['SBAR-ADV', 'S|<,-ADVP>'],
#   ['NP-SBJ-82', 'VP'],
#   ['S-NOM-SBJ', 'S|<VP-.>'],
#   ['PP-LOC', 'S|<,-NP-SBJ-84>'],
#   ['NP-SBJ-85', 'S|<VP-.>'],
#   ['NP-SBJ-87', 'VP'],
#   ['NP-SBJ', 'S|<PP-VP>'],
#   ['CC', 'S|<,-SBAR-ADV>'],
#   ['NP-SBJ', 'S|<,-PP-TMP>'],
#   ['CC', 'S|<``-S-TPC-1>'],
#   ['PP-TMP', 'S|<,-SBAR-TMP>'],
#   ['S', 'S|<,-NP-SBJ-1>'],
#   ['ADVP-TMP', 'S|<NP-SBJ-3-VP>'],
#   ['NP-TPC-3', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ', 'S|<,-S-ADV>'],
#   ['NP-SBJ-2', 'S|<,-PP>'],
#   ['``', 'S|<PP-TMP-,>'],
#   ['NP-SBJ-1', 'S|<NP-TMP-VP>'],
#   ['``', 'S|<CC-PP>'],
#   ['NP-SBJ-2', 'S|<,-VP>'],
#   ['CC', 'S|<NP-SBJ-3-VP>'],
#   ['NP-SBJ-3', 'S|<ADVP-TMP-VP>'],
#   ['ADVP-TMP', 'S|<ADVP-TMP-,>'],
#   ['S-TMP', 'S|<,-NP-SBJ-2>'],
#   ['CC', 'S|<NP-SBJ-ADVP-MNR>'],
#   ['NP-SBJ', 'S|<ADVP-LOC-VP>'],
#   ['NP-SBJ', 'S|<ADJP-PRD-S-2>'],
#   ['SBAR-ADV', 'S|<,-PP-TMP>'],
#   ['NP-SBJ', 'S|<ADJP-PRD-ADVP>'],
#   ['NP-SBJ-1', 'S|<,-ADVP>'],
#   ['FRAG-ADV', 'S|<,-NP-SBJ>'],
#   ['ADVP-LOC', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ=1', 'PP=3'],
#   ['NP-TMP', 'S|<NP-SBJ-ADVP>'],
#   ['NP-SBJ-2', 'S|<,-S-ADV>'],
#   ['NP-SBJ', 'S|<``-ADVP>'],
#   ['``', 'S|<FRAG-TPC-2-,>'],
#   ['NP-SBJ=1', 'S|<PP-CLR=2-,>'],
#   ['LST', 'S|<PP-LOC-,>'],
#   ['NP-TMP-TPC-1', 'S|<NP-SBJ-VP>'],
#   ['NP-SBJ-1+NP', 'VP'],
#   ['PRN', 'S|<NP-SBJ-2-ADVP-TMP>'],
#   ['CC', 'S|<NP-SBJ-2-VP>'],
#   ['NP-SBJ', 'S|<,-SBAR>'],
#   ['NP-SBJ-6', 'VP'],
#   ['NP-SBJ-7', 'VP'],
#   ['NP-TMP', 'S|<NP-SBJ-2-VP>'],
#   ['-LRB-', 'S|<NP-SBJ--RRB->'],
#   ['SBAR-ADV', 'S|<NP-SBJ-1-VP>'],
#   ['NP-SBJ=1-3', 'VP=2'],
#   ['PP-PRP', 'S|<NP-SBJ-VP>'],
#   ['PP-LOC', 'S|<PP-TMP-NP-TMP>'],
#   ['UCP-ADV', 'S|<,-NP-SBJ-1>'],
#   ['NP-SBJ', 'S|<,-PP-LOC>'],
#   ['PP', 'S|<,-PP-TMP>'],
#   ['ADVP-PRP', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ', 'S|<ADJP-PRD-SBAR-1>'],
#   ['CC', 'S|<SBAR-ADV-NP-SBJ>'],
#   ['CC', 'S|<NP-SBJ-PP-TMP>'],
#   ['CC', 'S|<``-NP-SBJ>'],
#   ['PP-PRP', 'S|<,-NP-SBJ-1>'],
#   ['SBAR-TMP', 'S|<,-NP-SBJ-4>'],
#   ['S-ADV', 'S|<,-NP-SBJ-5>'],
#   ['NP-ADV', 'S|<,-NP-SBJ>'],
#   ['S-2', 'S|<,-NP-SBJ>'],
#   ['NP-SBJ', 'S|<NP-TMP-PP-LOC-3>'],
#   ['PP-LOC', 'S|<NP-TMP-NP-SBJ-1>'],
#   ['ADVP', 'S|<,-NP-SBJ-3>']],
#  'NP-SBJ': [['NP', 'NP-SBJ|<,-ADJP>'],
#   ['NNP', 'NNP'],
#   ['NP', 'RRC'],
#   ['NP', 'NP-SBJ|<,-NP>'],
#   ['NP', 'PP'],
#   ['DT', 'NP-SBJ|<JJS-NNS>'],
#   ['DT', 'NP-SBJ|<NNP-NN>'],
#   ['DT', 'NP-SBJ|<NP-CC>'],
#   ['DT', 'NN'],
#   ['NP', 'NP'],
#   ['DT', 'NNS'],
#   ['DT', 'NP-SBJ|<NN-NN>'],
#   ['NP', 'NP-SBJ|<,-SBAR>'],
#   ['DT', 'NNP'],
#   ['DT', 'NP-SBJ|<NNP-NNP>'],
#   ['NP', 'NP-SBJ|<PP-SBAR>'],
#   ['NN', 'NNS'],
#   ['DT', 'NP-SBJ|<JJ-NN>'],
#   ['NP', 'NP-SBJ|<PP-,>'],
#   ['DT', 'NP-SBJ|<JJ-JJ>'],
#   ['NNP', 'NP-SBJ|<NNP-NNP>'],
#   ['DT', 'NP-SBJ|<NN-VBG>'],
#   ['PRP$', 'NP-SBJ|<NNP-CC>'],
#   ['NP', 'NP-SBJ|<,-VP>'],
#   ['NP', 'NP-SBJ|<NN-NN>'],
#   ['NP', 'NP-SBJ|<VBG-NNS>'],
#   ['NN', 'NP-SBJ|<CC-NN>'],
#   ['NNP', 'NP-SBJ|<CD-NNS>'],
#   ['NP', 'PP-TMP'],
#   ['NP', 'NP-SBJ|<VBN-NNS>'],
#   ['NP', 'PP-DIR'],
#   ['NP', 'SBAR'],
#   ['NP', 'NP-SBJ|<,-RRC>'],
#   ['NP', 'NP-SBJ|<NN-NNS>'],
#   ['NP', 'PP-LOC'],
#   ['PRP$', 'NN'],
#   ['NP', 'NP-SBJ|<,-NP-LOC>'],
#   ['NP', 'NP-SBJ|<VP-PRN>'],
#   ['JJ', 'NNS'],
#   ['PRP$', 'NNS'],
#   ['DT', 'NP-SBJ|<NN-SBAR>'],
#   ['NAC', 'NNS'],
#   ['NN', 'NP-SBJ|<NN-NNP>'],
#   ['NP', 'NP-SBJ|<NNP-CD>'],
#   ['NP', 'NP-SBJ|<PP-PP-TMP>'],
#   ['NP', 'NNP'],
#   ['DT', 'NP-SBJ|<JJ-NNS>'],
#   ['PRP$', 'NP-SBJ|<NN-NN>'],
#   ['NP', 'NP-SBJ|<VP-PP>'],
#   ['DT', 'NP-SBJ|<JJ-NNP>'],
#   ['JJ', 'NP-SBJ|<NNP-NNP>'],
#   ['NP', 'NP-SBJ|<NN-S>'],
#   ['DT', 'NP-SBJ|<NNP-NNS>'],
#   ['JJ', 'NP-SBJ|<NN-NNS>'],
#   ['NP', 'NP-SBJ|<:-NP>'],
#   ['NNP', 'NP-SBJ|<NN-NNS>'],
#   ['DT', 'NP-SBJ|<CD-NNS>'],
#   ['NNP', 'NP-SBJ|<NN-NN>'],
#   ['JJR', 'NP-SBJ|<NNP-NN>'],
#   ['DT', 'NP-SBJ|<CD-NN>'],
#   ['DT', 'NP-SBJ|<JJ-CD>'],
#   ['NP', 'NP-SBJ|<CC-NP>'],
#   ['JJ', 'NP-SBJ|<JJ-NNS>'],
#   ['PRP$', 'NP-SBJ|<NNP-NNP>'],
#   ['NP', 'NP-SBJ|<,-PP>'],
#   ['NP', 'NP-SBJ|<NNP-NNP>'],
#   ['NNP', 'NNS'],
#   ['NP', 'PRN'],
#   ['JJ', 'NN'],
#   ['DT', 'NP-SBJ|<NN-,>'],
#   ['JJ', 'NP-SBJ|<NN-NN>'],
#   ['ADJP', 'NNS'],
#   ['JJ', 'NP-SBJ|<VBG-NNS>'],
#   ['JJ', 'NP-SBJ|<CC-NN>'],
#   ['DT', 'NP-SBJ|<ADJP-NNS>'],
#   ['NP', 'VP'],
#   ['DT', 'NP-SBJ|<JJ-NNPS>'],
#   ['NP', 'NP-SBJ|<SBAR-PP>'],
#   ['DT', 'NP-SBJ|<NNP-CC>'],
#   ['NP', 'S'],
#   ['PRP$', 'NP-SBJ|<JJS-NN>'],
#   ['DT', 'NP-SBJ|<VBG-NNS>'],
#   ['NN', 'NN'],
#   ['NN', 'NP-SBJ|<NN-NN>'],
#   ['NP', 'NP-SBJ|<JJ-NN>'],
#   ['NNS', 'NNS'],
#   ['NP', 'NN'],
#   ['VBG', 'NNS'],
#   ['NP', 'NNS'],
#   ['NP', 'NP-SBJ|<PP-PP>'],
#   ['DT', 'NP-SBJ|<JJ-,>'],
#   ['``', "NP-SBJ|<NP-TTL-''>"],
#   ['NNP', 'NP-SBJ|<NNP-NNS>'],
#   ['NP+QP', 'PP'],
#   ['DT', 'NP-SBJ|<NNP-JJ>'],
#   ['DT', 'NP-SBJ|<NNP-POS>'],
#   ['NNP', 'NP-SBJ|<CC-NNP>'],
#   ['NP', 'NP-SBJ|<PP-NP-TMP>'],
#   ['NP', 'NP-SBJ|<,-CC>'],
#   ['DT', 'CD'],
#   ['DT', 'JJ'],
#   ['PRP$', 'NP-SBJ|<NN-NNS>'],
#   ['NP', 'ADJP'],
#   ['NNP', 'NP-SBJ|<NNP-POS>'],
#   ['DT', 'NP-SBJ|<NN-NNS>'],
#   ['NP', 'NP-SBJ|<NN-PP-LOC>'],
#   ['NP', 'NP-SBJ|<JJ-JJ>'],
#   ['JJ', 'NNPS'],
#   ['NNS', 'S'],
#   ['PRP$', 'NP-SBJ|<JJ-NN>'],
#   ['PRP', 'NN'],
#   ['QP', 'NNS'],
#   ['PRP$', 'NP-SBJ|<JJ-NNS>'],
#   ['NNP', 'NP-SBJ|<.-NNP>'],
#   ['DT', 'NP-SBJ|<NNS-CC>'],
#   ['JJ', 'NP-SBJ|<NNS-,>'],
#   ['NP', 'NP-SBJ|<,-NP+NP>'],
#   ['JJS', 'NNS'],
#   ['NP-TTL', 'NP-SBJ|<CC-NP-TTL>'],
#   ['NP', 'NP-SBJ|<PP-PRN>'],
#   ['NP-TTL', 'PP'],
#   ['NNPS', 'NP-SBJ|<NNP-CC>'],
#   ['NP', 'NP-SBJ|<PP-PP-DIR>'],
#   ['VBN', 'NP-SBJ|<NN-SBAR>'],
#   ['CD', 'NP-SBJ|<NNP-NNP>'],
#   ['DT', 'NP-SBJ|<JJS-NN>'],
#   ['DT', 'NP-SBJ|<NAC-LOC-NN>'],
#   ['NNP', 'NP-SBJ|<NNPS-NNP>'],
#   ['NNP', 'POS'],
#   ['NP', 'NNPS'],
#   ['DT', 'NP-SBJ|<NAC-LOC-JJ>'],
#   ['NN', 'S'],
#   ['NN', 'NP-SBJ|<NNP-NNS>'],
#   ['NNP', 'NN'],
#   ['NNP', 'NP-SBJ|<NNP-SYM>'],
#   ['PRP$', 'NP-SBJ|<NN-POS>'],
#   ['DT', 'NP-SBJ|<DT-NNS>'],
#   ['DT', 'NP-SBJ|<VBG-NN>'],
#   ['DT', 'NP-SBJ|<``-JJ>'],
#   ['CD', 'NN'],
#   ['DT', 'NP-SBJ|<ADJP-JJ>'],
#   ['JJ', 'NP-SBJ|<-LRB--NN>'],
#   ['NP', 'NP-SBJ|<PP-TMP-PP>'],
#   ['VBN', 'NN'],
#   ['CD', 'NP-SBJ|<NN-NN>'],
#   ['DT', 'NP-SBJ|<NNS-NNS>'],
#   ['DT', 'NP-SBJ|<JJ-CC>'],
#   ['NNP', 'NNPS'],
#   ['DT', 'NP-SBJ|<QP--NONE->'],
#   ['PDT', 'NP-SBJ|<DT-NN>'],
#   ['DT', 'NP-SBJ|<JJR-NNS>'],
#   ['PRP$', 'NP-SBJ|<NNS-CC>'],
#   ['NAC', 'NNP'],
#   ['NP', 'NP-SBJ|<,-SBAR-LOC>'],
#   ['VBG', 'NN'],
#   ['DT', 'NP-SBJ|<VBN-NN>'],
#   ['NNP', 'NP-SBJ|<NNP-CD>'],
#   ['DT', 'NP-SBJ|<ADJP-CD>'],
#   ['DT', 'NP-SBJ|<CD-NNP>'],
#   ['NP', 'NP-SBJ|<NNP-IN>'],
#   ['NP', 'NP-SBJ|<CD-NNP>'],
#   ['JJR', 'NNS'],
#   ['CD', 'NP-SBJ|<CD-NNP>'],
#   ['NNP', 'NP-SBJ|<NNP-CC>'],
#   ['NNP', 'NP-SBJ|<NNP-NN>'],
#   ['NP', 'NP-SBJ|<NN-JJ>'],
#   ['NP', 'NP-ADV'],
#   ['JJ', 'NP-SBJ|<DT-NN>'],
#   ['NP', 'NP-SBJ|<PP-LOC-PP>'],
#   ['NP-1', 'VP'],
#   ['NP', 'NP-SBJ|<-LRB--PP-LOC>'],
#   ['NNS', 'SBAR'],
#   ['DT', 'NP-SBJ|<NAC-NN>'],
#   ['DT', 'NP-SBJ|<DT-``>'],
#   ['NP', 'NP-SBJ|<,-RB>'],
#   ['NP', 'NP-SBJ|<,-ADVP>'],
#   ['DT', 'NP-SBJ|<JJ-NX>'],
#   ['DT', 'NP-SBJ|<NNS-NN>'],
#   ['JJ', 'NP-SBJ|<NNS-NNS>'],
#   ['NP', 'NP-SBJ|<PP-NP>'],
#   ['NP', 'ADVP-LOC'],
#   ['CD', 'NP-SBJ|<NNS-CC>'],
#   ['CD', 'NP-SBJ|<JJ-NNS>'],
#   ['DT', 'PRP'],
#   ['JJ', 'NP-SBJ|<NN-NNP>'],
#   ['CD', 'NP-SBJ|<JJ-NN>'],
#   ['DT', 'NP-SBJ|<NNP-CD>'],
#   ['DT', 'NP-SBJ|<JJ-ADJP>'],
#   ['NP', 'NP-SBJ|<VP-SBAR>'],
#   ['NP', 'NP-SBJ|<PP-LOC-,>'],
#   ['JJS', 'NNPS'],
#   ['DT', 'NP-SBJ|<NNS-RB>'],
#   ['NP', 'NP-SBJ|<``-S-TTL>'],
#   ['NP', 'NP-SBJ|<JJ-NNS>'],
#   ['DT', 'NP-SBJ|<RBS-JJ>'],
#   ['NP', 'NP-SBJ|<NNP-.>'],
#   ['QP', 'NN'],
#   ['NP', 'NP-SBJ|<VBG-NN>'],
#   ['DT', 'NP-SBJ|<NNP-``>'],
#   ['NP', 'NP-SBJ|<,-PP-DIR>'],
#   ['ADJP', 'NP-SBJ|<VBG-NN>'],
#   ['DT', 'NP-SBJ|<NNP-NNPS>'],
#   ['DT', 'NP-SBJ|<VBG-CD>'],
#   ['DT', 'NP-SBJ|<JJR-NN>'],
#   ['DT', 'NP-SBJ|<ADJP-NN>'],
#   ['DT', 'NNPS'],
#   ['NP', 'NP-SBJ|<PP-:>'],
#   ['NP', 'NP-SBJ|<PP-PP-LOC>'],
#   ['NP', 'NP-SBJ|<``-NP-TTL>'],
#   ['PRP$', 'NP-SBJ|<``-JJ>'],
#   ['JJ', 'NP-SBJ|<VBN-NNS>'],
#   ['NP', 'NP-SBJ|<,-PRN>'],
#   ['NNS', 'NP-SBJ|<,-NNS>'],
#   ['DT', 'NP-SBJ|<NN-S>'],
#   ['NP', 'NP-SBJ|<VBN-NN>'],
#   ['NP', "NP-SBJ|<PP-''>"],
#   ['NN', 'CD'],
#   ['NP', 'NP-SBJ|<PP-VP>'],
#   ['NP', 'NP-SBJ|<NNS-NN>'],
#   ['IN', 'NP-SBJ|<JJ-NNS>'],
#   ['IN', 'DT'],
#   ['NP', 'NP-SBJ|<PP-LOC-NP>'],
#   ['CD', 'NNS'],
#   ['NP', 'NP-SBJ|<NP-PP-LOC>'],
#   ['NP', 'NP-SBJ|<PP-S-2>'],
#   ['PRP$', 'NP-SBJ|<VBN-CD>'],
#   ['NN', 'NP-SBJ|<NN-NNS>'],
#   ['JJ', 'NP-SBJ|<NNS-CC>'],
#   ['DT', 'NP-SBJ|<-LRB--NN>'],
#   ['NP', 'NP-SBJ|<NN-CC>'],
#   ['NN', 'NP-SBJ|<NNS-NN>'],
#   ['NP', 'NP-SBJ|<``-NN>'],
#   ['ADJP', 'NN'],
#   ['NP', 'SBAR-ADV'],
#   ['NP', 'NP-SBJ|<PRN-PP>'],
#   ['UCP', 'NNS'],
#   ['NP', 'NP-SBJ|<PP-LOC-NP-TMP>'],
#   ['NNS', 'NP-SBJ|<CC-NNS>'],
#   ['RB', 'NP-SBJ|<JJ-NN>'],
#   ['RBR', 'NP-SBJ|<JJ-NNS>'],
#   ['NP-LOC', 'NP-SBJ|<SBAR-,>'],
#   ['NP', 'NP-TMP'],
#   ['NP', 'NP-SBJ|<``-NNS>'],
#   ['RB', 'NP-SBJ|<JJ-NNS>'],
#   ['DT', 'NP-SBJ|<VBN-NNS>'],
#   ['DT', 'VBG'],
#   ['DT', 'NP-SBJ|<CD-JJ>'],
#   ['NNP', 'NP-SBJ|<NNPS-NN>'],
#   ['NNP', 'VBZ'],
#   ['PRP$', 'NP-SBJ|<NNS-NN>'],
#   ['DT', 'NP-SBJ|<NN-CD>'],
#   ['NP', 'NP-SBJ|<NNP-NN>'],
#   ['DT', 'NP-SBJ|<JJS-NNP>'],
#   ['PDT', 'NP-SBJ|<DT-JJ>'],
#   ['NN', 'NP-SBJ|<.-NNP>'],
#   ['DT', 'NP-SBJ|<ADJP-NNP>'],
#   ['ADJP', 'NP-SBJ|<JJ-JJ>'],
#   ['NP', 'NP-SBJ|<NP-TMP-S-1>'],
#   ['PRP$', 'NP-SBJ|<VBG-NNS>'],
#   ['NNP', 'NP-SBJ|<,-NNP>'],
#   ['ADJP', 'NP-SBJ|<NN-NNS>'],
#   ['DT', 'NP-SBJ|<NNP-,>'],
#   ['NP', 'NP-SBJ|<ADJP-NN>'],
#   ['RBS', 'NP-SBJ|<JJ-NNS>'],
#   ['NP', 'NP-SBJ|<NNPS-NNP>'],
#   ['NP', 'NP-SBJ|<NN-NNP>'],
#   ['NP', 'NP-SBJ|<CD-JJ>'],
#   ['DT', 'NP-SBJ|<UCP-NN>'],
#   ['NP', 'NP-SBJ|<VP-,>'],
#   ['VBN', 'NP-SBJ|<NN-NN>'],
#   ['NP', 'NP-SBJ|<,-UCP>'],
#   ['NN', 'NP-SBJ|<NNP-NNP>'],
#   ['ADJP', 'NP-SBJ|<NNP-NNP>'],
#   ['DT', 'NP-SBJ|<NN-CC>'],
#   ['JJ', 'NNP'],
#   ['NAC', 'NP-SBJ|<NNP-NNP>'],
#   ['QP', '-NONE-'],
#   ['NP', 'NP-SBJ|<NP-TMP-PP>'],
#   ['NNP', 'VBP'],
#   ['NNS', 'NX'],
#   ['NN', 'NP-SBJ|<NNS-CC>'],
#   ['PDT', 'DT'],
#   ['JJR', 'NP-SBJ|<NN-NNS>'],
#   ['JJ', 'NP-SBJ|<JJ-JJ>'],
#   ['PRP$', 'NP-SBJ|<CD-JJ>'],
#   ['RB', 'NP'],
#   ['NP', 'NP-SBJ|<PRN-,>'],
#   ['DT', 'VBN'],
#   ['``', 'NP-SBJ|<NNP-NNP>'],
#   ['RB', 'CD'],
#   ['NP', 'NP-SBJ|<JJS-NN>'],
#   ['NP', 'NP-SBJ|<VBG-JJ>'],
#   ['VBN', 'NP-SBJ|<NN-CC>'],
#   ['CD', 'NP-SBJ|<VBG-NN>'],
#   ['NNP', 'NX'],
#   ['JJ', 'NP-SBJ|<JJ-NN>']],
#  'NP': [['NNP', 'NNP'],
#   ['CD', 'NNS'],
#   ['DT', 'NN'],
#   ['DT', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<,-NP>'],
#   ['DT', 'NP|<NNP-VBG>'],
#   ['NP', 'PP'],
#   ['JJ', 'NN'],
#   ['NNP', 'NP|<NNP-NNP>'],
#   ['DT', 'NP|<JJ-JJ>'],
#   ['NNP', 'NP|<NN-NNS>'],
#   ['NP', 'NP|<PP-PP-LOC>'],
#   ['NN', 'NNS'],
#   ['NP', 'RRC+VP'],
#   ['QP', 'NNS'],
#   ['DT', 'NP|<NN-NN>'],
#   ['DT', 'NNS'],
#   ['RB', 'NP|<JJ-NNS>'],
#   ['NP', 'SBAR'],
#   ['NP', 'NP|<PP-SBAR>'],
#   ['ADJP', 'NP|<NNP-NNP>'],
#   ['NNP', 'NNS'],
#   ['PRP$', 'NP|<NN-NN>'],
#   ['QP', 'NN'],
#   ['NP', 'NP|<NNP-NNP>'],
#   ['NN', 'POS'],
#   ['NP', 'ADJP'],
#   ['DT', 'NP|<JJ-NNS>'],
#   ['PRP$', 'NNS'],
#   ['DT', 'NP|<NNP-NNS>'],
#   ['NNP', 'POS'],
#   ['NP', 'PP-DIR'],
#   ['NP', 'NP|<CC-NP>'],
#   ['DT', 'NP|<NNP-NNP>'],
#   ['ADJP', 'NNS'],
#   ['DT', 'NP|<JJ-CD>'],
#   ['QP', 'NP|<NNP-NNS>'],
#   ['DT', 'NP|<CD-VBG>'],
#   ['JJ', 'NNS'],
#   ['ADJP', 'NN'],
#   ['NN', 'NN'],
#   ['NN', 'NP|<NN-NNS>'],
#   ['NP', 'PP-LOC'],
#   ['DT', 'NP|<NAC-LOC-NN>'],
#   ['DT', 'JJS'],
#   ['DT', 'NP|<NN-NNS>'],
#   ['JJ', 'NP|<VBN-NNS>'],
#   ['NP', 'NP|<PP-S-2>'],
#   ['NN', 'S'],
#   ['NP', 'NP|<PP-PP>'],
#   ['NP', 'VP'],
#   ['NP', 'NP|<PP-,>'],
#   ['JJS', 'NNS'],
#   ['DT', 'NP|<JJ-VBN>'],
#   ['DT', 'NP|<JJR-NN>'],
#   ['DT', 'NP|<JJ-,>'],
#   ['DT', 'NP|<NAC-NNP>'],
#   ['ADJP', 'NP|<VBG-NNS>'],
#   ['DT', 'CD'],
#   ['JJ', 'NP|<NN-NNS>'],
#   ['DT', 'NP|<VBN-NN>'],
#   ['NN', 'NP|<CC-NN>'],
#   ['``', 'NP|<NP-PP>'],
#   ['DT', 'NP|<NNS-CC>'],
#   ['NNP', 'NP|<CC-NNP>'],
#   ['NP', 'NP-TMP'],
#   ['JJ', 'NP|<JJ-NNS>'],
#   ['NNS', 'SBAR'],
#   ['DT', 'NP|<CD-JJ>'],
#   ['CD', 'NN'],
#   ['NP', 'NNS'],
#   ['DT', 'NP|<NNS-POS>'],
#   ['NP', 'PP-TMP'],
#   ['JJ', 'NNP'],
#   ['VBG', 'NP|<NN-NNS>'],
#   ['RB', 'NP|<JJR-NNS>'],
#   ['VBG', 'NNS'],
#   ['JJR', 'NNS'],
#   ['NP', 'PRN'],
#   ['JJ', 'NP|<NNP-NNS>'],
#   ['NP', 'NN'],
#   ['QP', '-NONE-'],
#   ['DT', 'NP|<JJS-NN>'],
#   ['DT', 'NP|<JJS-NNS>'],
#   ['PRP$', 'NN'],
#   ['DT', 'NP|<CD-NNS>'],
#   ['NP', 'NP|<,-SBAR>'],
#   ['NNP', 'NP|<NNP-CC>'],
#   ['DT', 'NP|<ADJP-NN>'],
#   ['ADVP', 'NP|<DT-NNP>'],
#   ['NP', 'NP|<CD-NN>'],
#   ['NNP', 'NP|<NNP-POS>'],
#   ['NP', 'NP|<,-CC>'],
#   ['NP', 'NP-ADV'],
#   ['$', 'NP|<CD--NONE->'],
#   ['PRP$', 'NP|<NNP-NNP>'],
#   ['NNP', 'NP|<NNP-.>'],
#   ['NNP', 'NP|<NNS-NNS>'],
#   ['DT', 'NP|<NN-S>'],
#   ['DT', 'NP|<NN-POS>'],
#   ['NNP', 'CD'],
#   ['JJ', 'NP|<NN-NN>'],
#   ['NP', 'NP|<NNP-NNS>'],
#   ['NP', 'NP|<NNP-NN>'],
#   ['PRP$', 'NP|<JJ-NN>'],
#   ['DT', 'NP|<NNP-NN>'],
#   ['CD', 'NP|<JJ-NN>'],
#   ['DT', 'NP|<VBG-NN>'],
#   ['NP', 'NP|<,-CONJP>'],
#   ['RB', 'NP|<DT-JJ>'],
#   ['NP', 'NP|<:-ADVP-LOC>'],
#   ['DT', 'NP|<VBN-NNP>'],
#   ['NNP', 'NP|<NN-NN>'],
#   ['NP', 'NP|<JJ-NN>'],
#   ['DT', 'NP|<NNP-CC>'],
#   ['DT', 'NP|<NN-JJR>'],
#   ['NP', 'NP|<,-ADVP>'],
#   ['VBN', 'NP|<NN-NNS>'],
#   ['NP', 'NP'],
#   ['NNP', 'NN'],
#   ['PRP$', 'NP|<VBN-NN>'],
#   ['NP', 'NP|<NN-NN>'],
#   ['PRP$', 'NP|<CD-NN>'],
#   ['NP', 'NP|<PP-LOC-PP-TMP>'],
#   ['NP', 'NP|<PP-PP-DIR>'],
#   ['NP', 'NP|<PP-DIR-,>'],
#   ['NNS', 'NP|<CC-NNS>'],
#   ['DT', 'NP|<JJS-RB>'],
#   ['DT', 'NP|<VBG-JJ>'],
#   ['NP', 'NP|<PP-LOC-SBAR>'],
#   ['NN', 'NP|<CD-NN>'],
#   ['DT', 'NP|<QP--NONE->'],
#   ['JJ', 'NP|<JJ-NN>'],
#   ['RB', 'NP|<DT-CD>'],
#   ['NP', "NP|<''-SBAR>"],
#   ['NP', 'NP|<NN-S>'],
#   ['NP', 'NP|<NN-NNS>'],
#   ['JJR', 'NP|<NN-NNS>'],
#   ['CD', 'NP|<NN--NONE->'],
#   ['NP', 'NP|<PP-VP>'],
#   ['DT', 'NNP'],
#   ['NP', 'NP|<,-PP-DIR>'],
#   ['NP', 'NP|<,-UCP>'],
#   ['JJ', 'NX'],
#   ['NNPS', 'NP|<``-NNP>'],
#   ['VBN', 'NP|<NNP-NNP>'],
#   ['NNP', 'NP|<NNP-NN>'],
#   ['PRP$', 'NP|<JJ-CC>'],
#   ['DT', 'NP|<UCP-NN>'],
#   ['NP', 'ADVP'],
#   ['NP', 'NP|<SBAR-,>'],
#   ['JJ', 'NP|<NNS-S>'],
#   ['PRP$', 'NP|<CD-NNS>'],
#   ['DT', 'NP|<QP-NNS>'],
#   ['DT', 'NP|<JJ-QP>'],
#   ['DT', 'NP|<ADJP-NNP>'],
#   ['DT', 'NP|<VBN-CD>'],
#   ['PRP$', 'NP|<NN-NNS>'],
#   ['PRP$', 'NP|<QP-NNS>'],
#   ['NP', 'NP|<NNP-CD>'],
#   ['NP', 'NP|<PP-SBAR-PRP>'],
#   ['DT', 'NP|<NNP-CD>'],
#   ['NP', 'NP|<JJ-NNS>'],
#   ['NNS', 'NP|<,-NNS>'],
#   ['NNP', 'NP|<NNPS-NNP>'],
#   ['NN', 'NP|<NNP-NNP>'],
#   ['DT', 'NP|<NN-PRN>'],
#   ['PRP$', 'NX'],
#   ['DT', 'NP|<NNPS-CC>'],
#   ['NP', 'NP|<NN-JJ>'],
#   ['ADVP', 'NP|<DT-QP>'],
#   ['PRP$', 'NP|<ADJP-JJ>'],
#   ['NP', 'NP|<,-NP-LOC>'],
#   ['NP', 'NP|<JJ-,>'],
#   ['DT', 'NP|<NNP-POS>'],
#   ['DT', 'NP|<JJS-JJ>'],
#   ['NNP', 'NP|<NNP-NNPS>'],
#   ['NP', 'NP|<:-NP>'],
#   ['NP', 'NP|<JJ-CD>'],
#   ['QP', 'NP|<JJ-NNS>'],
#   ['RB', 'NP|<DT-NNP>'],
#   ['CD', 'NP|<NNP-NNP>'],
#   ['QP', 'NP|<NNP-NNP>'],
#   ['ADVP', 'DT'],
#   ['DT', 'NP|<CD-NN>'],
#   ['DT', 'NP|<JJ-DT>'],
#   ['DT', 'NP|<JJ-NAC-LOC>'],
#   ['NP', 'NP|<SBAR-PP>'],
#   ['NN', 'NP|<NN-NN>'],
#   ['NNP', 'NP|<NN-NNP>'],
#   ['NN', 'NP|<VBG-NN>'],
#   ['RB', 'NN'],
#   ['NNP', 'NNPS'],
#   ['NNP', 'NX'],
#   ['CD', 'NP|<JJ-NNS>'],
#   ['NNP', 'NP|<,-NNP>'],
#   ['DT', 'NP|<JJ-NNP>'],
#   ['NP', "NP|<''-PP-LOC>"],
#   ['DT', 'NP|<VBG-NNS>'],
#   ['DT', 'NP|<``-NN>'],
#   ['DT', 'NP|<-LRB--VBG>'],
#   ['PRP$', 'NP|<JJ-NNS>'],
#   ['PRP$', 'NP|<JJS-NNS>'],
#   ['NP', 'NP|<VBG-NN>'],
#   ['JJ', 'NP|<NN-CC>'],
#   ['PRP$', 'NP|<NNS-S>'],
#   ['VBG', 'NP|<JJ-NN>'],
#   ['NNP', 'NP|<JJ-NNS>'],
#   ['RB', 'RB'],
#   ['DT', 'NP|<NN-CC>'],
#   ['JJR', 'NP|<JJ-NNS>'],
#   ['DT', 'NP|<NNP-,>'],
#   ['ADVP-TMP', 'NP|<NP-PP>'],
#   ['CD', 'NP|<NNP-NNS>'],
#   ['DT', 'NP|<ADJP-NNS>'],
#   ['PRP$', 'NP|<JJ-VBN>'],
#   ['DT', 'JJ'],
#   ['DT', 'NP|<NNP-NNPS>'],
#   ['NP', 'NP|<VP-PP>'],
#   ['VB', 'NNS'],
#   ['NP', 'NP|<,-PP>'],
#   ['JJ', 'NP|<VBG-NNS>'],
#   ['NP', 'NP|<PP-LOC-NP-TMP>'],
#   ['NP', 'NP|<JJ-JJ>'],
#   ['ADVP-TMP', 'NP|<NN-NN>'],
#   ['JJ', 'NP|<NNS-NN>'],
#   ['NN', 'NP|<CC-VBG>'],
#   ['NP', 'NNP'],
#   ['NP', 'NP|<NNP-NNPS>'],
#   ['JJ', 'NP|<CC-JJ>'],
#   ['NP', 'NP|<PP-LOC-ADJP>'],
#   ['NNP', 'NP|<NNP-NNS>'],
#   ['NP+QP', 'PP'],
#   ['NN', 'CD'],
#   ['NNS', 'POS'],
#   ['PRP$', 'NP|<ADJP-NN>'],
#   ['NP', 'NP|<ADJP-PP>'],
#   ['DT', 'NP|<DT-JJ>'],
#   ['DT', 'NNPS'],
#   ['NP', 'NP|<PP-PP-TMP>'],
#   ['NAC', 'NP|<JJ-NN>'],
#   ['DT', 'NP|<JJR-ADJP>'],
#   ['QP', 'NP|<NN-NNS>'],
#   ['QP', 'NP|<DT-NN>'],
#   ['JJ', 'NP|<NNP-NNP>'],
#   ['NNP', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<PRN-SBAR-TMP>'],
#   ['DT', 'NP|<``-JJ>'],
#   ['JJ', 'NP|<JJ-JJ>'],
#   ['RB', 'CD'],
#   ['NNP', 'NP|<NNP-,>'],
#   ['DT', 'NP|<DT-NN>'],
#   ['JJ', 'CD'],
#   ['DT', 'NP|<JJ-ADJP>'],
#   ['CD', 'POS'],
#   ['NNP', 'NP|<NNS-CC>'],
#   ['DT', 'NX'],
#   ['DT', 'NP|<NN-SBAR>'],
#   ['VBN', 'NNS'],
#   ['NP', 'NP|<,-ADJP>'],
#   ['``', "NP|<NP-''>"],
#   ['DT', 'NP|<NNS-SBAR>'],
#   ['JJ', 'NP|<,-JJ>'],
#   ['JJ', 'NP|<NN-POS>'],
#   ['NNS', 'NN'],
#   ['JJ', 'NP|<NN-SBAR>'],
#   ['NP', 'ADVP-TMP'],
#   ['NN', 'SBAR'],
#   ['CD', 'NP|<NN-POS>'],
#   ['NP', 'NP|<,-VP>'],
#   ['VBN', 'NN'],
#   ['ADJP', 'NP|<NNP-NNS>'],
#   ['ADJP', 'NP|<NN-NNS>'],
#   ['ADJP', 'NP|<JJ-NNS>'],
#   ['NP', 'NP|<JJS-NNS>'],
#   ['NP', 'NP|<``-NX-TTL+NP>'],
#   ['DT', 'NP|<JJ-``>'],
#   ['NP', 'NP|<:-CC>'],
#   ['WP', 'RB'],
#   ['``', "NP|<NP-TTL-''>"],
#   ['NP', 'NP|<PRN-SBAR>'],
#   ['NP', 'NP|<,-PP-LOC>'],
#   ['RB', 'NP|<DT-ADJP>'],
#   ['PRP$', 'NP|<NNS-POS>'],
#   ['NP', 'NP|<,-SBAR-LOC>'],
#   ['NNS', 'NNS'],
#   ['DT', 'NP|<``-NNP>'],
#   ['JJ', 'NP|<NNS-CC>'],
#   ['NP', 'SBAR-LOC'],
#   ['NP+QP', 'PP-LOC'],
#   ['NP', 'NP|<PP-NP-TMP>'],
#   ['JJ', 'NP|<DT-JJ>'],
#   ['``', 'NP|<NP-,>'],
#   ['JJR', 'NN'],
#   ['CD', 'NP|<JJR-NNS>'],
#   ['NP', 'NP|<PRN-PP>'],
#   ['CD', 'NP|<NN-NN>'],
#   ['ADJP', 'NP|<NN-NN>'],
#   ['``', 'NP|<NP-TTL-,>'],
#   ['PRP$', 'NNP'],
#   ['RB', 'NNS'],
#   ['DT', 'PRP'],
#   ['NP', 'NP|<PRN-,>'],
#   ['PRP$', 'NP|<JJ-NP>'],
#   ['RB', 'NP|<JJ-DT>'],
#   ['PRP$', 'NP|<``-NX-TTL>'],
#   ['RB', 'JJ'],
#   ['PRP$', 'JJS'],
#   ['NNS', 'S'],
#   ['PRP$', 'NP|<JJ-JJ>'],
#   ['PRP$', 'NP|<JJ-CD>'],
#   ['DT', 'NP|<JJR-CD>'],
#   ['JJS', 'NP|<JJ-NNS>'],
#   ['DT', 'NP'],
#   ['``', 'NP|<JJ-NNS>'],
#   ['NP', 'NP|<NNS-NN>'],
#   ['PRP$', 'JJ'],
#   ['CD', 'NP|<JJ-,>'],
#   ['NN', 'NP|<:-IN>'],
#   ['NNP', ':'],
#   ['NP', 'NP|<VP-SBAR>'],
#   ['NP', "NP|<PP-''>"],
#   ['PRP$', 'NP|<NN-S>'],
#   ['PDT', 'NP|<DT-JJ>'],
#   ['PRP$', 'NP|<JJ-ADJP>'],
#   ['PRP$', 'NP|<PRN-NN>'],
#   ['PRP$', 'NP|<JJ-NNP>'],
#   ['NP', 'NP|<PP-NP>'],
#   ['QP', 'NP|<DT-NNP>'],
#   ['NP', 'NP|<``-JJ>'],
#   ['JJ', 'NP|<NNS-POS>'],
#   ['NAC', 'POS'],
#   ['DT', 'NP|<ADJP-JJ>'],
#   ['JJR', 'NP|<JJ-CC>'],
#   ['DT', 'NP|<JJ-CC>'],
#   ['CD', 'NP|<ADJP-NNS>'],
#   ['NP', 'NP|<CONJP-NP>'],
#   ['NAC', 'NP|<NNP-NNP>'],
#   ['NP', 'PP-CLR'],
#   ['JJS', 'NP|<JJ-JJ>'],
#   ['ADVP-TMP', 'NP|<NP-JJS>'],
#   ['NP', 'NP|<NN-SBAR>'],
#   ['RB', 'DT'],
#   ['NP', 'NP|<CD-NNP>'],
#   ['JJ', 'NP|<NN-S>'],
#   ['NN', 'NP|<NNS-CC>'],
#   ['DT', 'NP|<NAC-LOC-,>'],
#   ['IN', 'NP|<JJ-NN>'],
#   ['DT', 'NP|<JJS-CD>'],
#   ['NP', 'NP|<JJS-CC>'],
#   ['ADJP', 'NP|<NN-NNP>'],
#   ['PRP$', 'NP|<CD-ADJP>'],
#   ['NP', 'NP|<PP-TMP-PP-TMP>'],
#   ['CD', 'NP|<CC-CD>'],
#   ['DT', 'NP|<NN-``>'],
#   ['DT', 'NP|<NN-NNP>'],
#   ['DT', 'NP|<NNP-JJ>'],
#   ['VBG', 'NN'],
#   ['DT', 'NP|<RBS-JJ>'],
#   ['NN', 'NP|<,-NN>'],
#   ['CD', 'NP|<NN-JJ>'],
#   ['NP', 'NP|<PP-LOC-ADVP-TMP>'],
#   ['NP', 'NP|<PP-LOC-,>'],
#   ['DT', "NP|<''-NNS>"],
#   ['PRP', 'NP|<NN-NN>'],
#   ['NP', 'NP|<,-RB>'],
#   ['PDT', 'DT'],
#   ['PDT', 'NP|<DT-NNS>'],
#   ['DT', 'NP|<ADJP-NX-TTL>'],
#   ['NP', 'ADVP-LOC'],
#   ['RB', 'NP|<DT-NN>'],
#   ['NP', 'NP|<CC-NP-TTL>'],
#   ['NP', 'S-NOM'],
#   ['PRP$', 'NP|<NNS-CC>'],
#   ['DT', 'ADJP'],
#   ['NP', 'NX'],
#   ['DT', 'NX-TTL'],
#   ['PRP$', 'NP|<NX-TTL-JJ>'],
#   ['NX-TTL', 'NP|<NNS-POS>'],
#   ['NP-TTL', 'NP|<CC-NP-TTL>'],
#   ['ADVP', 'NP|<DT-JJ>'],
#   ['NP-TTL', 'NP|<,-SBAR>'],
#   ['NP', 'NP|<PP-S-1>'],
#   ['DT', 'NP|<NNS-S>'],
#   ['NNP', 'NP|<NNPS-CC>'],
#   ['CD', 'NP|<NN-NNS>'],
#   ['JJ', 'NP|<JJ-NNP>'],
#   ['ADJP', 'NP|<JJ-NN>'],
#   ['NNPS', 'POS'],
#   ['NP', 'NP|<NNS-S>'],
#   ['JJR', 'NP|<JJ-NN>'],
#   ['CD', 'CD'],
#   ['NP', 'NP|<PP-ADVP>'],
#   ['DT', 'NP|<CD-JJS>'],
#   ['DT', 'NP|<JJR-NNP>'],
#   ['NP', 'SBAR-PRP'],
#   ['NNPS', 'NNP'],
#   ['NNP', 'NP|<NNP-JJ>'],
#   ['CD', 'NP|<NP-NNS>'],
#   ['QP', 'NP|<NN-NN>'],
#   ['NP', 'NP|<,-SBAR-TMP>'],
#   ['NP', 'NP|<NNS-SBAR>'],
#   ['DT', 'NP|<NNPS-NNP>'],
#   ['DT', 'NP|<NAC-NN>'],
#   ['JJ', 'NP|<NN-NNP>'],
#   ['NN', 'NP|<NN-CC>'],
#   ['DT', 'NP|<JJ-JJS>'],
#   ['NP', 'NP|<PP-TMP-PP>'],
#   ['NAC-LOC', 'NN'],
#   ['DT', 'NP|<NNS-NN>'],
#   ['QP', 'NP|<NNP-NN>'],
#   ['CD', 'NP|<JJ-JJ>'],
#   ['NP', 'NP|<NN-CD>'],
#   ['PRP$', 'NP|<JJS-JJ>'],
#   ['NP', 'NP|<ADJP-NN>'],
#   ['PRP$', 'NP|<NN-POS>'],
#   ['NP', "NP|<,-''>"],
#   ['NP', 'NP|<PP-RRC>'],
#   ['NN', 'NP|<CC-NNS>'],
#   ['NP', 'RRC'],
#   ['NP', 'NP|<PP-LOC-VP>'],
#   ['NP', 'NP|<SBAR-.>'],
#   ['LST', 'NP|<NP-VP>'],
#   ['LST', 'NP|<JJ-JJ>'],
#   ['NP', 'NP|<NP-.>'],
#   ['DT', 'NP|<NN-ADJP>'],
#   ['DT', 'NP|<VBN-ADJP>'],
#   ['NP', 'NP|<,-PP-TMP>'],
#   ['PRP$', 'NP|<JJS-NN>'],
#   ['DT', 'NP|<NN-PP-DIR>'],
#   ['JJR', 'NP|<JJ-NX>'],
#   ['JJ', 'NP|<JJ-NX>'],
#   ['PRP$', 'NP|<NAC-LOC-NN>'],
#   ['VBN', 'NP|<JJ-NN>'],
#   ['NNP', '.'],
#   ['UCP', 'NN'],
#   ['JJ', 'NP|<NNP-JJ>'],
#   ['JJR', 'NP|<NNP-NN>'],
#   ['NN', 'VBG'],
#   ['DT', 'NP|<VBG-NNP>'],
#   ['NP', 'NP|<NP-TMP-PP>'],
#   ['RB', 'JJR'],
#   ['``', "NP|<NNP-''>"],
#   ['DT', 'NP|<CD-NX>'],
#   ['NP', 'NP|<:-S>'],
#   ['JJ', 'NP|<NNP-POS>'],
#   ['RB', 'NP|<CD-NNS>'],
#   ['NP', 'SBAR-TMP'],
#   ['JJR', 'NP|<DT-NN>'],
#   ['NP', 'NP|<JJR-NNS>'],
#   ['NP', "NP|<''-PP>"],
#   ['NP', 'NP|<NN-CC>'],
#   ['RB', 'NP|<NN-NNS>'],
#   ['PRP$', 'NP|<NNP-NN>'],
#   ['DT', 'NP|<JJR-JJ>'],
#   ['PRP$', 'NP|<RB-VBN>'],
#   ['$', 'NP|<QP--NONE->'],
#   ['NNP', 'NP|<NNPS-POS>'],
#   ['DT', 'NP|<``-ADJP>'],
#   ['S-NOM', 'NP|<CC-NP>'],
#   ['JJ', 'NP|<ADJP-NNS>'],
#   ['CD', 'NP|<NNS-QP>'],
#   ['QP', 'NP|<DT-JJ>'],
#   ['DT', 'NP|<NAC-TMP-NN>'],
#   ['PRP$', 'NP|<NNPS-NNP>'],
#   ['CD', 'NP|<VBN-NNS>'],
#   ['ADJP', 'NP|<NNP-NNPS>'],
#   ['NP', 'NP|<ADJP-VP>'],
#   ['PRP$', 'NP|<CD-NNP>'],
#   ['DT', 'NP|<JJS-VBG>'],
#   ['NP', 'UCP'],
#   ['VBN', 'NP|<JJ-NNS>'],
#   ['DT', 'NP|<NNP-IN>'],
#   ['DT', 'NP|<JJR-NNS>'],
#   ['DT', 'NP|<CD-CC>'],
#   ['NP', 'NP|<NP-ADV-QP-1>'],
#   ['QP', 'NP|<-NONE--QP>'],
#   ['NP', 'NP|<NP-ADV-ADVP>'],
#   ['NP', 'NP|<PP-LOC-NP>'],
#   ['NP', 'NNPS'],
#   ['ADVP-TMP', 'NP|<$-CD>'],
#   ['JJ', 'NP|<JJ-NNPS>'],
#   ['NNP', 'NP|<DT-NNP>'],
#   ['NP', 'NP|<PP-PRN>'],
#   ['DT', 'RB'],
#   ['JJ', 'NP|<DT-NN>'],
#   ['NP', 'NP|<PP-ADVP-LOC>'],
#   ['PRP$', 'NP|<VBN-NNS>'],
#   ['CD', 'JJ'],
#   ['NP', 'NP|<NP-PP>'],
#   ['VBZ', 'S'],
#   ['NP', 'NP|<CC-ADVP>'],
#   [':', 'NP|<NP-PP>'],
#   ['JJ', 'VBG'],
#   ['DT', 'NP|<$-CD>'],
#   ['NP', 'NP|<PP-LOC-PP>'],
#   ['JJ', 'SBAR'],
#   ['JJ', 'NP|<VBN-NN>'],
#   ['``', "NP|<QP-''>"],
#   ['DT', 'NP|<NNP-.>'],
#   ['RB', 'NNP'],
#   ['NP', 'NP|<ADJP-JJ>'],
#   ['NN', 'NP|<NNP-POS>'],
#   ['CD', 'NP|<NNP-NN>'],
#   ['NP', 'NP|<VP-PP-LOC>'],
#   ['NNS', 'NP|<CC-NN>'],
#   ['NP', 'NP|<PP-ADVP-TMP>'],
#   ['QP', 'NP|<NNP-CC>'],
#   ['NP', 'NP|<JJR-NN>'],
#   ['NP', 'NP|<JJS-VBG>'],
#   ['NAC', 'NP|<NN-NN>'],
#   ['JJ', 'NP|<,-ADJP>'],
#   ['NP', 'NP|<JJ-NNP>'],
#   ['NNS', 'NP|<,-NN>'],
#   ['DT', 'NP|<JJ-VBG>'],
#   ['S-NOM', 'NP|<,-NP>'],
#   ['ADJP', 'NP|<NN-QP>'],
#   ['PRP$', 'NP|<NNP-NNS>'],
#   ['PRP$', 'NP'],
#   ['NP', 'NP|<RB-NP>'],
#   ['NP', 'NP|<ADVP-PP>'],
#   ['PRP$', 'NP|<JJ-VBG>'],
#   ['ADJP', 'NP|<-LRB--NNS>'],
#   ['DT', 'NP|<NN-JJ>'],
#   ['CD', 'NP|<ADJP-JJ>'],
#   ['RB', 'NP|<DT-QP>'],
#   ['VBG', 'NP|<NNS-.>'],
#   ['VBN', 'NP|<NNS-NNS>'],
#   ['VBG', 'NX'],
#   ['PRP$', 'NP|<NP-CD>'],
#   ['CD', 'NP|<RB-.>'],
#   ['CD', 'RB'],
#   ['PRP$', 'NP|<VBG-JJ>'],
#   ['NNP', 'NP|<CD-JJ>'],
#   ['JJ', 'NP|<NNS-NNS>'],
#   ['JJ', 'NP|<VBG-NN>'],
#   ['DT', 'NP|<VBG-CD>'],
#   [':', 'NP|<NP-,>'],
#   ['PRP$', 'NP|<JJ-``>'],
#   ['QP', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<PP-:>'],
#   ['DT', 'NP|<RBR-JJ>'],
#   ['NP', 'NP|<PRN-VP>'],
#   ['DT', 'VBG'],
#   ['NP', 'NP|<JJS-NN>'],
#   ['DT', 'NP|<RB-JJ>'],
#   ['DT', 'NP|<CD-VBN>'],
#   ['NP', 'NP|<ADJP-NNS>'],
#   ['NP', 'NP|<ADVP-LOC-PP>'],
#   ['NP', 'NP|<ADVP-DIR-PP-DIR>'],
#   ['CD', 'NP|<,-CD>'],
#   ['NNP', 'NP|<CD-NNS>'],
#   ['JJR', 'NP|<NN-NN>'],
#   ['PRP$', 'NP|<NNP-CD>'],
#   ['DT', 'NP|<JJ-$>'],
#   ['NP', 'NP|<NP-LOC-.>'],
#   ['QP', 'NP|<PRP$-NN>'],
#   ['PRP$', 'NP|<NN-CC>'],
#   ['PRP$', 'NP|<UCP-NN>'],
#   ['JJ', 'NP|<``-NN>'],
#   ['NP', 'NP|<,-ADVP-TMP>'],
#   ['NNS', 'NP|<,-CC>'],
#   ['NNP', 'NP|<IN-NNP>'],
#   ['``', 'NP|<NP-PP-LOC>'],
#   ['DT', 'NP|<NP-CC>'],
#   ['NP', 'NP|<``-S-TTL>'],
#   ['PDT', 'NP|<DT-NN>'],
#   ['NNPS', 'NNPS'],
#   ['NN', 'NP|<CC-JJ>'],
#   ['NP', 'NP|<PRN-:>'],
#   ['ADVP-TMP', 'NN'],
#   ['NP', 'NP|<NNS-NNS>'],
#   ['DT', 'NP|<NNS-NNS>'],
#   ['DT', 'NP|<JJ-NX>'],
#   ['DT', 'NP|<NNP-NX>'],
#   ['JJ', 'NP|<NNP-CD>'],
#   ['ADVP', 'NP|<NP-CC>'],
#   ['DT', 'NP|<NNS-RB>'],
#   ['CC', 'NP|<DT-NNP>'],
#   ['RB', 'NP|<RBR--LRB->'],
#   ['NP', 'NP|<PP-SBAR-TMP>'],
#   ['NN', 'NP|<NNS-NN>'],
#   ['NP', 'NP|<:-ADJP>'],
#   ['NP', 'NP|<:-SQ>'],
#   ['NP', 'NP|<JJ-ADJP>'],
#   ['PRP$', 'NP|<CD-JJR>'],
#   ['NN', 'NP|<JJ-NN>'],
#   ['PRP$', 'NP|<NNS-NN>'],
#   ['JJ', 'NP|<NN-VBZ>'],
#   ['DT', 'NP|<VBN-QP>'],
#   ['JJ', 'NP|<NN-VBG>'],
#   ['NP', 'NP|<PP-CLR-PP>'],
#   ['NN', 'NP|<VBG-NNS>'],
#   ['IN', 'NP|<DT-NN>'],
#   ['NP', 'PRN+SBAR'],
#   ['NP', 'NP|<RB-RB>'],
#   ['DT', 'NP|<VBN-JJ>'],
#   ['``', 'NP|<RB-DT>'],
#   ['JJS', 'NP|<NN-NNS>'],
#   ['NNP', 'NP|<CC-JJ>'],
#   ['``', 'NN'],
#   ['NP', 'NP|<NAC-LOC-NN>'],
#   ['QP', 'NP|<VBN-NNS>'],
#   ['JJ', 'NP|<UCP-NNS>'],
#   ['RB', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<JJS-VBN>'],
#   ['JJS', 'NP|<RB-JJ>'],
#   ['DT', 'NP|<``-NNS>'],
#   ['NP', 'NP|<PP-NP-LOC>'],
#   ['UCP', 'NNS'],
#   ['NP', 'NP-LOC'],
#   ['NNS', 'NP|<CONJP-NNS>'],
#   ['DT', 'NP|<RB-CD>'],
#   ['DT', 'NP|<CD-NNP>'],
#   ['PRP$', 'NP|<NNS-,>'],
#   ['NN', 'NP|<JJ-NNS>'],
#   ['CD', 'NP|<NN-QP>'],
#   ['CD', 'NP|<CC-JJR>'],
#   ['DT', 'NP|<NAC-NNS>'],
#   ['DT', 'NP|<CD-CD>'],
#   ['VBG', 'NP|<CC-NN>'],
#   ['DT', 'NP|<NNS-,>'],
#   ['NP', 'NP|<PP-S>'],
#   ['NAC', 'NNS'],
#   ['DT', 'NP|<RB-JJS>'],
#   ['NP', 'NP|<:-SBARQ-NOM>'],
#   ['DT', 'JJR'],
#   ['VBN', 'NP|<NN-NN>'],
#   ['DT', 'NP|<NNP-VBN>'],
#   ['JJ', 'NP|<CD-NNS>'],
#   ['NP', 'NP|<NP-TMP-PP-LOC>'],
#   ['NNP', 'NP|<CD-,>'],
#   ['DT', 'NP|<JJ-UCP>'],
#   ['CD', 'NP|<CD-NN>'],
#   ['NP', 'NP|<PP-.>'],
#   ['JJ', 'NP|<NNP-NN>'],
#   ['NP', 'NP|<:-NP+NP>'],
#   ['NP', 'NP|<VP-.>'],
#   ['NNP', 'NP|<NNP-PRN>'],
#   ['NNP', 'NP|<RB-NNS>'],
#   ['NNP', 'NP|<NN-VBN>'],
#   ['NN', 'NP|<VBD-NNS>'],
#   ['NP', 'NP|<:-VP>'],
#   ['NP', 'NP|<:-RB>'],
#   ['NP', 'NP|<JJ-CC>'],
#   ['DT', 'NP|<RB-VBN>'],
#   ['PRP', 'NN'],
#   ['NP', 'NP|<:-``>'],
#   ['NP', 'NP|<NN-PRN>'],
#   ['NP', 'NP|<PP-TMP-VP>'],
#   ['DT', 'NP|<CC-DT>'],
#   ['``', "NP|<JJ-''>"],
#   ['NP', 'NP|<PP-PP-PRP>'],
#   ['NP', 'NP|<NNS-CC>'],
#   ['NP', 'NP|<``-VP>'],
#   ['PRP$', 'NP|<JJR-NN>'],
#   ['DT', 'NP|<VBN-NNS>'],
#   ['JJ', 'NP|<CC-DT>'],
#   ['NNP', 'NP|<NN-,>'],
#   ['ADJP', 'NP|<DT-NN>'],
#   ['DT', 'NP|<NN-QP>'],
#   ['NP', 'NP|<PP-LOC-1-PP-DIR-2>'],
#   ['PP-LOC=1', 'PP-DIR=2'],
#   ['ADJP', 'NNP'],
#   ['NP', 'NP|<ADJP-NP-TMP>'],
#   ['NP', 'NP|<VBN-NNP>'],
#   ['DT', 'NP|<CC-NN>'],
#   ['PRP$', 'NP|<IN-NNS>'],
#   ['``', 'NP|<NP-NN>'],
#   ['NP', 'JJ'],
#   ['NN', 'NP|<CC-DT>'],
#   ['DT', 'NP|<NN-CD>'],
#   ['NP', 'NP|<VBN-NN>'],
#   ['NP', 'NP|<CC-PRN>'],
#   ['IN', 'NP|<CD-NNS>'],
#   ['NP', 'NP|<-LRB--NP>'],
#   ['DT', 'NP|<NN-VBG>'],
#   ['NP', 'NP|<VBN-NNS>'],
#   ['RB', 'NP|<DT-NNS>'],
#   ['NNPS', 'NP|<NNP-NNP>'],
#   ['NP', 'NP|<TO-NP>'],
#   ['PRP$', 'NP|<CD-CC>'],
#   ['NN', 'NP|<NNS-POS>'],
#   ['IN', 'NP|<DT-JJ>'],
#   ['NN', 'NP|<NNS-NNS>'],
#   ['RB', 'NP|<CD-NN>'],
#   ['DT', 'NP|<ADJP-``>'],
#   ['LST', 'NP|<VBN-NN>'],
#   ['LST', 'NP|<DT-JJ>'],
#   ['LST', 'NP|<NP-PP>'],
#   ['DT', 'NP|<ADJP-CD>'],
#   ['RB', 'NNPS'],
#   ['NP+QP', 'NP-ADV'],
#   ['ADJP', 'JJR'],
#   ['NP', "NP|<''-ADVP>"],
#   ['PDT', 'NP|<DT-NNP>'],
#   ['NP', 'NP|<``-NNS>'],
#   ['ADJP', 'NP|<VBN-NN>'],
#   ['VBG', 'NP|<JJ-NNS>'],
#   ['DT', 'NP|<NN-,>'],
#   ['PDT', 'NP|<PRP$-NNS>'],
#   ['NP', "NP|<''-VP>"],
#   ['QP', 'NP|<NNS-NN>'],
#   ['``', "NP|<NN-''>"],
#   ['JJ', "NP|<NN-''>"],
#   ['DT', 'NP|<NN-VBZ>'],
#   ['NAC-LOC', 'NP|<CD-NNP>'],
#   ['NP', '.'],
#   ['NP', 'NP|<PP-ADJP>'],
#   ['NP', 'NP|<NNPS-NNP>'],
#   ['DT', 'NP|<ADJP-QP>'],
#   ['JJ', 'NP|<NN-JJ>'],
#   ['$', 'NP|<CD-CD>'],
#   ['CD', 'NP|<JJ-CC>'],
#   ['NP', 'NP|<QP-.>'],
#   ['NP', 'NP|<NP-TMP-,>'],
#   ['VB', 'NN'],
#   ['CD', 'NP|<CD-JJ>'],
#   ['NP', 'NP|<PP-TMP-,>'],
#   ['ADJP', 'NP|<ADJP-NNS>'],
#   ['NP', 'NP|<CD-JJS>'],
#   ['CD', 'NP|<NN-CC>'],
#   ['NP', 'NP|<PP-LOC-PRN>'],
#   ['SBAR-NOM', 'NP|<CC-NP>'],
#   ['NP', 'NP|<JJ-``>'],
#   ['DT', 'NP|<NP-NN>'],
#   ['NNS', 'RB'],
#   ['RB', 'NP|<DT-VBG>'],
#   ['JJ', "NP|<NNS-''>"],
#   ['NP', 'NP|<VBN-QP>'],
#   ['ADVP', 'CD'],
#   ['CD', 'NP|<NNS-JJ>'],
#   ['NP', 'NP|<SBAR-SBAR>'],
#   ['JJ', 'NP|<CD-NNP>'],
#   ['NP', 'NP|<:-SBAR-NOM>'],
#   ['NN', 'RB'],
#   ['NP', 'NP|<PP-TMP-SBAR>'],
#   ['NP', 'QP'],
#   ['CD', 'NP|<CD-NNS>'],
#   ['PRP$', 'NP|<NN-JJ>'],
#   ['NP+QP', 'PP-TMP'],
#   ['NP', 'NP|<JJS-JJ>'],
#   ['#', 'NP|<CD--NONE->'],
#   ['ADJP', 'NP|<CD-NN>'],
#   ['VBD', 'NN'],
#   [':', 'NP|<NNP-NNP>'],
#   ['NN', 'NP|<NN-NNP>'],
#   ['NNPS', 'NP|<NNP-NNPS>'],
#   ['NP', 'NP|<RB-NN>'],
#   ['NP', 'NP|<S-CLR-NP-TMP>'],
#   ['NP', 'S-CLR'],
#   ['NP', 'ADVP-PRD'],
#   ['IN', 'NP|<QP--NONE->'],
#   ['NP', 'NP|<VBN-JJ>'],
#   ['NNPS', 'NP|<NNP-POS>'],
#   ['NN', 'NP|<VBD-NN>'],
#   ['NP', 'NP|<NN-PP>'],
#   ['NP-HLN', 'NP|<:-S>'],
#   ['IN', 'NP|<CD-NN>'],
#   ['NP-HLN', 'NP|<:-NP>'],
#   ['NP', 'NP|<JJ-IN>'],
#   ['NP', 'NP|<:-ADVP>'],
#   ['NP', 'NP|<:-S-NOM>'],
#   ['DT', 'NP|<ADJP-,>'],
#   ['NN', 'NP|<NN-SBAR>'],
#   ['NP', 'NP|<NP-TMP-S-1>'],
#   ['RB', 'NP|<NP-CC>'],
#   ['NP', 'NP|<``-SBAR>'],
#   ['CD', 'NP|<NN-NNP>'],
#   ['NP', 'NP|<QP-JJ>'],
#   ['JJ', 'NP|<CD-POS>'],
#   ['JJ', 'NP|<QP--NONE->'],
#   ['PRP$', 'NP|<NN-CD>'],
#   ['QP', 'NP|<NNS-X+PP>'],
#   ['DT', 'NP|<RB-S>'],
#   ['RBR', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<QP-NNS>'],
#   ['NP', 'NP|<NP-ADV-PP>'],
#   ['DT', 'NAC'],
#   ['NP-3', 'NP|<,-SBAR>'],
#   ['NP=3', 'NP|<,-ADVP-DIR=4>'],
#   ['CD', 'NP|<JJ-ADJP>'],
#   ['NNP', 'JJ'],
#   ['DT', 'VBD'],
#   ['NP', 'NP|<QP--NONE->'],
#   ['JJ', 'NP'],
#   ['VB', 'NP|<NN-NNS>'],
#   ['NP', 'NP|<PP-POS>'],
#   ['DT', 'NP|<QP-JJ>'],
#   ['VBN', 'NP|<NNP-JJ>'],
#   ['VBN', 'NP|<JJ-JJ>'],
#   ['VBG', 'NNP'],
#   ['NNP', 'NP|<``-NN>'],
#   ['VBN', 'NP|<NN-CC>'],
#   ['PRP$', 'NP|<NNP-CC>'],
#   ['NP', 'NP|<,-PRN>'],
#   ['VBG', 'NP|<NN-NN>'],
#   ['NP', 'NP|<CC-RB>'],
#   ['NNP', 'NP|<NNS-POS>'],
#   ['NP', ':'],
#   ['DT', 'NP|<JJ-NNPS>'],
#   ['DT', 'NP|<ADJP-NAC-LOC>'],
#   ['NP', 'NP|<PP-NP-ADV>'],
#   ['VBN', 'NP|<NN-SBAR>'],
#   ['RB', 'NP|<QP-JJ>'],
#   ['NP-TMP', 'NP|<:-NP>'],
#   ['RB', 'NP|<DT-``>'],
#   ['VBN', 'NP|<NNS-CC>'],
#   ['NP', 'NP|<PP-SBAR-2>'],
#   ['NP', 'NP|<CC-``>'],
#   ['``', 'NP|<NNP-NNP>'],
#   ['NP', 'NP|<PP-DIR-PP-DIR>'],
#   ['NNS', 'NNP'],
#   ['NN', 'NNP'],
#   ['PRP$', 'NP|<CD-JJ>'],
#   ['DT', 'NP|<NN-:>'],
#   ['UCP', 'NP|<JJ-NNS>'],
#   ['ADJP', 'NP|<``-JJ>'],
#   ['CONJP', 'NP|<NP-,>'],
#   ['NNPS', 'NNS'],
#   ['NN', 'NP|<CD--LRB->'],
#   ['NP', 'NP|<CD-JJ>'],
#   ['DT', 'NP|<VBG-QP>'],
#   ['QP', 'NP|<-NONE--NNS>'],
#   ['PRP$', 'NP|<UCP-NNS>'],
#   ['JJR', 'NP|<VBG-NN>'],
#   ['DT', 'RBS'],
#   ['PRP$', 'NP|<NN-VBG>'],
#   ['``', 'NP|<RB-JJ>'],
#   ['NNP', 'NP|<VBG-NNS>'],
#   ['JJR', 'NP|<NNS-CC>'],
#   ['DT', 'NP|<ADJP-NX>']],
#  'NP-SBJ|<,-ADJP>': [[',', 'NP-SBJ|<ADJP-,>'], [',', 'ADJP']],
#  'NP-SBJ|<ADJP-,>': [['ADJP', ',']],
#  'ADJP': [['NP', 'JJ'],
#   ['JJ', 'JJ'],
#   ['JJ', 'S'],
#   ['RB', 'JJ'],
#   ['RB', 'VBN'],
#   ['RB', 'JJR'],
#   ['RB', 'DT'],
#   ['JJ', 'PP'],
#   ['CD', 'NN'],
#   ['JJ', 'PRN'],
#   ['QP', 'NN'],
#   ['QP', '-NONE-'],
#   ['NP-ADV', 'JJR'],
#   ['VBG', 'ADJP|<CC-VBG>'],
#   ['RB', 'ADJP|<JJ-CC>'],
#   ['ADJP', 'PP'],
#   ['RB', 'ADJP|<RB-JJ>'],
#   ['VBN', 'PP'],
#   ['QP', 'JJR'],
#   ['RBR', 'JJ'],
#   ['$', 'ADJP|<JJ--NONE->'],
#   ['ADVP-TMP', 'VBN'],
#   ['CD', 'NNS'],
#   ['RB', 'ADJP|<JJ-PP>'],
#   ['JJ', 'ADJP|<CD-NN>'],
#   ['ADVP', 'JJ'],
#   ['ADJP', 'ADJP|<,-ADJP>'],
#   ['ADVP-TMP', 'JJ'],
#   ['RBS', 'JJ'],
#   ['JJR', 'ADJP|<CC-JJR>'],
#   ['$', 'ADJP|<CD--NONE->'],
#   ['ADVP-TMP', 'ADJP|<RB-JJ>'],
#   ['JJ', 'NP-TMP'],
#   ['ADVP', 'VBN'],
#   ['JJ', 'ADJP|<CC-JJ>'],
#   ['JJ', 'ADJP|<CC-NNP>'],
#   ['JJ', 'SBAR'],
#   ['JJ', 'PP-LOC'],
#   ['ADJP', 'ADJP|<,-CC>'],
#   ['NN', 'NN'],
#   ['ADJP', 'ADJP|<CC-ADJP>'],
#   ['RBS', 'ADJP|<RB-JJ>'],
#   ['NNP', 'JJ'],
#   ['JJ', 'ADJP|<,-JJ>'],
#   ['JJR', 'JJ'],
#   ['NNS', 'ADJP|<CC-NNS>'],
#   ['NNP', 'ADJP|<,-JJ>'],
#   ['NNP', 'NNP'],
#   ['ADVP', 'ADJP|<JJ-PP>'],
#   ['RB', 'ADJP|<``-JJ>'],
#   ['RB', 'RB'],
#   ['JJ', 'ADJP|<,-CC>'],
#   ['RB', 'ADJP|<VBN-PRT>'],
#   ['JJS', 'JJ'],
#   ['VBN', 'PP-CLR'],
#   ['RB', 'ADJP|<JJ-PP-LOC>'],
#   ['JJ', 'JJR'],
#   ['JJ', 'ADJP|<CC-VBG>'],
#   ['JJ', 'ADJP|<RB-SBAR>'],
#   ['NN', 'ADJP|<RB-SBAR>'],
#   ['QP', 'ADJP|<RB-JJ>'],
#   ['RB', 'ADJP|<RB-PP>'],
#   ['RB', 'ADJP|<RB-S>'],
#   ['NN', 'JJ'],
#   ['RB', 'ADJP|<RBR-JJ>'],
#   ['NNS', 'ADJP|<PRN-VBN>'],
#   ['RB', 'ADJP|<JJR-IN>'],
#   ['JJR', 'VBN'],
#   ['RB', 'VBG'],
#   ['RBS', 'VBN'],
#   ['JJR', 'PP'],
#   ['RBR', 'ADJP|<JJ-PP>'],
#   ['ADVP', 'ADJP|<RB-JJR>'],
#   ['DT', 'ADJP|<ADJP-CC>'],
#   ['``', "ADJP|<JJ-''>"],
#   ['JJS', 'ADJP|<JJ-S>'],
#   ['JJ', 'RB'],
#   ['$', 'ADJP|<CD-JJ>'],
#   ['CD', 'ADJP|<CD-NN>'],
#   ['JJ', 'PP-TMP'],
#   ['JJ', 'JJS'],
#   ['VB', 'JJR'],
#   ['NP-ADV', 'JJ'],
#   ['JJ', 'NP'],
#   ['VBN', 'JJ'],
#   ['NNP', 'ADJP|<NNP-,>'],
#   ['NN', 'ADJP|<CC-NN>'],
#   ['$', 'JJ'],
#   ['``', "ADJP|<RB-''>"],
#   ['JJ', 'ADJP|<CC-RB>'],
#   ['CD', 'JJ'],
#   ['IN', 'NN'],
#   ['NP', 'ADJP|<JJ-PP>'],
#   ['``', 'ADJP|<RB-VBN>'],
#   ['NNP', 'ADJP|<,-NNP>'],
#   ['JJ', 'VBN'],
#   ['VBN', 'ADJP|<CC-JJ>']],
#  'S|<VP-.>': [['VP', '.'], ['VP', "S|<.-''>"], ['VP', 'S|<.--RRB->']],
#  'VP': [['MD', 'VP'],
#   ['VB', 'VP|<NP-PP-CLR>'],
#   ['VBZ', 'NP-PRD'],
#   ['VBD', 'VP'],
#   ['VBN', 'S'],
#   ['VBN', 'VP|<NP-S-CLR>'],
#   ['TO', 'VP'],
#   ['VB', 'NP'],
#   ['VBZ', 'VP'],
#   ['VBN', 'NP'],
#   ['VBD', 'SBAR'],
#   ['VBZ', 'VP|<ADJP-PRD-SBAR-TMP>'],
#   ['VBZ', 'NP'],
#   ['VBG', 'NP'],
#   ['VBP', 'VP|<PRT-ADVP-TMP>'],
#   ['VBG', 'VP|<NP-PP-LOC-CLR>'],
#   ['VBN', 'VP|<NP-ADVP-TMP>'],
#   ['VBP', 'PP-LOC'],
#   ['VB', 'VP|<NP-PP-DIR>'],
#   ['VBD', 'VP|<,-``>'],
#   ['VBP', 'VP'],
#   ['VBG', 'PP-CLR'],
#   ['VBD', 'PP-CLR'],
#   ['VBZ', 'VP|<NP-PRD-PP-LOC>'],
#   ['VBD', 'NP'],
#   ['VBD', 'ADJP-PRD'],
#   ['VBP', 'NP'],
#   ['VBP', 'PP-PRD'],
#   ['VBD', 'S'],
#   ['VP', 'VP|<CC-VP>'],
#   ['VBN', 'VP|<NP-PP-CLR>'],
#   ['VBN', 'VP|<NP-PP>'],
#   ['VBD', 'VP|<ADVP-MNR-PP-CLR>'],
#   ['VBN', 'VP|<:-NP-1>'],
#   ['VBP', 'VP|<NP-,>'],
#   ['VBZ', 'S'],
#   ['VB', 'NP-PRD'],
#   ['VBD', 'PP-LOC-PRD'],
#   ['VBP', 'SBAR'],
#   ['VB', 'VP|<NP-ADVP-MNR>'],
# ...
#  "S-1|<.-''>": [['.', "''"]],
#  'NP|<PP-LOC-ADJP>': [['PP-LOC', 'ADJP']],
#  'VP|<PP-TMP-PRN>': [['PP-TMP', 'PRN'], ['PP-TMP', 'VP|<PRN-S-ADV>']],
#  'PRN|<CC-NP>': [['CC', 'NP'], ['CC', 'PRN|<NP-:>']],
#  'NP+QP': [['RB', 'NP+QP|<DT-NN>'],
#   ['JJ', 'NNS'],
#   ['RB', 'NN'],
#   ['RB', 'JJ'],
#   ['CD', 'NP+QP|<IN-CD>'],
#   ['RB', 'NP+QP|<IN-CD>'],
#   ['CD', 'CD'],
#   ['RB', 'DT'],
#   ['IN', 'CD'],
#   ['RB', 'CD'],
#   ['RB', 'NP+QP|<DT-JJ>'],
#   ['JJR', 'NP+QP|<IN-CD>'],
#   ['JJR', 'NP+QP|<IN-DT>'],
#   ['IN', 'NP+QP|<CD-CD>']],
#  'NP+QP|<DT-NN>': [['DT', 'NN']],
#  'NP-SBJ-44': [['NP', 'NP-SBJ-44|<,-NP>'], ['NP', 'PP']],
#  'NP-SBJ-44|<,-NP>': [[',', 'NP-SBJ-44|<NP-,>']],
#  'NP-SBJ-44|<NP-,>': [['NP', ',']],
#  'NP-SBJ|<NN-,>': [['NN', 'NP-SBJ|<,-NN>'],
#   ['NN', 'NP-SBJ|<,-CC>'],
#   ['NN', ',']],
#  'NP-SBJ|<,-NN>': [[',', 'NP-SBJ|<NN-CC>']],
#  'NP-SBJ|<NN-CC>': [['NN', 'NP-SBJ|<CC-NN>'],
#   ['NN', 'NP-SBJ|<CC-NNS>'],
#   ['NN', 'NP-SBJ|<CC-JJ>']],
#  'NP-SBJ|<NNS-NN>': [['NNS', 'NN'], ['NNS', 'NP-SBJ|<NN-CC>']],
#  'NP+NP|<JJ-NNP>': [['JJ', 'NP+NP|<NNP-NNP>']],
#  'NP+NP|<NNP-NNP>': [['NNP', 'NNP']],
#  'ADJP|<JJ--NONE->': [['JJ', '-NONE-']],
#  'NP|<ADJP-PP>': [['ADJP', 'PP'], ['ADJP', 'NP|<PP-SBAR>']],
#  'NP-SBJ-1|<,-VP>': [[',', 'NP-SBJ-1|<VP-,>']],
#  'NP-SBJ-1|<VP-,>': [['VP', ','], ['VP', "NP-SBJ-1|<,-''>"]],
#  'NP-SBJ-45': [['DT', 'NN']],
#  'NP|<PP-PP-TMP>': [['PP', 'PP-TMP'], ['PP', 'NP|<PP-TMP-,>']],
#  'VP|<PP-DIR-ADVP-TMP>': [['PP-DIR', 'ADVP-TMP'],
#   ['PP-DIR', 'VP|<ADVP-TMP-PP-DIR-2>']],
#  'NP|<JJR-ADJP>': [['JJR', 'NP|<ADJP-NN>']],
#  'NP|<PP-TMP-PP>': [['PP-TMP', 'PP'], ['PP-TMP', 'NP|<PP-,>']],
#  'NP-PRD|<:-NP>': [[':', 'NP'], [':', 'NP-PRD|<NP-:>']],
#  'QP|<JJR-IN>': [['JJR', 'QP|<IN-CD>']],
#  'VP|<VP-NP-TMP>': [['VP', 'VP|<NP-TMP-PRN>']],
#  'VP|<NP-TMP-PRN>': [['NP-TMP', 'VP|<PRN-PP>']],
#  'VP|<PRN-PP>': [['PRN', 'PP']],
#  'PRN|<NP-1-,>': [['NP-1', ',']],
#  'NP|<DT-NN>': [['DT', 'NN'], ['DT', 'NP|<NN-NN>'], ['DT', 'NP|<NN-S>']],
#  'PP-CLR|<PP-PP>': [['PP', 'PP']],
#  'S|<,-NP-SBJ-46>': [[',', 'S|<NP-SBJ-46-VP>']],
#  'S|<NP-SBJ-46-VP>': [['NP-SBJ-46', 'S|<VP-.>']],
#  'NP-SBJ-46': [['NP', 'NN'], ['NP', 'NP-SBJ-46|<,-NP>']],
#  'VP|<PP-LOC-ADVP-LOC>': [['PP-LOC', 'VP|<ADVP-LOC-ADVP-TMP>'],
#   ['PP-LOC', 'ADVP-LOC']],
#  'VP|<ADVP-LOC-ADVP-TMP>': [['ADVP-LOC', 'ADVP-TMP']],
#  "SINV|<S-TPC-1-''>": [['S-TPC-1', "SINV|<''-VP>"]],
#  'S-TPC-1|<:-SBARQ>': [[':', 'SBARQ']],
#  'SBARQ': [['WRB', 'SBARQ|<RP-FRAG+NP>'],
#   ['WHNP-1', 'SBARQ|<SQ-.>'],
#   ['WHNP-1', 'SBARQ|<S-.>'],
#   ['WHNP-2', 'SBARQ|<SQ-.>'],
#   ['WHNP-234', 'SBARQ|<SQ-.>'],
#   ['WHNP-247', 'SBARQ|<SQ-.>'],
#   ['WHADVP', 'SBARQ|<SQ-.>'],
#   ['FRAG', 'SBARQ|<,-SBARQ>'],
#   ['WHNP-1', 'SQ'],
#   ['WHADVP-1', 'SBARQ|<SQ-.>'],
#   ['WHNP-27', 'SQ'],
#   ['WHADVP-4', 'SQ'],
#   ['WHADVP-5', 'SQ'],
#   ['RB', 'SBARQ|<SBAR-ADV-,>'],
#   ['RB', 'SBARQ|<WHNP-78-SQ>']],
#  'SBARQ|<RP-FRAG+NP>': [['RP', 'SBARQ|<FRAG+NP-.>']],
#  'SBARQ|<FRAG+NP-.>': [['FRAG+NP', '.']],
#  'FRAG+NP': [['DT', 'FRAG+NP|<NNP-NNP>']],
#  'FRAG+NP|<NNP-NNP>': [['NNP', 'FRAG+NP|<NNP-NNP>'], ['NNP', 'NNP']],
#  'S-2|<VP-.>': [['VP', '.'], ['VP', "S-2|<.-''>"]],
#  'NP|<``-JJ>': [['``', 'NP|<JJ-NN>'],
#   ['``', "NP|<JJ-''>"],
#   ['``', 'NP|<JJ-,>'],
#   ['``', 'NP|<JJ-NNS>']],
#  'NP|<PRN-SBAR-TMP>': [['PRN', 'SBAR-TMP']],
#  'PRN|<S-,>': [['S', ','], ['S', 'PRN|<,-``>']],
#  'VP|<ADJP-PRD-ADVP-TMP>': [['ADJP-PRD', 'ADVP-TMP']],
#  'NP-PRD|<``-JJ>': [['``', "NP-PRD|<JJ-''>"], ['``', 'NP-PRD|<JJ-NN>']],
#  'VP|<PP-CLR-NP>': [['PP-CLR', 'NP'], ['PP-CLR', 'VP|<NP-ADVP-MNR>']],
#  'VP|<VP-VP-1>': [['VP', 'VP-1']],
#  'VP|<MD-VP>': [['MD', 'VP']],
#  'VP-1': [['VBN', 'VP-1|<NP-PP-LOC>'],
#   ['VBN', 'VP-1|<NP-PP>'],
#   ['VBG', 'NP'],
#   ['VBG', 'VP-1|<:-``>'],
#   ['VBG', 'PP'],
#   ['VBG', 'SBAR']],
#  'VP-1|<NP-PP-LOC>': [['NP', 'PP-LOC']],
#  'SINV|<S-TPC-2-VP>': [['S-TPC-2', 'SINV|<VP-NP-SBJ>']],
#  'S-TPC-2|<VP-,>': [['VP', ',']],
#  "VP|<S-''>": [['S', "VP|<''-ADVP-TMP>"],
#   ['S', "VP|<''-SBAR-PRP>"],
#   ['S', "VP|<''-PP-TMP>"],
#   ['S', "VP|<''-NP-TMP>"]],
#  "VP|<''-ADVP-TMP>": [["''", 'VP|<ADVP-TMP-SBAR-TMP>'], ["''", 'ADVP-TMP']],
#  'PP-LOC-TPC-1': [['IN', 'NP']],
#  'VP|<ADVP-DIR-PP-TMP>': [['ADVP-DIR', 'PP-TMP'],
#   ['ADVP-DIR', 'VP|<PP-TMP-ADVP-TMP>']],
#  'VP|<NP-ADVP-DIR>': [['NP', 'VP|<ADVP-DIR-S-PRP>'],
#   ['NP', 'VP|<ADVP-DIR-PP-TMP>'],
#   ['NP', 'VP|<ADVP-DIR-PP-DIR>'],
#   ['NP', 'VP|<ADVP-DIR-PP-CLR>'],
#   ['NP', 'VP|<ADVP-DIR-ADVP-TMP>'],
#   ['NP', 'VP|<ADVP-DIR-PP>'],
#   ['NP', 'ADVP-DIR']],
#  'VP|<ADVP-DIR-S-PRP>': [['ADVP-DIR', 'S-PRP']],
#  'ADVP-DIR|<CC-RB>': [['CC', 'RB']],
#  'VP|<PP-MNR-ADVP-MNR>': [['PP-MNR', 'ADVP-MNR']],
#  'VP|<NP-S-PRP-CLR>': [['NP', 'S-PRP-CLR']],
#  'S-PRP-CLR': [['NP-SBJ-1', 'VP'], ['NP-SBJ', 'VP']],
#  'FRAG|<:-NP-SBJ-1>': [[':', 'FRAG|<NP-SBJ-1-VP>']],
#  'FRAG|<NP-SBJ-1-VP>': [['NP-SBJ-1', 'FRAG|<VP-.>']],
#  'FRAG|<VP-.>': [['VP', '.']],
#  'VP|<NP-TMP-ADVP-TMP>': [['NP-TMP', 'ADVP-TMP']],
#  'S|<PRN-S>': [['PRN', 'S|<S-CC>']],
#  'S|<NP-SBJ-47-VP>': [['NP-SBJ-47', 'S|<VP-.>']],
#  'NP-SBJ-47': [['JJS', 'NP-SBJ-47|<NN-NNS>'], ['PRP$', 'NP-SBJ-47|<JJ-NN>']],
#  'NP-SBJ-47|<NN-NNS>': [['NN', 'NNS']],
#  'VP|<ADVP-PP-TMP>': [['ADVP', 'PP-TMP'],
#   ['ADVP', 'VP|<PP-TMP-S-PRP>'],
#   ['ADVP', 'VP|<PP-TMP-PP-TMP>']],
#  'WHNP-41': [['WHNP', 'PP']],
#  'VP|<ADJP-PRD-PP-1>': [['ADJP-PRD', 'VP|<PP-1-ADVP-TMP>'],
#   ['ADJP-PRD', 'VP|<PP-1-PRN>']],
#  'VP|<PP-1-ADVP-TMP>': [['PP-1', 'ADVP-TMP']],
#  'VP|<PP-CLR-PP-CLR>': [['PP-CLR', 'PP-CLR'],
#   ['PP-CLR', 'VP|<PP-CLR-,>'],
#   ['PP-CLR', 'VP|<PP-CLR-PP-TMP>']],
#  'VP|<PP-CLR-UCP-TMP>': [['PP-CLR', 'UCP-TMP']],
#  'UCP-TMP': [['PP', 'UCP-TMP|<CC-NP>'], ['SBAR', 'UCP-TMP|<CC-PP>']],
#  'UCP-TMP|<CC-NP>': [['CC', 'NP']],
#  'S|<NP-SBJ-1-ADVP-TMP>': [['NP-SBJ-1', 'S|<ADVP-TMP-VP>']],
#  'S|<NP-TMP-VP>': [['NP-TMP', 'VP'], ['NP-TMP', 'S|<VP-.>']],
#  'ADVP|<RBR-RB>': [['RBR', 'RB']],
#  'ADJP-PRD|<VBN-PP>': [['VBN', 'PP']],
#  'NP|<JJ-ADJP>': [['JJ', 'NP|<ADJP-NN>'], ['JJ', 'NP|<ADJP-NNS>']],
#  'VP|<PP-PP-CLR>': [['PP', 'PP-CLR'], ['PP', 'VP|<PP-CLR-PP>']],
#  'VP|<RB-ADVP>': [['RB', 'VP|<ADVP-ADJP-PRD>'],
#   ['RB', 'VP|<ADVP-VP>'],
#   ['RB', 'ADVP'],
#   ['RB', 'VP|<ADVP-NP-PRD>']],
#  'ADJP-PRD|<VBN-S>': [['VBN', 'S']],
#  'NP-SBJ|<ADJP-NNS>': [['ADJP', 'NNS']],
#  'S-PRD': [['NP-SBJ-2', 'VP'],
#   ['NP-SBJ', 'VP'],
#   ['NP-SBJ-18', 'VP'],
#   ['NP-SBJ-43', 'VP'],
#   ['NP-SBJ-79', 'VP'],
#   ['NP-SBJ-1', 'VP']],
#  'NP-SBJ|<JJ-NNPS>': [['JJ', 'NNPS']],
#  'NP-MNR': [['DT', 'NN'], ['NP', 'SBAR'], ['NNP', 'NP-MNR|<NNP-NNP>']],
#  'VP|<ADVP-VP>': [['ADVP', 'VP'], ['ADVP', 'VP|<VP-,>']],
#  'VP|<ADVP-CLR-ADVP-TMP>': [['ADVP-CLR', 'VP|<ADVP-TMP-S-PRP>'],
#   ['ADVP-CLR', 'ADVP-TMP']],
#  'VP|<ADVP-TMP-S-PRP>': [['ADVP-TMP', 'S-PRP']],
#  'VP|<:-``>': [[':', 'VP|<``-S>'],
#   [':', 'VP|<``-S-CLF>'],
#   [':', 'VP|<``-SBARQ-NOM>']],
#  'NP-SBJ|<SBAR-PP>': [['SBAR', 'PP']],
#  'VP|<PRT-S>': [['PRT', 'S']],
#  'NP-SBJ-49': [['DT', 'NNS'], ['DT', 'NN']],
#  'NP-SBJ-50': [['JJ', 'NNS'], ['NP', 'PP']],
#  'VP|<PP-LOC-ADVP-MNR>': [['PP-LOC', 'ADVP-MNR']],
#  'S|<,-PP-TMP>': [[',', 'S|<PP-TMP-,>']],
#  'VP|<ADJP-PRD-S-1>': [['ADJP-PRD', 'S-1']],
#  "VP|<''-SBAR>": [["''", 'SBAR']],
#  'ADJP-TMP': [['JJ', 'PP']],
#  'S|<NP-SBJ-51-VP>': [['NP-SBJ-51', 'S|<VP-.>']],
#  'NP-SBJ-51': [['NP', 'ADVP-LOC'], ['DT', 'NN']],
#  'VP|<PP-CLR-SBAR-TMP>': [['PP-CLR', 'SBAR-TMP'],
#   ['PP-CLR', 'VP|<SBAR-TMP-,>'],
#   ['PP-CLR', 'VP|<SBAR-TMP-ADVP>']],
#  'PRN|<SBAR-,>': [['SBAR', ',']],
#  'NX|<NNP-NNP>': [['NNP', 'NNP']],
#  'ADJP|<JJ-PP>': [['JJ', 'PP']],
#  'NP-SBJ-1|<CC-NP>': [['CC', 'NP'],
#   ['CC', 'NP-SBJ-1|<NP-DT>'],
#   ['CC', 'NP-SBJ-1|<NP-,>']],
#  'NP-SBJ|<JJS-NN>': [['JJS', 'NN'], ['JJS', 'NP-SBJ|<NN-NN>']],
#  'VP|<ADVP-CLR-PP-DIR>': [['ADVP-CLR', 'VP|<PP-DIR-PP-DIR>'],
#   ['ADVP-CLR', 'PP-DIR']],
#  'S|<,-ADVP>': [[',', 'S|<ADVP-,>'],
#   [',', 'S|<ADVP-VP>'],
#   [',', 'S|<ADVP-NP-SBJ>'],
#   [',', 'S|<ADVP-ADVP=3>']],
#  'S|<ADVP-,>': [['ADVP', 'S|<,-ADVP>'],
#   ['ADVP', 'S|<,-NP-SBJ>'],
#   ['ADVP', 'S|<,-VP>'],
#   ['ADVP', 'S|<,-NP-SBJ-33>'],
#   ['ADVP', 'S|<,-S>'],
#   ['ADVP', 'S|<,-NP-SBJ-3>']],
#  'VP|<ADVP-CLR-PP-TMP>': [['ADVP-CLR', 'VP|<PP-TMP-PP-TMP>'],
#   ['ADVP-CLR', 'VP|<PP-TMP-ADVP-TMP>'],
#   ['ADVP-CLR', 'PP-TMP']],
#  'VP|<,-NP-1>': [[',', 'NP-1']],
#  'NP-SBJ-1|<PP-LOC-PP-TMP>': [['PP-LOC', 'PP-TMP']],
#  "S|<SBARQ-TPC-1-''>": [['SBARQ-TPC-1', "S|<''-NP-SBJ>"]],
#  'SBARQ-TPC-1': [['WHNP-46', 'SBARQ-TPC-1|<SQ-.>']],
#  'WHNP-46': [['WP', 'NN']],
#  'SBARQ-TPC-1|<SQ-.>': [['SQ', '.']],
#  'SQ': [['VBZ', 'SQ|<NP-SBJ-2-VP>'],
#   ['VBZ', 'SQ|<NP-SBJ-ADVP-TMP>'],
#   ['VBZ', 'SQ|<NP-SBJ-VP>'],
#   ['INTJ', 'SQ|<,-VBP>'],
#   ['VBZ', 'SQ|<NP-SBJ-PP-LOC-PRD>'],
#   ['VBZ', 'SQ|<NP-SBJ-NP-PRD>'],
#   ['NP-SBJ', 'VP'],
#   ['ADVP-MNR', 'SQ|<MD-NP-SBJ-1>'],
#   ['VBZ', 'SQ|<NP-SBJ-ADJP-PRD>'],
#   ['VBP', 'SQ|<NP-SBJ-1-ADVP-TMP>'],
#   ['MD', 'SQ|<NP-SBJ-VP>'],
#   ['CC', 'SQ|<MD-NP-SBJ>'],
#   ['VBP', 'SQ|<NP-SBJ-VP>'],
#   ['CC', 'SQ|<VBZ-RB>'],
#   ['VBD', 'SQ|<RB-NP-SBJ>'],
#   ['VBZ', 'SQ|<NP-SBJ-ADVP-PRD>'],
#   ['``', 'SQ|<VBP-NP-SBJ>'],
#   ['VBD', 'SQ|<``-NP-SBJ>'],
#   ['MD', 'SQ|<NP-SBJ-ADVP>'],
#   ['VBP', 'SQ|<NP-SBJ-2-RB>']],
#  'SQ|<NP-SBJ-2-VP>': [['NP-SBJ-2', 'VP']],
#  'VP|<ADVP-MNR-:>': [['ADVP-MNR', 'VP|<:-SBAR-ADV>']],
#  'VP|<:-SBAR-ADV>': [[':', 'SBAR-ADV']],
#  'FRAG+ADVP': [['IN', 'DT']],
#  "NP|<NP-''>": [['NP', "NP|<''-SBAR>"],
#   ['NP', "NP|<''-PP-LOC>"],
#   ['NP', "NP|<''-CC>"],
#   ['NP', "NP|<''-NNS>"]],
#  'VP|<PP-PRP-,>': [['PP-PRP', 'VP|<,-PP>'], ['PP-PRP', "VP|<,-''>"]],
#  'NP|<NNS-SBAR>': [['NNS', 'SBAR']],
#  'VP|<ADVP-PRD-PP-TMP>': [['ADVP-PRD', 'PP-TMP'],
#   ['ADVP-PRD', 'VP|<PP-TMP-PP-DIR-3>'],
#   ['ADVP-PRD', 'VP|<PP-TMP-PP>']],
#  'ADVP-PRD': [['RB', 'ADVP-PRD|<NP-PP>'],
#   ['JJ', 'ADVP-PRD|<NP-PP>'],
#   ['RB', 'RB'],
#   ['RP', 'S'],
#   ['RB', 'NP'],
#   ['IN', 'ADVP'],
#   ['RB', 'IN'],
#   ['VBN', 'PP'],
#   ['IN', 'NP'],
#   ['RB', 'PP']],
#  'ADVP-PRD|<NP-PP>': [['NP', 'PP']],
#  'VP|<PP-TMP-PP-DIR-3>': [['PP-TMP', 'PP-DIR-3']],
#  'PP-DIR-3': [['TO', 'NP']],
#  'VP|<NP-PRN>': [['NP', 'PRN'],
#   ['NP', 'VP|<PRN-PP-CLR>'],
#   ['NP', 'VP|<PRN-S-PRP>'],
#   ['NP', 'VP|<PRN-SBAR-PRP>']],
#  'PP|<ADVP-RB>': [['ADVP', 'PP|<RB-PP-TMP>']],
#  'PP|<RB-PP-TMP>': [['RB', 'PP-TMP']],
#  'VP|<ADVP-PRD-PP>': [['ADVP-PRD', 'PP'], ['ADVP-PRD', 'VP|<PP-ADVP-LOC>']],
#  'VP|<PP-TMP-PP>': [['PP-TMP', 'PP'],
#   ['PP-TMP', 'VP|<PP-,>'],
#   ['PP-TMP', 'VP|<PP-PP-TMP>'],
#   ['PP-TMP', 'VP|<PP-PP>']],
#  'PP-TMP|<IN-NP>': [['IN', 'NP']],
#  'S-TPC-2|<,-NP-SBJ>': [[',', 'S-TPC-2|<NP-SBJ-VP>']],
#  'S-TPC-2|<NP-SBJ-VP>': [['NP-SBJ', 'VP']],
#  'SINV|<,-VP>': [[',', 'SINV|<VP-NP-SBJ>']],
#  'VP|<PP-PRD-LOC-PP-TMP>': [['PP-PRD-LOC', 'VP|<PP-TMP-S-PRP>']],
#  'PP-PRD-LOC': [['IN', 'NP'], ['ADVP', 'PP-PRD-LOC|<IN-NP>']],
#  'ADJP|<CD-NN>': [['CD', 'NN']],
#  'VP|<PP-TMP-S-PRP>': [['PP-TMP', 'S-PRP']],
#  'NP-SBJ-1+NP': [['NP', 'NP-SBJ-1+NP|<NN-NN>'],
#   ['DT', 'NP-SBJ-1+NP|<``-NNP>']],
#  'NP-SBJ-1+NP|<NN-NN>': [['NN', 'NN']],
#  'PRN|<SBAR-ADV-,>': [['SBAR-ADV', ',']],
#  'NP-SBJ+NP': [['NP', 'PP'],
#   ['ADJP', 'NNP'],
#   ['NP', 'NP-SBJ+NP|<CC-NP>'],
#   ['NP', 'SBAR']],
#  'PP|<NP-PP-TMP>': [['NP', 'PP-TMP']],
#  'VP|<SBAR-,>': [['SBAR', 'VP|<,-PP-1>'],
#   ['SBAR', 'VP|<,-PP>'],
#   ['SBAR', 'VP|<,-S-ADV>'],
#   ['SBAR', 'VP|<,-SBAR-ADV>'],
#   ['SBAR', 'VP|<,-RB>'],
#   ['SBAR', 'VP|<,-SBAR-PRP>']],
#  'VP|<ADVP-PRD-NP-TMP>': [['ADVP-PRD', 'NP-TMP']],
#  'VP|<ADVP-MNR-PP-TMP>': [['ADVP-MNR', 'VP|<PP-TMP-SBAR-1>'],
#   ['ADVP-MNR', 'VP|<PP-TMP-,>'],
#   ['ADVP-MNR', 'PP-TMP']],
#  'VP|<PP-TMP-SBAR-1>': [['PP-TMP', 'SBAR-1']],
#  'NP-SBJ-56': [['NP', 'NN']],
#  'PP-TPC-1': [['IN', 'NP']],
#  'VP|<RB-VBG>': [['RB', 'VP|<VBG-ADVP>']],
#  'VP|<VBG-ADVP>': [['VBG', 'ADVP']],
#  'QP|<RB-DT>': [['RB', 'DT']],
#  'VP|<NP-PP-PUT>': [['NP', 'PP-PUT'],
#   ['NP', 'VP|<PP-PUT-PP-PRP>'],
#   ['NP', 'VP|<PP-PUT-SBAR-TMP>'],
#   ['NP', 'VP|<PP-PUT-S-PRP>']],
#  'PP-PUT': [['IN', 'NP'], ['IN', 'PP']],
#  'NP-SBJ|<PP-PP>': [['PP', 'NP-SBJ|<PP-PP>'],
#   ['PP', 'PP'],
#   ['PP', 'NP-SBJ|<PP-,>']],
#  'NP|<``-NX-TTL+NP>': [['``', "NP|<NX-TTL+NP-''>"]],
#  "NP|<NX-TTL+NP-''>": [['NX-TTL+NP', "NP|<''-PRN>"]],
#  'NX-TTL+NP': [['DT', 'NX-TTL+NP|<NNP-NNP>']],
#  'NX-TTL+NP|<NNP-NNP>': [['NNP', 'NX-TTL+NP|<NNP-NNP>'], ['NNP', 'NNP']],
#  "NP|<''-PRN>": [["''", 'PRN']],
#  'PRN|<NP-,>': [['NP', 'PRN|<,-NP>'],
#   ['NP', 'PRN|<,-NP-LOC>'],
#   ['NP', 'PRN|<,-PP>'],
#   ['NP', 'PRN|<,-IN>'],
#   ['NP', ',']],
#  'PRN|<,-NP>': [[',', 'PRN|<NP-,>'],
#   [',', 'PRN|<NP--RRB->'],
#   [',', 'PRN|<NP-:>']],
#  'ADJP-PRD|<,-ADJP>': [[',', 'ADJP'],
#   [',', 'ADJP-PRD|<ADJP-,>'],
#   [',', 'ADJP-PRD|<ADJP-CC>']],
#  'VP|<``-NP-TTL>': [['``', "VP|<NP-TTL-''>"], ['``', 'NP-TTL']],
#  "VP|<NP-TTL-''>": [['NP-TTL', "''"],
#   ['NP-TTL', "VP|<''-PP-CLR>"],
#   ['NP-TTL', "VP|<''-PP-DIR>"]],
#  'NP-TTL': [['NNP', 'NP-TTL|<NNP-NNP>'],
#   ['DT', 'NP-TTL|<NNP-NNP>'],
#   ['NNP', 'NNP'],
#   ['PRP', 'NP-TTL|<NNP-NNP>'],
#   ['DT', 'NP-TTL|<NNP-IN>'],
#   ['NNP', 'NNPS'],
#   ['NP', 'PP'],
#   ['DT', 'NP-TTL|<CD-NNP>'],
#   ['NP', 'PP-LOC']],
#  'NP-TTL|<NNP-NNP>': [['NNP', 'NNP'],
#   ['NNP', 'NP-TTL|<NNP-NNP>'],
#   ['NNP', 'NP-TTL|<NNP-,>']],
#  'NP|<JJ-``>': [['JJ', 'NP|<``-JJ>'],
#   ['JJ', 'NP|<``-NNS>'],
#   ['JJ', 'NP|<``-NN>']],
#  "NP|<JJ-''>": [['JJ', "NP|<''-NN>"], ['JJ', "NP|<''-NNS>"]],
#  "S|<NP-TTL-SBJ-''>": [['NP-TTL-SBJ', "S|<''-VP>"]],
#  'NP-TTL-SBJ': [['DT', 'NP-TTL-SBJ|<NNP-NNP>'],
#   ['PRP', 'NP-TTL-SBJ|<NNP-NNP>'],
#   ['NNP', 'NNP'],
#   ['NNP', 'NNPS']],
#  'NP-TTL-SBJ|<NNP-NNP>': [['NNP', 'NP-TTL-SBJ|<NNP-NNP>'], ['NNP', 'NNP']],
#  "S|<''-VP>": [["''", 'VP'], ["''", 'S|<VP-.>'], ["''", 'S|<VP-:>']],
#  'VP|<RB-S-PRD>': [['RB', 'S-PRD'], ['RB', 'VP|<S-PRD-,>']],
#  'NP-SBJ-57': [['NP', 'PP'], ['JJ', 'NNS']],
#  'PP|<``-NP-TTL>': [['``', "PP|<NP-TTL-''>"]],
#  "PP|<NP-TTL-''>": [['NP-TTL', "''"]],
#  'ADJP-PRD|<CC-ADJP>': [['CC', 'ADJP'], ['CC', 'ADJP-PRD|<ADJP-SBAR-2>']],
#  'NP-SBJ|<JJ-,>': [['JJ', 'NP-SBJ|<,-JJ>']],
#  'NP-SBJ|<,-JJ>': [[',', 'NP-SBJ|<JJ-,>'],
#   [',', 'NP-SBJ|<JJ-NN>'],
#   [',', 'NP-SBJ|<JJ-JJ>']],
#  'VP|<PRT-PP-CLR>': [['PRT', 'VP|<PP-CLR-PP-PRP>'],
#   ['PRT', 'PP-CLR'],
#   ['PRT', 'VP|<PP-CLR-PP-CLR>'],
#   ['PRT', 'VP|<PP-CLR-PP-TMP>']],
#  'VP|<PP-PRP-PP>': [['PP-PRP', 'PP']],
#  'WHNP-54': [['WP$', 'WHNP-54|<JJ-NNS>']],
#  'WHNP-54|<JJ-NNS>': [['JJ', 'NNS']],
#  'VP|<PRN-NP>': [['PRN', 'NP'],
#   ['PRN', 'VP|<NP-PP-CLR>'],
#   ['PRN', 'VP|<NP-PP-TMP>']],
#  "NP|<NP-TTL-''>": [['NP-TTL', "NP|<''-PRN>"], ['NP-TTL', "''"]],
#  'PRN|<S--RRB->': [['S', '-RRB-']],
#  'NP|<PRN-SBAR>': [['PRN', 'SBAR']],
#  'NP-TTL|<NNP-,>': [['NNP', ',']],
#  'NP|<,-PP-LOC>': [[',', 'PP-LOC']],
#  'NP-PRD|<``-NN>': [['``', 'NN'], ['``', "NP-PRD|<NN-''>"]],
#  "S|<NP-SBJ-''>": [['NP-SBJ', "S|<''-VP>"]],
#  "PP|<NP-''>": [['NP', "''"]],
#  "NP|<,-''>": [[',', "''"],
#   [',', "NP|<''-PP>"],
#   [',', "NP|<''-NP>"],
#   [',', "NP|<''-RB>"],
#   [',', "NP|<''-SBAR>"],
#   [',', "NP|<''-SBAR-ADV>"]],
#  'VP|<PRN-SBAR-PRP>': [['PRN', 'SBAR-PRP']],
#  'PRN|<VP-:>': [['VP', ':']],
#  'VP|<PP-LOC-PRN>': [['PP-LOC', 'PRN']],
#  'FRAG+PP-LOC': [['IN', 'NP']],
#  'VP|<ADVP-MNR-PP-LOC>': [['ADVP-MNR', 'PP-LOC']],
#  'VP|<PRT-PP-LOC>': [['PRT', 'PP-LOC'],
#   ['PRT', 'VP|<PP-LOC-,>'],
#   ['PRT', 'VP|<PP-LOC-SBAR-MNR>'],
#   ['PRT', 'VP|<PP-LOC-NP-TMP>']],
#  "NP-SBJ|<NP-TTL-''>": [['NP-TTL', "NP-SBJ|<''-PRN>"], ['NP-TTL', "''"]],
#  "NP-SBJ|<''-PRN>": [["''", 'NP-SBJ|<PRN-PP>']],
#  'NP-SBJ|<PRN-PP>': [['PRN', 'PP'], ['PRN', 'NP-SBJ|<PP-,>']],
#  'VP|<SBAR-TMP-:>': [['SBAR-TMP', 'VP|<:-PP>'],
#   ['SBAR-TMP', 'VP|<:-SBAR-ADV>']],
#  'VP|<PP-PRD-PP-LOC>': [['PP-PRD', 'PP-LOC']],
#  'VP|<:-PP>': [[':', 'PP']],
#  'ADJP|<,-ADJP>': [[',', 'ADJP|<ADJP-,>'], [',', 'ADJP']],
#  'ADJP|<ADJP-,>': [['ADJP', 'ADJP|<,-ADJP>'], ['ADJP', ',']],
#  'VP|<NP-:>': [['NP', 'VP|<:-PP-LOC>'],
#   ['NP', 'VP|<:-S-ADV>'],
#   ['NP', 'VP|<:-``>'],
#   ['NP', 'VP|<:-PP-TMP>'],
#   ['NP', 'VP|<:-ADVP>'],
#   ['NP', 'VP|<:-CC>']],
#  'NP|<DT-ADJP>': [['DT', 'NP|<ADJP-NNS>'], ['DT', 'NP|<ADJP-NN>']],
#  'VP|<:-PP-LOC>': [[':', 'VP|<PP-LOC-ADVP-MNR>']],
#  'NP|<,-SBAR-LOC>': [[',', 'SBAR-LOC']],
#  'PP-LOC|<:-JJ>': [[':', 'PP-LOC|<JJ-PP>']],
#  'PP-LOC|<JJ-PP>': [['JJ', 'PP']],
#  'NP-LGS|<JJ-NN>': [['JJ', 'NN'], ['JJ', 'NP-LGS|<NN-NN>']],
#  'VP|<ADJP-PRD-SBAR-3>': [['ADJP-PRD', 'SBAR-3']],
#  'SBAR-3|<,-SBAR>': [[',', 'SBAR-3|<SBAR-,>']],
#  'SBAR-3|<SBAR-,>': [['SBAR', 'SBAR-3|<,-CC>']],
#  'NP-SBJ-1|<DT-JJ>': [['DT', 'NP-SBJ-1|<JJ-NN>']],
#  'PP-CLR-2': [['TO', 'NP'], ['IN', 'NP']],
#  ...}

# %%
total_dict['VP|<VP-PP>']
total1=list(total)

# %%
import numpy as np
from tqdm import tqdm_notebook as tqdm
sent="'I' 'saw' 'John' 'with' 'my' 'eyes'"
sent=sent.split(" ")
print(sent)
nonterms=['CC','CD','DT','EX','FW','IN','JJ','JJR','JJS','LS','MD','NN','NNS','NNP','NNPS','PDT','POS','PRP','PRP$','RB','RBR','RBS','RP','SYM','TO','UH','VBD','VB','VBG','VBN','VBP','VBZ','WDT','WP','WP$','WRB']
nonterm=len(lhs_1)
score = [ [ [0.0 for y in range(nonterm ) ] for x in range( len(sent) +1 ) ] for z in range(len(sent) +1)]
back = [ [ [None for y in range( nonterm) ] for x in range( len(sent) +1 ) ] for z in range(len(sent) +1)]
a=0
for i in tqdm(range(len(sent))):
    l=sent[i]
    pks=set()
    for A in tqdm(Unary.keys()):
        for pk in prob.keys():    
            if pk.split(' -> ')[1] in sent:
                pks.add(pk.split(' -> ')[0])
        if str(A+" -> "+l) in prob.keys():
            print(A)
            score[i][i+1][lhs_dict[A]] = float(prob[str(A+' -> '+l)])
            print(score[i][i+1][lhs_dict[A]],i)
            a+=1
    print(pks)
    added=1
    print("started")
    while added:
        added=0
        for k in tqdm(Unary.keys()):
            for item in Unary[k]:
                if item in lhs_dict.keys():
                    if score[i][i+1][lhs_dict[item]]>0:
                        p1=prob[str(k)+' -> '+item]*score[i][i+1][lhs_dict[item]]
                        if p1>score[i][i+1][lhs_dict[k]]:
                            score[i][i+1][lhs_dict[k]]=p1
                            back[i][i+1][lhs_dict[k]]=item
                            print(back[i][i+1][lhs_dict[k]])
                            added=1
# Out:
# ["'I'", "'saw'", "'John'", "'with'", "'my'", "'eyes'"]
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# NNP
# 0.00021254 0
# PRP
# 0.0658508 0
# {'NNP', 'PRP$', 'NNS', 'PRP', 'VBD', 'IN'}
# started
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# PRP
# PRP
# PRP
# NNP
# PRP
# NNP
# PRP
# NNP
# NNP
# PRP
# NNP
# PRP
# NNP
# PRP
# NNP
# PRP
# NNP
# PRP
# PRP
# PRP
# PRP
# PRP
# PRP
# PRP
# PRP
# NNP
# NNP
# PRP
# NNP
# PRP
# NNP
# NNP
# PRP
# PRP
# PRP
# PRP
# NNP
# PRP
# PRP
# PRP
# PRP
# PRP
# PRP
# NNP
# NNP
# NNP
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# VBD
# 0.00164312 1
# {'NNP', 'PRP$', 'NNS', 'PRP', 'VBD', 'IN'}
# started
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# VBD
# VBD
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# NNP
# 0.00361318 2
# {'NNP', 'PRP$', 'NNS', 'PRP', 'VBD', 'IN'}
# started
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# NNP
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# IN
# 0.0392614 3
# {'NNP', 'PRP$', 'NNS', 'PRP', 'VBD', 'IN'}
# started
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# IN
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# PRP$
# 0.0234987 4
# {'NNP', 'PRP$', 'NNS', 'PRP', 'VBD', 'IN'}
# started
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# PRP$
# PRP$
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# NNS
# 0.000330743 5
# {'NNP', 'PRP$', 'NNS', 'PRP', 'VBD', 'IN'}
# started
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# NNS
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))

# %%
for i in range(7):
    print([j for j, e in enumerate(score[i][6]) if e != 0])
# Out:
# []
# []
# []
# []
# []
# [203, 595, 915, 1005, 1300, 1348, 1818, 1918, 2214, 2622, 2762, 2803, 2814, 2828, 3047, 3131, 3186, 3760]
# []

# %%
Binary['S']
lhs_dict['S']
# Out:
# 3835

# %%
print(len(sent))
for span in tqdm(range(2,len(sent)+1)):
    print("span:"+str(span))
    for begin in tqdm(range(len(sent)-span+1)):
        end=begin+span
        print("span: "+str(span)+" begin: "+str(begin)+" end: "+str(end))
        for split in tqdm(range(begin+1,end)):
            print("span: "+str(span)+" begin: "+str(begin)+" end: "+str(end)+" split: "+str(split))
            print("Check in grammar")
            for k in Binary.keys():
                for item in Binary[k]:
                    if begin==0 and end==6:
                        
                        if item[0] in lhs_dict.keys() and item[1] in lhs_dict.keys():
                            
                            p1=score[begin][split][lhs_dict[item[0]]]*score[split][end][lhs_dict[item[1]]]*prob[str(k)+' -> '+item[0]+" "+item[1]]
                            if score[begin][split][lhs_dict[item[0]]]!=0 and score[split][end][lhs_dict[item[1]]]: 
                                print(score[begin][split][lhs_dict[item[0]]])
                                print(score[split][end][lhs_dict[item[1]]])
                            if p1>score[begin][end][lhs_dict[A]]:
                                print(p1)
                                score[begin][end][lhs_dict[A]]=p1
                                back[begin][end][lhs_dict[A]]=(split,item[0],item[1])
                                print(back[begin][end][lhs_dict[A]])
                                print("S: "+k)
                                print(begin,end)
        added=1
        while added:
            added=0
            for k in tqdm(Unary.keys()):
                for item in Unary[k]:
                    if item in lhs_dict.keys():
                        if score[begin][end][lhs_dict[item]]>0:
                            p1=prob[str(k)+' -> '+item]*score[begin][end][lhs_dict[item]]
                            print(p1)
                            if p1>score[begin][end][lhs_dict[k]]:
                                score[begin][end][lhs_dict[k]]=p1
                                back[begin][end][lhs_dict[k]]=item
                                added=1
# Out:
# 6
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# span:2
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# span: 2 begin: 0 end: 2
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 0 end: 2 split: 1
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 2 begin: 1 end: 3
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 1 end: 3 split: 2
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 2 begin: 2 end: 4
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 2 end: 4 split: 3
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 2 begin: 3 end: 5
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 3 end: 5 split: 4
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 2 begin: 4 end: 6
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 2 begin: 4 end: 6 split: 5
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span:3
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# span: 3 begin: 0 end: 3
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# span: 3 begin: 0 end: 3 split: 1
# Check in grammar
# span: 3 begin: 0 end: 3 split: 2
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 3 begin: 1 end: 4
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# span: 3 begin: 1 end: 4 split: 2
# Check in grammar
# span: 3 begin: 1 end: 4 split: 3
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 3 begin: 2 end: 5
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# span: 3 begin: 2 end: 5 split: 3
# Check in grammar
# span: 3 begin: 2 end: 5 split: 4
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 3 begin: 3 end: 6
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# span: 3 begin: 3 end: 6 split: 4
# Check in grammar
# span: 3 begin: 3 end: 6 split: 5
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span:4
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# span: 4 begin: 0 end: 4
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# span: 4 begin: 0 end: 4 split: 1
# Check in grammar
# span: 4 begin: 0 end: 4 split: 2
# Check in grammar
# span: 4 begin: 0 end: 4 split: 3
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 4 begin: 1 end: 5
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# span: 4 begin: 1 end: 5 split: 2
# Check in grammar
# span: 4 begin: 1 end: 5 split: 3
# Check in grammar
# span: 4 begin: 1 end: 5 split: 4
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 4 begin: 2 end: 6
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# span: 4 begin: 2 end: 6 split: 3
# Check in grammar
# span: 4 begin: 2 end: 6 split: 4
# Check in grammar
# span: 4 begin: 2 end: 6 split: 5
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span:5
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# span: 5 begin: 0 end: 5
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# span: 5 begin: 0 end: 5 split: 1
# Check in grammar
# span: 5 begin: 0 end: 5 split: 2
# Check in grammar
# span: 5 begin: 0 end: 5 split: 3
# Check in grammar
# span: 5 begin: 0 end: 5 split: 4
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span: 5 begin: 1 end: 6
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# span: 5 begin: 1 end: 6 split: 2
# Check in grammar
# span: 5 begin: 1 end: 6 split: 3
# Check in grammar
# span: 5 begin: 1 end: 6 split: 4
# Check in grammar
# span: 5 begin: 1 end: 6 split: 5
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))
# span:6
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# span: 6 begin: 0 end: 6
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# span: 6 begin: 0 end: 6 split: 1
# Check in grammar
# span: 6 begin: 0 end: 6 split: 2
# Check in grammar
# span: 6 begin: 0 end: 6 split: 3
# Check in grammar
# span: 6 begin: 0 end: 6 split: 4
# Check in grammar
# span: 6 begin: 0 end: 6 split: 5
# Check in grammar
# HBox(children=(IntProgress(value=0, max=465), HTML(value='')))

# %%
class GrammarTree(object):
    '''
    Tree data structure used to represent the grammar tree output generated by the cky algorithm
    '''
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

    def insertLeft(self, new_node):
            self.left = new_node

    def insertRight(self, new_node):
            self.right = new_node

# %%
from collections import deque
def print_level_order(head, queue = deque()):
    if isinstance(head,str):
        print(head)
        return
    print(head.data)
    [queue.append(node) for node in [head.left, head.right] if node]
    if queue:
        print_level_order(queue.popleft(), queue)

# %%
def build_tree(start,end,idx,back,non_terms):
    '''
    build_tree() builds tree from the backpointer matrix obtained in the cky() function
    :param start: start index for tree
    :param end: end index for tree
    :param idx: index used to find non_terminal
    :param back: the backpointer matrix
    :param non_terms: a list of non-terminals
    :return:
    '''
    tree = GrammarTree(non_terms[idx])
    node = back[start][end][idx]
    if isinstance(node,tuple):
        split,left_rule,right_rule = node
        tree.insertLeft(build_tree(start,split,left_rule,back,non_terms))
        tree.insertRight(build_tree(split,end,right_rule,back,non_terms))
        return tree
"""
    else:
        if node>0:
            tree.insertLeft(GrammarTree(non_terms[node]))
        return tree
"""
# Out:
# '\n    else:\n        if node>0:\n            tree.insertLeft(GrammarTree(non_terms[node]))\n        return tree\n'

# %%
def get_parse_tree(score, back,non_terms):
    '''
    get_parse_tree() calls the build_tree() method
    :param score: score matrix
    :param back: backpointer matrix
    :param non_terms: list of non_terminals
    :return: GrammarTree the final parse tree
    '''
    root_index = score[0][len(score)-1].index(max(score[0][len(score)-1]))
    print(root_index)
    print(score[0][len(score)-1][root_index])
    tree = build_tree(0,len(score)-1,root_index,back,non_terms)
    print(tree)
    return tree

# %%
tree=get_parse_tree(score,back,reverse_dict)
# Out:
# 0
# 0.0
# None

# %%
reverse_dict[0]
# Out:
# 'UCP|<CC-NNP>'
